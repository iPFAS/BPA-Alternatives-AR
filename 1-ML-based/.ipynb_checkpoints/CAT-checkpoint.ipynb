# %%
import time
import warnings
import sys
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
import pandas as pd
import numpy as np
from sklearn.feature_selection import SelectPercentile, f_classif, SelectFromModel
from sklearn.metrics import roc_auc_score, confusion_matrix, precision_recall_curve, auc, mean_squared_error, \
    r2_score, mean_absolute_error,cohen_kappa_score,accuracy_score,f1_score,matthews_corrcoef,precision_score,recall_score
from sklearn.model_selection import train_test_split
import multiprocessing
from xgboost import XGBRegressor, XGBClassifier
from catboost import CatBoostClassifier
from catboost import CatBoostRegressor

start = time.time()
warnings.filterwarnings("ignore")

def standardize(col):
    return (col - np.mean(col)) / np.std(col)

# the metrics for classification
def statistical(y_true, y_pred, y_pro):
    c_mat = confusion_matrix(y_true, y_pred)
    tn, fp, fn, tp = list(c_mat.flatten())
    se = tp / (tp + fn)
    sp = tn / (tn + fp)
    auc_prc = auc(precision_recall_curve(y_true, y_pro, pos_label=1)[1],
                  precision_recall_curve(y_true, y_pro, pos_label=1)[0])
    acc = (tp + tn) / (tn + fp + fn + tp)
#     acc_skl = accuracy_score(y_true, y_pred)
    auc_roc = roc_auc_score(y_true, y_pro)
    recall = se
#     recall_skl = recall_score(y_true, y_pred)
    precision = tp / (tp + fp)
#     precision_skl = precision_score(y_true, y_pred)
    f1 = 2 * (precision * recall) / (precision + recall) # F1 = 2 * (precision * recall) / (precision + recall)
#     f1_skl = f1_score(y_true, y_pred)
    kappa = cohen_kappa_score(y_true,y_pred)
    mcc = (tp * tn - fp * fn) / np.sqrt((tp + fp) * (tp + fn) * (tn + fp) * (tn + fn) + 1e-8)
#     mcc_skl = matthews_corrcoef(y_true,y_pred)
    return tn,fp,fn,tp,se,sp,auc_prc,acc,auc_roc,recall,precision,f1,kappa,mcc

def all_one_zeros(data):
    if (len(np.unique(data)) == 2):
        flag = False
    else:
        flag = True
    return flag


feature_selection = False
tasks_dic = {'1-AR-Alva-6108-slim-Normalize-group.csv': ['activity']}

# %%
# {'actual_estimator__eta': LogUniformDistribution(high=0.5, low=1e-06),
#  'actual_estimator__depth': IntUniformDistribution(high=11, low=1, step=1),
#  'actual_estimator__n_estimators': IntUniformDistribution(high=300, low=10, step=1),
#  'actual_estimator__random_strength': UniformDistribution(high=0.8, low=0.0),
#  'actual_estimator__l2_leaf_reg': IntLogUniformDistribution(high=200, low=1, step=1)}

# %%
file_name = '1-AR-Alva-6108-slim-Normalize-group.csv'
task_type = 'cla'  # 'reg' or 'cla'
dataset_label = file_name.split('/')[-1].split('_')[0]
tasks = tasks_dic[dataset_label]
OPT_ITERS = 50
repetitions = 10
num_pools = 10
unbalance = True
patience = 100
ecfp = True
# preset the hyper_parameters_space 
space_ = {'n_estimators': hp.choice('n_estimators', range(10,300,1)),
#           'learning_rate': hp.loguniform('learning_rate', 1e-06, 0.5),
          'learning_rate': hp.uniform('learning_rate', 1e-06, 0.5),
          'depth': hp.choice('depth', range(1,11,1)),
          'random_strength': hp.uniform('random_strength', 0.0, 0.8),
          'l2_leaf_reg': hp.choice('l2_leaf_reg', range(1,200,1)),
          }

n_estimators_ls = range(10,300,1)
depth_ls =  range(1,11,1)
l2_leaf_reg_ls = range(1,200,1)

dataset = pd.read_csv(file_name)
pd_res = []

# %%
def hyper_runing(subtask):
    cols = [subtask]
    cols.extend(dataset.columns[(len(tasks) + 1):])
    sub_dataset = dataset[cols]

    # detect the na in the subtask (y cloumn)
    rm_index = sub_dataset[subtask][sub_dataset[subtask].isnull()].index
    sub_dataset.drop(index=rm_index, inplace=True)

    # remove the features with na
    sub_dataset = sub_dataset.dropna(axis=1)
    # *******************
    # demension reduction
    # *******************
    # Removing features with low variance
    # threshold = 0.05
    data_fea_var = sub_dataset.iloc[:, 2:].var()
    del_fea1 = list(data_fea_var[data_fea_var <= 0.05].index)
    sub_dataset.drop(columns=del_fea1, inplace=True)

    # pair correlations
    # threshold = 0.95
    data_fea_corr = sub_dataset.iloc[:, 2:].corr()
    del_fea2_col = []
    del_fea2_ind = []
    length = data_fea_corr.shape[1]
    for i in range(length):
        for j in range(i + 1, length):
            if abs(data_fea_corr.iloc[i, j]) >= 0.95:
                del_fea2_col.append(data_fea_corr.columns[i])
                del_fea2_ind.append(data_fea_corr.index[j])
    sub_dataset.drop(columns=del_fea2_ind, inplace=True)

    # standardize the features
    cols_ = list(sub_dataset.columns)[2:]
    if not ecfp :
        sub_dataset[cols_] = sub_dataset[cols_].apply(standardize, axis=0)

    # get the attentivefp data splits
    data_tr = sub_dataset[sub_dataset['group'] == 'train']
    data_va = sub_dataset[sub_dataset['group'] == 'valid']
    data_te = sub_dataset[sub_dataset['group'] == 'test']

    # prepare data for training
    # training set
    data_tr_y = data_tr[subtask].values.reshape(-1, 1)
    data_tr_x = np.array(data_tr.iloc[:, 2:].values)

    # validation set
    data_va_y = data_va[subtask].values.reshape(-1, 1)
    data_va_x = np.array(data_va.iloc[:, 2:].values)

    # test set
    data_te_y = data_te[subtask].values.reshape(-1, 1)
    data_te_x = np.array(data_te.iloc[:, 2:].values)

    if feature_selection:
        # univariate feature selection
        trans1 = SelectPercentile(f_classif, percentile=80)
        trans1.fit(data_tr_x, data_tr_y)
        data_tr_x = trans1.transform(data_tr_x)
        data_va_x = trans1.transform(data_va_x)
        data_te_x = trans1.transform(data_te_x)

        # select from model
        clf = XGBClassifier(random_state=1)
        clf = clf.fit(data_tr_x, data_tr_y)
        trans2 = SelectFromModel(clf, prefit=True)

        data_tr_x = trans2.transform(data_tr_x)
        data_va_x = trans2.transform(data_va_x)
        data_te_x = trans2.transform(data_te_x)

    num_fea = data_tr_x.shape[1]
    print('the num of retained features for the ' + dataset_label + ' ' + subtask + ' is:', num_fea)

    def hyper_opt(args):
        model = CatBoostClassifier(**args, random_state=1) if task_type == 'cla' else CatBoostRegressor(**args,
                                                                                                   random_state=1)

        model.fit(data_tr_x, data_tr_y,
          eval_set=[(data_va_x, data_va_y)],
          early_stopping_rounds=patience, verbose=False)
        val_preds = model.predict_proba(data_va_x) if task_type == 'cla' else \
            model.predict(data_va_x)
        loss = 1 - roc_auc_score(data_va_y, val_preds[:, 1]) if task_type == 'cla' else np.sqrt(
            mean_squared_error(data_va_y, val_preds))
        return {'loss': loss, 'status': STATUS_OK}

    # start hyper-parameters optimization
    trials = Trials()
    best_results = fmin(hyper_opt, space_, algo=tpe.suggest, max_evals=OPT_ITERS, trials=trials, show_progressbar=False)
    print('the best hyper-parameters for ' + dataset_label + ' ' + subtask + ' are:  ', best_results)
    
    best_model = CatBoostClassifier(    n_estimators= n_estimators_ls[best_results['n_estimators']],
#                                         learning_rate = best_results['learning_rate'],
                                        learning_rate=best_results['learning_rate'],
                                        depth=depth_ls[best_results['depth']],
                                        random_strength=best_results['random_strength'],
                                        l2_leaf_reg=l2_leaf_reg_ls[best_results['l2_leaf_reg']],
                                        random_state=1) \
        if task_type == 'cla' else CatBoostRegressor(
                                        n_estimators= n_estimators_ls[best_results['n_estimators']],
#                                         learning_rate = best_results['learning_rate'],
                                        learning_rate=best_results['learning_rate'],
                                        depth=depth_ls[best_results['depth']],
                                        random_strength=best_results['random_strength'],
                                        l2_leaf_reg=l2_leaf_reg_ls[best_results['l2_leaf_reg']],
                                        random_state=1)  
    
    best_model.fit(data_tr_x, data_tr_y,
                  eval_set=[(data_va_x, data_va_y)],
                  early_stopping_rounds=patience, verbose=False)
    
    num_of_compounds = len(sub_dataset)

    if task_type == 'cla':
        # training set
        tr_pred = best_model.predict_proba(data_tr_x)
        tr_results = [dataset_label, subtask, 'tr', num_fea, num_of_compounds, data_tr_y[data_tr_y == 1].shape[0],
                      data_tr_y[data_tr_y == 0].shape[0],
                      data_tr_y[data_tr_y == 0].shape[0] / data_tr_y[data_tr_y == 1].shape[0],
                      n_estimators_ls[best_results['n_estimators']],
#                       best_results['learning_rate'],
                      best_results['learning_rate'],
                      depth_ls[best_results['depth']],
                      best_results['random_strength'],
                      l2_leaf_reg_ls[best_results['l2_leaf_reg']],
                     ]
        tr_results.extend(statistical(data_tr_y, np.argmax(tr_pred, axis=1), tr_pred[:, 1]))
        # validation set
        va_pred = best_model.predict_proba(data_va_x)
                      
        va_results = [dataset_label, subtask, 'va', num_fea, num_of_compounds, data_va_y[data_va_y == 1].shape[0],
                      data_va_y[data_va_y == 0].shape[0],
                      data_va_y[data_va_y == 0].shape[0] / data_va_y[data_va_y == 1].shape[0],
                      n_estimators_ls[best_results['n_estimators']],
#                       best_results['learning_rate'],
                      best_results['learning_rate'],
                      depth_ls[best_results['depth']],
                      best_results['random_strength'],
                      l2_leaf_reg_ls[best_results['l2_leaf_reg']],
                     ]
        va_results.extend(statistical(data_va_y, np.argmax(va_pred, axis=1), va_pred[:, 1]))

        # test set
        te_pred = best_model.predict_proba(data_te_x)
        te_results = [dataset_label, subtask, 'te', num_fea, num_of_compounds, data_te_y[data_te_y == 1].shape[0],
                      data_te_y[data_te_y == 0].shape[0],
                      data_te_y[data_te_y == 0].shape[0] / data_te_y[data_te_y == 1].shape[0],
                      n_estimators_ls[best_results['n_estimators']],
#                       best_results['learning_rate'],
                      best_results['learning_rate'],
                      depth_ls[best_results['depth']],
                      best_results['random_strength'],
                      l2_leaf_reg_ls[best_results['l2_leaf_reg']],
                     ]
        te_results.extend(statistical(data_te_y, np.argmax(te_pred, axis=1), te_pred[:, 1]))
    else:
        # training set
        tr_pred = best_model.predict(data_tr_x)
        tr_results = [dataset_label, subtask, 'tr', num_fea, num_of_compounds,
                      n_estimators_ls[best_results['n_estimators']],
#                       best_results['learning_rate'],
                      best_results['learning_rate'],
                      depth_ls[best_results['depth']],
                      best_results['random_strength'],
                      l2_leaf_reg_ls[best_results['l2_leaf_reg']],
                      np.sqrt(mean_squared_error(data_tr_y, tr_pred)), r2_score(data_tr_y, tr_pred),
                      mean_absolute_error(data_tr_y, tr_pred)]

        # validation set
        va_pred = best_model.predict(data_va_x)
        va_results = [dataset_label, subtask, 'va', num_fea, num_of_compounds,
                      n_estimators_ls[best_results['n_estimators']],
#                       best_results['learning_rate'],
                      best_results['learning_rate'],
                      depth_ls[best_results['depth']],
                      best_results['random_strength'],
                      l2_leaf_reg_ls[best_results['l2_leaf_reg']],
                      np.sqrt(mean_squared_error(data_va_y, va_pred)), r2_score(data_va_y, va_pred),
                      mean_absolute_error(data_va_y, va_pred)]

        # test set
        te_pred = best_model.predict(data_te_x)
        te_results = [dataset_label, subtask, 'te', num_fea, num_of_compounds,
                      n_estimators_ls[best_results['n_estimators']],
#                       best_results['learning_rate'],
                      best_results['learning_rate'],
                      depth_ls[best_results['depth']],
                      best_results['random_strength'],
                      l2_leaf_reg_ls[best_results['l2_leaf_reg']],
                      np.sqrt(mean_squared_error(data_te_y, te_pred)), r2_score(data_te_y, te_pred),
                      mean_absolute_error(data_te_y, te_pred)]
    return tr_results, va_results, te_results


pool = multiprocessing.Pool(num_pools)
res = pool.starmap(hyper_runing, zip(tasks))
pool.close()
pool.join()
for item in res:
    for i in range(3):
        pd_res.append(item[i])
if task_type == 'cla':       
                                            
    best_hyper = pd.DataFrame(pd_res, columns=['dataset', 'subtask', 'set',
                                               'num_of_retained_feature',
                                               'num_of_compounds', 'postives',
                                               'negtives', 'negtives/postives',
                                               'n_estimators',
#                                                'learning_rate',
                                               'learning_rate','depth','random_strength','l2_leaf_reg',
                                               'tn', 'fp', 'fn', 'tp', 'se', 'sp',
                                               'auc_prc', 'acc', 'auc_roc','recall','precision','f1','kappa','mcc'])
else:
    best_hyper = pd.DataFrame(pd_res, columns=['dataset', 'subtask', 'set',
                                               'n_estimators',
#                                                'learning_rate', 
                                               'learning_rate','depth','random_strength','l2_leaf_reg',
                                               'rmse', 'r2', 'mae'])
best_hyper.to_csv('./model/' + dataset_label + '_CAT_hyperopt_info.csv', index=0)

if task_type == 'cla':
    print('train', best_hyper[best_hyper['set'] == 'tr']['auc_roc'].mean(),
          best_hyper[best_hyper['set'] == 'tr']['auc_prc'].mean())
    print('valid', best_hyper[best_hyper['set'] == 'va']['auc_roc'].mean(),
          best_hyper[best_hyper['set'] == 'va']['auc_prc'].mean())
    print('test', best_hyper[best_hyper['set'] == 'te']['auc_roc'].mean(),
          best_hyper[best_hyper['set'] == 'te']['auc_prc'].mean())
else:
    print('train', best_hyper[best_hyper['set'] == 'tr']['rmse'].mean(),
          best_hyper[best_hyper['set'] == 'tr']['r2'].mean(), best_hyper[best_hyper['set'] == 'tr']['mae'].mean())
    print('valid', best_hyper[best_hyper['set'] == 'va']['rmse'].mean(),
          best_hyper[best_hyper['set'] == 'va']['r2'].mean(), best_hyper[best_hyper['set'] == 'va']['mae'].mean())
    print('test', best_hyper[best_hyper['set'] == 'te']['rmse'].mean(),
          best_hyper[best_hyper['set'] == 'te']['r2'].mean(), best_hyper[best_hyper['set'] == 'te']['mae'].mean())
# Out:
# the num of retained features for the 1-AR-Alva-6108-slim-Normalize-group.csv activity is: 1508
# 0:	learn: 0.4772915	total: 62.2ms	remaining: 10s
# 1:	learn: 0.3723341	total: 70.7ms	remaining: 5.66s
# 2:	learn: 0.3430872	total: 76.9ms	remaining: 4.07s
# 3:	learn: 0.3222038	total: 83ms	remaining: 3.28s
# 4:	learn: 0.3098999	total: 88.8ms	remaining: 2.79s
# 5:	learn: 0.3019175	total: 94.3ms	remaining: 2.45s
# 6:	learn: 0.2968996	total: 99.5ms	remaining: 2.2s
# 7:	learn: 0.2931951	total: 105ms	remaining: 2.02s
# 8:	learn: 0.2890393	total: 111ms	remaining: 1.88s
# 9:	learn: 0.2863918	total: 116ms	remaining: 1.77s
# 10:	learn: 0.2831141	total: 122ms	remaining: 1.68s
# 11:	learn: 0.2788659	total: 128ms	remaining: 1.6s
# 12:	learn: 0.2771092	total: 134ms	remaining: 1.54s
# 13:	learn: 0.2741101	total: 140ms	remaining: 1.48s
# 14:	learn: 0.2711171	total: 146ms	remaining: 1.43s
# 15:	learn: 0.2696467	total: 152ms	remaining: 1.38s
# 16:	learn: 0.2678423	total: 157ms	remaining: 1.34s
# 17:	learn: 0.2657511	total: 163ms	remaining: 1.3s
# 18:	learn: 0.2640994	total: 169ms	remaining: 1.27s
# 19:	learn: 0.2620630	total: 175ms	remaining: 1.24s
# 20:	learn: 0.2609425	total: 181ms	remaining: 1.21s
# 21:	learn: 0.2595342	total: 187ms	remaining: 1.19s
# 22:	learn: 0.2572580	total: 192ms	remaining: 1.16s
# 23:	learn: 0.2562628	total: 198ms	remaining: 1.14s
# 24:	learn: 0.2549417	total: 204ms	remaining: 1.12s
# 25:	learn: 0.2529746	total: 211ms	remaining: 1.1s
# 26:	learn: 0.2522788	total: 217ms	remaining: 1.08s
# 27:	learn: 0.2518436	total: 223ms	remaining: 1.06s
# 28:	learn: 0.2507424	total: 229ms	remaining: 1.05s
# 29:	learn: 0.2491710	total: 239ms	remaining: 1.05s
# 30:	learn: 0.2480299	total: 244ms	remaining: 1.03s
# 31:	learn: 0.2477276	total: 251ms	remaining: 1.02s
# 32:	learn: 0.2467857	total: 257ms	remaining: 1s
# 33:	learn: 0.2449195	total: 262ms	remaining: 987ms
# 34:	learn: 0.2438100	total: 268ms	remaining: 973ms
# 35:	learn: 0.2434432	total: 274ms	remaining: 960ms
# 36:	learn: 0.2427744	total: 281ms	remaining: 948ms
# 37:	learn: 0.2412850	total: 287ms	remaining: 935ms
# 38:	learn: 0.2405064	total: 293ms	remaining: 923ms
# 39:	learn: 0.2395892	total: 299ms	remaining: 911ms
# 40:	learn: 0.2383912	total: 304ms	remaining: 898ms
# 41:	learn: 0.2376119	total: 310ms	remaining: 887ms
# 42:	learn: 0.2368785	total: 316ms	remaining: 875ms
# 43:	learn: 0.2354533	total: 322ms	remaining: 864ms
# 44:	learn: 0.2352660	total: 328ms	remaining: 853ms
# 45:	learn: 0.2343304	total: 334ms	remaining: 842ms
# 46:	learn: 0.2333400	total: 340ms	remaining: 832ms
# 47:	learn: 0.2323398	total: 346ms	remaining: 822ms
# 48:	learn: 0.2320612	total: 352ms	remaining: 812ms
# 49:	learn: 0.2306552	total: 359ms	remaining: 803ms
# 50:	learn: 0.2295838	total: 368ms	remaining: 800ms
# 51:	learn: 0.2293985	total: 373ms	remaining: 789ms
# 52:	learn: 0.2288780	total: 379ms	remaining: 780ms
# 53:	learn: 0.2284124	total: 390ms	remaining: 780ms
# 54:	learn: 0.2282823	total: 396ms	remaining: 771ms
# 55:	learn: 0.2281018	total: 403ms	remaining: 762ms
# 56:	learn: 0.2279762	total: 414ms	remaining: 763ms
# 57:	learn: 0.2272917	total: 420ms	remaining: 753ms
# 58:	learn: 0.2267679	total: 426ms	remaining: 744ms
# 59:	learn: 0.2258260	total: 435ms	remaining: 739ms
# 60:	learn: 0.2251837	total: 441ms	remaining: 730ms
# 61:	learn: 0.2238497	total: 447ms	remaining: 721ms
# 62:	learn: 0.2229004	total: 452ms	remaining: 711ms
# 63:	learn: 0.2220385	total: 458ms	remaining: 702ms
# 64:	learn: 0.2219268	total: 465ms	remaining: 694ms
# 65:	learn: 0.2218279	total: 472ms	remaining: 686ms
# 66:	learn: 0.2195447	total: 478ms	remaining: 678ms
# 67:	learn: 0.2188210	total: 484ms	remaining: 669ms
# 68:	learn: 0.2182987	total: 490ms	remaining: 661ms
# 69:	learn: 0.2176540	total: 497ms	remaining: 653ms
# 70:	learn: 0.2171697	total: 503ms	remaining: 645ms
# 71:	learn: 0.2169572	total: 510ms	remaining: 637ms
# 72:	learn: 0.2163116	total: 516ms	remaining: 629ms
# 73:	learn: 0.2158872	total: 523ms	remaining: 621ms
# 74:	learn: 0.2154136	total: 529ms	remaining: 613ms
# 75:	learn: 0.2153513	total: 535ms	remaining: 605ms
# 76:	learn: 0.2152503	total: 541ms	remaining: 597ms
# 77:	learn: 0.2151846	total: 548ms	remaining: 590ms
# 78:	learn: 0.2151201	total: 554ms	remaining: 582ms
# 79:	learn: 0.2150560	total: 561ms	remaining: 575ms
# 80:	learn: 0.2149928	total: 567ms	remaining: 567ms
# 81:	learn: 0.2147051	total: 573ms	remaining: 559ms
# 82:	learn: 0.2140997	total: 579ms	remaining: 551ms
# 83:	learn: 0.2140366	total: 585ms	remaining: 543ms
# 84:	learn: 0.2132845	total: 591ms	remaining: 535ms
# 85:	learn: 0.2126870	total: 597ms	remaining: 527ms
# 86:	learn: 0.2122417	total: 603ms	remaining: 519ms
# 87:	learn: 0.2117159	total: 608ms	remaining: 511ms
# 88:	learn: 0.2111112	total: 614ms	remaining: 504ms
# 89:	learn: 0.2110491	total: 620ms	remaining: 496ms
# 90:	learn: 0.2106300	total: 627ms	remaining: 489ms
# 91:	learn: 0.2105681	total: 633ms	remaining: 482ms
# 92:	learn: 0.2105069	total: 640ms	remaining: 475ms
# 93:	learn: 0.2104462	total: 646ms	remaining: 467ms
# 94:	learn: 0.2103437	total: 652ms	remaining: 460ms
# 95:	learn: 0.2102835	total: 658ms	remaining: 452ms
# 96:	learn: 0.2102241	total: 664ms	remaining: 445ms
# 97:	learn: 0.2100397	total: 671ms	remaining: 438ms
# 98:	learn: 0.2099475	total: 677ms	remaining: 431ms
# 99:	learn: 0.2095366	total: 683ms	remaining: 423ms
# 100:	learn: 0.2094405	total: 689ms	remaining: 416ms
# 101:	learn: 0.2093069	total: 695ms	remaining: 409ms
# 102:	learn: 0.2084827	total: 701ms	remaining: 401ms
# 103:	learn: 0.2083880	total: 707ms	remaining: 394ms
# 104:	learn: 0.2083189	total: 713ms	remaining: 387ms
# 105:	learn: 0.2082596	total: 723ms	remaining: 382ms
# 106:	learn: 0.2079921	total: 730ms	remaining: 375ms
# 107:	learn: 0.2078982	total: 736ms	remaining: 368ms
# 108:	learn: 0.2078151	total: 742ms	remaining: 361ms
# 109:	learn: 0.2077189	total: 749ms	remaining: 354ms
# 110:	learn: 0.2073052	total: 756ms	remaining: 347ms
# 111:	learn: 0.2072466	total: 763ms	remaining: 340ms
# 112:	learn: 0.2068552	total: 769ms	remaining: 333ms
# 113:	learn: 0.2064645	total: 775ms	remaining: 326ms
# 114:	learn: 0.2062847	total: 781ms	remaining: 319ms
# 115:	learn: 0.2062270	total: 788ms	remaining: 312ms
# 116:	learn: 0.2061374	total: 795ms	remaining: 306ms
# 117:	learn: 0.2060805	total: 802ms	remaining: 299ms
# 118:	learn: 0.2052710	total: 808ms	remaining: 292ms
# 119:	learn: 0.2052133	total: 815ms	remaining: 285ms
# 120:	learn: 0.2051558	total: 821ms	remaining: 278ms
# 121:	learn: 0.2050987	total: 827ms	remaining: 271ms
# 122:	learn: 0.2050422	total: 833ms	remaining: 264ms
# 123:	learn: 0.2049859	total: 840ms	remaining: 257ms
# 124:	learn: 0.2049309	total: 847ms	remaining: 251ms
# 125:	learn: 0.2048755	total: 858ms	remaining: 245ms
# 126:	learn: 0.2043612	total: 864ms	remaining: 238ms
# 127:	learn: 0.2035273	total: 871ms	remaining: 231ms
# 128:	learn: 0.2034327	total: 877ms	remaining: 224ms
# 129:	learn: 0.2033782	total: 884ms	remaining: 218ms
# 130:	learn: 0.2028561	total: 890ms	remaining: 211ms
# 131:	learn: 0.2025247	total: 896ms	remaining: 204ms
# 132:	learn: 0.2022457	total: 902ms	remaining: 197ms
# 133:	learn: 0.2018117	total: 916ms	remaining: 191ms
# 134:	learn: 0.2015645	total: 922ms	remaining: 184ms
# 135:	learn: 0.2010178	total: 928ms	remaining: 177ms
# 136:	learn: 0.2003887	total: 934ms	remaining: 171ms
# 137:	learn: 0.2003345	total: 941ms	remaining: 164ms
# 138:	learn: 0.2001998	total: 947ms	remaining: 157ms
# 139:	learn: 0.2001463	total: 954ms	remaining: 150ms
# 140:	learn: 0.2000943	total: 960ms	remaining: 143ms
# 141:	learn: 0.2000426	total: 966ms	remaining: 136ms
# 142:	learn: 0.1999912	total: 972ms	remaining: 129ms
# 143:	learn: 0.1999402	total: 979ms	remaining: 122ms
# 144:	learn: 0.1996940	total: 985ms	remaining: 115ms
# 145:	learn: 0.1991873	total: 991ms	remaining: 109ms
# 146:	learn: 0.1989273	total: 997ms	remaining: 102ms
# 147:	learn: 0.1988478	total: 1s	remaining: 94.9ms
# 148:	learn: 0.1983919	total: 1.01s	remaining: 88.1ms
# 149:	learn: 0.1981916	total: 1.01s	remaining: 81.3ms
# 150:	learn: 0.1977489	total: 1.02s	remaining: 74.5ms
# 151:	learn: 0.1976477	total: 1.03s	remaining: 67.7ms
# 152:	learn: 0.1975989	total: 1.03s	remaining: 60.9ms
# 153:	learn: 0.1975504	total: 1.04s	remaining: 54.1ms
# 154:	learn: 0.1975026	total: 1.05s	remaining: 47.3ms
# 155:	learn: 0.1974550	total: 1.05s	remaining: 40.5ms
# 156:	learn: 0.1972829	total: 1.06s	remaining: 33.8ms
# 157:	learn: 0.1969582	total: 1.07s	remaining: 27ms
# 158:	learn: 0.1969107	total: 1.07s	remaining: 20.2ms
# 159:	learn: 0.1968635	total: 1.08s	remaining: 13.5ms
# 160:	learn: 0.1966604	total: 1.09s	remaining: 6.75ms
# 161:	learn: 0.1959304	total: 1.09s	remaining: 0us
# 0:	learn: 0.4447946	total: 110ms	remaining: 20.5s
# 1:	learn: 0.3519492	total: 213ms	remaining: 19.8s
# 2:	learn: 0.3182496	total: 315ms	remaining: 19.4s
# 3:	learn: 0.2967783	total: 416ms	remaining: 19.1s
# 4:	learn: 0.2768284	total: 519ms	remaining: 19s
# 5:	learn: 0.2632703	total: 620ms	remaining: 18.8s
# 6:	learn: 0.2551955	total: 727ms	remaining: 18.8s
# 7:	learn: 0.2493123	total: 828ms	remaining: 18.6s
# 8:	learn: 0.2432822	total: 933ms	remaining: 18.5s
# 9:	learn: 0.2367855	total: 1.03s	remaining: 18.4s
# 10:	learn: 0.2298648	total: 1.14s	remaining: 18.3s
# 11:	learn: 0.2256483	total: 1.24s	remaining: 18.2s
# 12:	learn: 0.2212315	total: 1.34s	remaining: 18.1s
# 13:	learn: 0.2175370	total: 1.45s	remaining: 18s
# 14:	learn: 0.2132068	total: 1.55s	remaining: 17.9s
# 15:	learn: 0.2095059	total: 1.66s	remaining: 17.8s
# 16:	learn: 0.2055879	total: 1.76s	remaining: 17.7s
# 17:	learn: 0.2028236	total: 1.86s	remaining: 17.6s
# 18:	learn: 0.1998673	total: 1.96s	remaining: 17.5s
# 19:	learn: 0.1973674	total: 2.06s	remaining: 17.3s
# 20:	learn: 0.1952923	total: 2.17s	remaining: 17.3s
# 21:	learn: 0.1926736	total: 2.27s	remaining: 17.1s
# 22:	learn: 0.1902399	total: 2.37s	remaining: 17s
# 23:	learn: 0.1888162	total: 2.47s	remaining: 16.9s
# 24:	learn: 0.1853469	total: 2.57s	remaining: 16.8s
# 25:	learn: 0.1822032	total: 2.67s	remaining: 16.7s
# 26:	learn: 0.1790040	total: 2.78s	remaining: 16.6s
# 27:	learn: 0.1773866	total: 2.88s	remaining: 16.5s
# 28:	learn: 0.1752517	total: 2.98s	remaining: 16.4s
# 29:	learn: 0.1745615	total: 3.08s	remaining: 16.2s
# 30:	learn: 0.1724716	total: 3.19s	remaining: 16.1s
# 31:	learn: 0.1697344	total: 3.3s	remaining: 16.1s
# 32:	learn: 0.1693318	total: 3.4s	remaining: 16s
# 33:	learn: 0.1679267	total: 3.5s	remaining: 15.9s
# 34:	learn: 0.1674583	total: 3.6s	remaining: 15.8s
# 35:	learn: 0.1654565	total: 3.71s	remaining: 15.6s
# 36:	learn: 0.1632533	total: 3.81s	remaining: 15.5s
# 37:	learn: 0.1612365	total: 3.91s	remaining: 15.4s
# 38:	learn: 0.1607155	total: 4.01s	remaining: 15.3s
# 39:	learn: 0.1588075	total: 4.11s	remaining: 15.2s
# 40:	learn: 0.1571129	total: 4.21s	remaining: 15.1s
# 41:	learn: 0.1548723	total: 4.32s	remaining: 15s
# 42:	learn: 0.1535158	total: 4.42s	remaining: 14.9s
# 43:	learn: 0.1517919	total: 4.52s	remaining: 14.8s
# 44:	learn: 0.1505645	total: 4.62s	remaining: 14.7s
# 45:	learn: 0.1485925	total: 4.72s	remaining: 14.6s
# 46:	learn: 0.1472915	total: 4.83s	remaining: 14.5s
# 47:	learn: 0.1469738	total: 4.92s	remaining: 14.4s
# 48:	learn: 0.1467904	total: 5.03s	remaining: 14.3s
# 49:	learn: 0.1458282	total: 5.13s	remaining: 14.2s
# 50:	learn: 0.1445890	total: 5.23s	remaining: 14.1s
# 51:	learn: 0.1443792	total: 5.33s	remaining: 14s
# 52:	learn: 0.1438352	total: 5.44s	remaining: 13.8s
# 53:	learn: 0.1435546	total: 5.54s	remaining: 13.8s
# 54:	learn: 0.1425144	total: 5.64s	remaining: 13.7s
# 55:	learn: 0.1422500	total: 5.74s	remaining: 13.5s
# 56:	learn: 0.1413036	total: 5.85s	remaining: 13.4s
# 57:	learn: 0.1400597	total: 5.95s	remaining: 13.3s
# 58:	learn: 0.1398382	total: 6.05s	remaining: 13.2s
# 59:	learn: 0.1386499	total: 6.15s	remaining: 13.1s
# 60:	learn: 0.1367688	total: 6.26s	remaining: 13s
# 61:	learn: 0.1356616	total: 6.36s	remaining: 12.9s
# 62:	learn: 0.1335824	total: 6.46s	remaining: 12.8s
# 63:	learn: 0.1318960	total: 6.57s	remaining: 12.7s
# 64:	learn: 0.1314433	total: 6.67s	remaining: 12.6s
# 65:	learn: 0.1299193	total: 6.77s	remaining: 12.5s
# 66:	learn: 0.1285242	total: 6.88s	remaining: 12.4s
# 67:	learn: 0.1283600	total: 6.98s	remaining: 12.3s
# 68:	learn: 0.1263833	total: 7.09s	remaining: 12.2s
# 69:	learn: 0.1252801	total: 7.19s	remaining: 12.1s
# 70:	learn: 0.1241245	total: 7.29s	remaining: 12s
# 71:	learn: 0.1229101	total: 7.39s	remaining: 11.9s
# 72:	learn: 0.1218319	total: 7.5s	remaining: 11.8s
# 73:	learn: 0.1203918	total: 7.6s	remaining: 11.7s
# 74:	learn: 0.1201315	total: 7.7s	remaining: 11.6s
# 75:	learn: 0.1196786	total: 7.81s	remaining: 11.5s
# 76:	learn: 0.1186349	total: 7.91s	remaining: 11.4s
# 77:	learn: 0.1176100	total: 8.02s	remaining: 11.3s
# 78:	learn: 0.1165348	total: 8.12s	remaining: 11.2s
# 79:	learn: 0.1146725	total: 8.22s	remaining: 11.1s
# 80:	learn: 0.1138053	total: 8.32s	remaining: 11s
# 81:	learn: 0.1127182	total: 8.43s	remaining: 10.9s
# 82:	learn: 0.1120370	total: 8.53s	remaining: 10.8s
# 83:	learn: 0.1112657	total: 8.63s	remaining: 10.7s
# 84:	learn: 0.1107395	total: 8.73s	remaining: 10.6s
# 85:	learn: 0.1094791	total: 8.84s	remaining: 10.5s
# 86:	learn: 0.1072588	total: 8.95s	remaining: 10.4s
# 87:	learn: 0.1059533	total: 9.05s	remaining: 10.3s
# 88:	learn: 0.1049029	total: 9.15s	remaining: 10.2s
# 89:	learn: 0.1046047	total: 9.26s	remaining: 10.1s
# 90:	learn: 0.1037634	total: 9.36s	remaining: 9.98s
# 91:	learn: 0.1027204	total: 9.46s	remaining: 9.88s
# 92:	learn: 0.1017206	total: 9.57s	remaining: 9.78s
# 93:	learn: 0.1007748	total: 9.68s	remaining: 9.68s
# 94:	learn: 0.0993631	total: 9.78s	remaining: 9.58s
# 95:	learn: 0.0985134	total: 9.88s	remaining: 9.47s
# 96:	learn: 0.0977663	total: 9.99s	remaining: 9.38s
# 97:	learn: 0.0969271	total: 10.1s	remaining: 9.28s
# 98:	learn: 0.0959178	total: 10.2s	remaining: 9.17s
# 99:	learn: 0.0952427	total: 10.3s	remaining: 9.07s
# 100:	learn: 0.0940845	total: 10.4s	remaining: 8.96s
# 101:	learn: 0.0932872	total: 10.5s	remaining: 8.86s
# 102:	learn: 0.0919951	total: 10.6s	remaining: 8.76s
# 103:	learn: 0.0912014	total: 10.7s	remaining: 8.65s
# 104:	learn: 0.0905332	total: 10.8s	remaining: 8.55s
# 105:	learn: 0.0899824	total: 10.9s	remaining: 8.45s
# 106:	learn: 0.0895771	total: 11s	remaining: 8.34s
# 107:	learn: 0.0891068	total: 11.1s	remaining: 8.24s
# 108:	learn: 0.0885196	total: 11.2s	remaining: 8.14s
# 109:	learn: 0.0878331	total: 11.3s	remaining: 8.04s
# 110:	learn: 0.0874192	total: 11.4s	remaining: 7.94s
# 111:	learn: 0.0867217	total: 11.6s	remaining: 7.84s
# 112:	learn: 0.0862609	total: 11.7s	remaining: 7.73s
# 113:	learn: 0.0857702	total: 11.8s	remaining: 7.63s
# 114:	learn: 0.0853439	total: 11.9s	remaining: 7.53s
# 115:	learn: 0.0841294	total: 12s	remaining: 7.42s
# 116:	learn: 0.0833673	total: 12.1s	remaining: 7.32s
# 117:	learn: 0.0829488	total: 12.2s	remaining: 7.22s
# 118:	learn: 0.0822175	total: 12.3s	remaining: 7.11s
# 119:	learn: 0.0815812	total: 12.4s	remaining: 7.01s
# 120:	learn: 0.0810750	total: 12.5s	remaining: 6.9s
# 121:	learn: 0.0803129	total: 12.6s	remaining: 6.8s
# 122:	learn: 0.0795574	total: 12.7s	remaining: 6.7s
# 123:	learn: 0.0788850	total: 12.8s	remaining: 6.59s
# 124:	learn: 0.0782936	total: 12.9s	remaining: 6.49s
# 125:	learn: 0.0775617	total: 13s	remaining: 6.39s
# 126:	learn: 0.0768574	total: 13.1s	remaining: 6.28s
# 127:	learn: 0.0760725	total: 13.2s	remaining: 6.18s
# 128:	learn: 0.0752219	total: 13.3s	remaining: 6.08s
# 129:	learn: 0.0747917	total: 13.4s	remaining: 5.98s
# 130:	learn: 0.0744969	total: 13.5s	remaining: 5.88s
# 131:	learn: 0.0738217	total: 13.6s	remaining: 5.77s
# 132:	learn: 0.0732369	total: 13.7s	remaining: 5.67s
# 133:	learn: 0.0729297	total: 13.8s	remaining: 5.57s
# 134:	learn: 0.0721722	total: 13.9s	remaining: 5.47s
# 135:	learn: 0.0716704	total: 14s	remaining: 5.36s
# 136:	learn: 0.0714678	total: 14.1s	remaining: 5.26s
# 137:	learn: 0.0708014	total: 14.2s	remaining: 5.16s
# 138:	learn: 0.0703074	total: 14.3s	remaining: 5.05s
# 139:	learn: 0.0700720	total: 14.4s	remaining: 4.95s
# 140:	learn: 0.0698427	total: 14.5s	remaining: 4.85s
# 141:	learn: 0.0692033	total: 14.6s	remaining: 4.74s
# 142:	learn: 0.0690512	total: 14.7s	remaining: 4.64s
# 143:	learn: 0.0688276	total: 14.8s	remaining: 4.54s
# 144:	learn: 0.0685096	total: 14.9s	remaining: 4.43s
# 145:	learn: 0.0680206	total: 15.1s	remaining: 4.33s
# 146:	learn: 0.0677218	total: 15.2s	remaining: 4.23s
# 147:	learn: 0.0674259	total: 15.3s	remaining: 4.12s
# 148:	learn: 0.0669574	total: 15.4s	remaining: 4.02s
# 149:	learn: 0.0665971	total: 15.5s	remaining: 3.92s
# 150:	learn: 0.0661068	total: 15.6s	remaining: 3.81s
# 151:	learn: 0.0659701	total: 15.7s	remaining: 3.71s
# 152:	learn: 0.0653717	total: 15.8s	remaining: 3.61s
# 153:	learn: 0.0648411	total: 15.9s	remaining: 3.5s
# 154:	learn: 0.0643766	total: 16s	remaining: 3.4s
# 155:	learn: 0.0639773	total: 16.1s	remaining: 3.3s
# 156:	learn: 0.0636382	total: 16.2s	remaining: 3.2s
# 157:	learn: 0.0634995	total: 16.3s	remaining: 3.09s
# 158:	learn: 0.0633241	total: 16.4s	remaining: 2.99s
# 159:	learn: 0.0625882	total: 16.5s	remaining: 2.89s
# 160:	learn: 0.0621839	total: 16.6s	remaining: 2.79s
# 161:	learn: 0.0616640	total: 16.7s	remaining: 2.68s
# 162:	learn: 0.0610999	total: 16.8s	remaining: 2.58s
# 163:	learn: 0.0608144	total: 16.9s	remaining: 2.48s
# 164:	learn: 0.0604464	total: 17s	remaining: 2.37s
# 165:	learn: 0.0600813	total: 17.1s	remaining: 2.27s
# 166:	learn: 0.0595765	total: 17.2s	remaining: 2.17s
# 167:	learn: 0.0592132	total: 17.3s	remaining: 2.06s
# 168:	learn: 0.0587635	total: 17.4s	remaining: 1.96s
# 169:	learn: 0.0582727	total: 17.5s	remaining: 1.86s
# 170:	learn: 0.0578079	total: 17.6s	remaining: 1.75s
# 171:	learn: 0.0573585	total: 17.7s	remaining: 1.65s
# 172:	learn: 0.0570280	total: 17.9s	remaining: 1.55s
# 173:	learn: 0.0567161	total: 18s	remaining: 1.44s
# 174:	learn: 0.0563856	total: 18.1s	remaining: 1.34s
# 175:	learn: 0.0560188	total: 18.2s	remaining: 1.24s
# 176:	learn: 0.0558611	total: 18.3s	remaining: 1.14s
# 177:	learn: 0.0555115	total: 18.4s	remaining: 1.03s
# 178:	learn: 0.0554032	total: 18.5s	remaining: 929ms
# 179:	learn: 0.0549114	total: 18.6s	remaining: 826ms
# 180:	learn: 0.0546602	total: 18.7s	remaining: 722ms
# 181:	learn: 0.0543223	total: 18.8s	remaining: 619ms
# 182:	learn: 0.0540717	total: 18.9s	remaining: 516ms
# 183:	learn: 0.0538701	total: 19s	remaining: 413ms
# 184:	learn: 0.0536258	total: 19.1s	remaining: 310ms
# 185:	learn: 0.0532280	total: 19.2s	remaining: 206ms
# 186:	learn: 0.0529639	total: 19.3s	remaining: 103ms
# 187:	learn: 0.0526156	total: 19.4s	remaining: 0us
# 0:	learn: 0.5760734	total: 56.6ms	remaining: 16.8s
# 1:	learn: 0.4890979	total: 95ms	remaining: 14.1s
# 2:	learn: 0.4272668	total: 133ms	remaining: 13.1s
# 3:	learn: 0.3868648	total: 171ms	remaining: 12.5s
# 4:	learn: 0.3535671	total: 212ms	remaining: 12.4s
# 5:	learn: 0.3416757	total: 250ms	remaining: 12.1s
# 6:	learn: 0.3242844	total: 290ms	remaining: 12.1s
# 7:	learn: 0.3119927	total: 329ms	remaining: 11.9s
# 8:	learn: 0.3001451	total: 368ms	remaining: 11.8s
# 9:	learn: 0.2899914	total: 408ms	remaining: 11.8s
# 10:	learn: 0.2821523	total: 446ms	remaining: 11.6s
# 11:	learn: 0.2761301	total: 487ms	remaining: 11.6s
# 12:	learn: 0.2704326	total: 530ms	remaining: 11.6s
# 13:	learn: 0.2656641	total: 574ms	remaining: 11.7s
# 14:	learn: 0.2612300	total: 614ms	remaining: 11.6s
# 15:	learn: 0.2570541	total: 654ms	remaining: 11.5s
# 16:	learn: 0.2528794	total: 694ms	remaining: 11.5s
# 17:	learn: 0.2496293	total: 736ms	remaining: 11.4s
# 18:	learn: 0.2459000	total: 774ms	remaining: 11.4s
# 19:	learn: 0.2433427	total: 815ms	remaining: 11.3s
# 20:	learn: 0.2406699	total: 854ms	remaining: 11.3s
# 21:	learn: 0.2385324	total: 894ms	remaining: 11.2s
# 22:	learn: 0.2361145	total: 932ms	remaining: 11.1s
# 23:	learn: 0.2336662	total: 971ms	remaining: 11.1s
# 24:	learn: 0.2313328	total: 1.01s	remaining: 11s
# 25:	learn: 0.2298465	total: 1.05s	remaining: 11s
# 26:	learn: 0.2278654	total: 1.09s	remaining: 10.9s
# 27:	learn: 0.2263038	total: 1.13s	remaining: 10.9s
# 28:	learn: 0.2258364	total: 1.16s	remaining: 10.8s
# 29:	learn: 0.2252808	total: 1.2s	remaining: 10.8s
# 30:	learn: 0.2238079	total: 1.24s	remaining: 10.7s
# 31:	learn: 0.2235388	total: 1.28s	remaining: 10.7s
# 32:	learn: 0.2216037	total: 1.32s	remaining: 10.6s
# 33:	learn: 0.2200441	total: 1.36s	remaining: 10.6s
# 34:	learn: 0.2188738	total: 1.4s	remaining: 10.5s
# 35:	learn: 0.2177472	total: 1.44s	remaining: 10.5s
# 36:	learn: 0.2171443	total: 1.48s	remaining: 10.5s
# 37:	learn: 0.2159219	total: 1.52s	remaining: 10.4s
# 38:	learn: 0.2142194	total: 1.56s	remaining: 10.4s
# 39:	learn: 0.2139231	total: 1.6s	remaining: 10.3s
# 40:	learn: 0.2135946	total: 1.64s	remaining: 10.3s
# 41:	learn: 0.2125802	total: 1.67s	remaining: 10.2s
# 42:	learn: 0.2114183	total: 1.71s	remaining: 10.2s
# 43:	learn: 0.2096732	total: 1.75s	remaining: 10.1s
# 44:	learn: 0.2086699	total: 1.79s	remaining: 10.1s
# 45:	learn: 0.2073999	total: 1.83s	remaining: 10s
# 46:	learn: 0.2061187	total: 1.88s	remaining: 10s
# 47:	learn: 0.2050316	total: 1.92s	remaining: 10s
# 48:	learn: 0.2046835	total: 1.96s	remaining: 9.95s
# 49:	learn: 0.2038127	total: 2s	remaining: 9.91s
# 50:	learn: 0.2028974	total: 2.04s	remaining: 9.86s
# 51:	learn: 0.2027728	total: 2.07s	remaining: 9.81s
# 52:	learn: 0.2024790	total: 2.11s	remaining: 9.77s
# 53:	learn: 0.2020126	total: 2.16s	remaining: 9.78s
# 54:	learn: 0.2012387	total: 2.2s	remaining: 9.73s
# 55:	learn: 0.1999288	total: 2.24s	remaining: 9.69s
# 56:	learn: 0.1992577	total: 2.28s	remaining: 9.64s
# 57:	learn: 0.1984730	total: 2.32s	remaining: 9.59s
# 58:	learn: 0.1983650	total: 2.36s	remaining: 9.57s
# 59:	learn: 0.1981862	total: 2.4s	remaining: 9.52s
# 60:	learn: 0.1980899	total: 2.44s	remaining: 9.47s
# 61:	learn: 0.1979311	total: 2.48s	remaining: 9.44s
# 62:	learn: 0.1978009	total: 2.52s	remaining: 9.4s
# 63:	learn: 0.1975983	total: 2.56s	remaining: 9.35s
# 64:	learn: 0.1975094	total: 2.6s	remaining: 9.31s
# 65:	learn: 0.1965350	total: 2.63s	remaining: 9.27s
# 66:	learn: 0.1963023	total: 2.68s	remaining: 9.24s
# 67:	learn: 0.1959721	total: 2.73s	remaining: 9.23s
# 68:	learn: 0.1948454	total: 2.77s	remaining: 9.2s
# 69:	learn: 0.1947668	total: 2.81s	remaining: 9.15s
# 70:	learn: 0.1946996	total: 2.85s	remaining: 9.11s
# 71:	learn: 0.1945871	total: 2.88s	remaining: 9.06s
# 72:	learn: 0.1944808	total: 2.92s	remaining: 9.02s
# 73:	learn: 0.1944085	total: 2.96s	remaining: 8.97s
# 74:	learn: 0.1942838	total: 3s	remaining: 8.93s
# 75:	learn: 0.1942166	total: 3.04s	remaining: 8.89s
# 76:	learn: 0.1941330	total: 3.08s	remaining: 8.84s
# 77:	learn: 0.1940675	total: 3.12s	remaining: 8.81s
# 78:	learn: 0.1939968	total: 3.16s	remaining: 8.76s
# 79:	learn: 0.1936926	total: 3.2s	remaining: 8.71s
# 80:	learn: 0.1930447	total: 3.24s	remaining: 8.67s
# 81:	learn: 0.1929963	total: 3.27s	remaining: 8.63s
# 82:	learn: 0.1923786	total: 3.31s	remaining: 8.59s
# 83:	learn: 0.1918354	total: 3.35s	remaining: 8.54s
# 84:	learn: 0.1917867	total: 3.4s	remaining: 8.52s
# 85:	learn: 0.1917143	total: 3.44s	remaining: 8.48s
# 86:	learn: 0.1916809	total: 3.48s	remaining: 8.44s
# 87:	learn: 0.1916175	total: 3.52s	remaining: 8.39s
# 88:	learn: 0.1910919	total: 3.55s	remaining: 8.35s
# 89:	learn: 0.1901270	total: 3.59s	remaining: 8.3s
# 90:	learn: 0.1900657	total: 3.63s	remaining: 8.26s
# 91:	learn: 0.1889595	total: 3.67s	remaining: 8.22s
# 92:	learn: 0.1886840	total: 3.71s	remaining: 8.18s
# 93:	learn: 0.1886401	total: 3.75s	remaining: 8.14s
# 94:	learn: 0.1882902	total: 3.79s	remaining: 8.1s
# 95:	learn: 0.1872556	total: 3.83s	remaining: 8.06s
# 96:	learn: 0.1867465	total: 3.87s	remaining: 8.02s
# 97:	learn: 0.1866891	total: 3.91s	remaining: 7.98s
# 98:	learn: 0.1866324	total: 3.95s	remaining: 7.94s
# 99:	learn: 0.1866057	total: 3.99s	remaining: 7.89s
# 100:	learn: 0.1861221	total: 4.03s	remaining: 7.85s
# 101:	learn: 0.1856621	total: 4.06s	remaining: 7.81s
# 102:	learn: 0.1855485	total: 4.1s	remaining: 7.77s
# 103:	learn: 0.1847143	total: 4.14s	remaining: 7.73s
# 104:	learn: 0.1842554	total: 4.18s	remaining: 7.69s
# 105:	learn: 0.1840085	total: 4.22s	remaining: 7.64s
# 106:	learn: 0.1839813	total: 4.26s	remaining: 7.6s
# 107:	learn: 0.1839424	total: 4.3s	remaining: 7.56s
# 108:	learn: 0.1834564	total: 4.34s	remaining: 7.52s
# 109:	learn: 0.1824780	total: 4.38s	remaining: 7.48s
# 110:	learn: 0.1819542	total: 4.42s	remaining: 7.44s
# 111:	learn: 0.1814732	total: 4.46s	remaining: 7.4s
# 112:	learn: 0.1814518	total: 4.5s	remaining: 7.36s
# 113:	learn: 0.1814122	total: 4.54s	remaining: 7.32s
# 114:	learn: 0.1808454	total: 4.58s	remaining: 7.28s
# 115:	learn: 0.1804646	total: 4.62s	remaining: 7.24s
# 116:	learn: 0.1797363	total: 4.66s	remaining: 7.21s
# 117:	learn: 0.1789980	total: 4.7s	remaining: 7.16s
# 118:	learn: 0.1785268	total: 4.74s	remaining: 7.12s
# 119:	learn: 0.1781256	total: 4.78s	remaining: 7.09s
# 120:	learn: 0.1780831	total: 4.82s	remaining: 7.05s
# 121:	learn: 0.1779784	total: 4.86s	remaining: 7s
# 122:	learn: 0.1778940	total: 4.9s	remaining: 6.97s
# 123:	learn: 0.1774024	total: 4.94s	remaining: 6.93s
# 124:	learn: 0.1768097	total: 4.98s	remaining: 6.89s
# 125:	learn: 0.1767594	total: 5.02s	remaining: 6.85s
# 126:	learn: 0.1767193	total: 5.06s	remaining: 6.81s
# 127:	learn: 0.1766652	total: 5.1s	remaining: 6.77s
# 128:	learn: 0.1760971	total: 5.13s	remaining: 6.73s
# 129:	learn: 0.1760497	total: 5.17s	remaining: 6.69s
# 130:	learn: 0.1759996	total: 5.21s	remaining: 6.65s
# 131:	learn: 0.1755615	total: 5.25s	remaining: 6.61s
# 132:	learn: 0.1754997	total: 5.29s	remaining: 6.57s
# 133:	learn: 0.1753360	total: 5.33s	remaining: 6.53s
# 134:	learn: 0.1752994	total: 5.37s	remaining: 6.49s
# 135:	learn: 0.1752599	total: 5.41s	remaining: 6.45s
# 136:	learn: 0.1745352	total: 5.45s	remaining: 6.41s
# 137:	learn: 0.1739445	total: 5.49s	remaining: 6.37s
# 138:	learn: 0.1738834	total: 5.53s	remaining: 6.32s
# 139:	learn: 0.1730835	total: 5.57s	remaining: 6.28s
# 140:	learn: 0.1730105	total: 5.61s	remaining: 6.24s
# 141:	learn: 0.1726217	total: 5.64s	remaining: 6.2s
# 142:	learn: 0.1721225	total: 5.68s	remaining: 6.16s
# 143:	learn: 0.1720821	total: 5.73s	remaining: 6.12s
# 144:	learn: 0.1716424	total: 5.77s	remaining: 6.08s
# 145:	learn: 0.1707931	total: 5.8s	remaining: 6.04s
# 146:	learn: 0.1706404	total: 5.84s	remaining: 6s
# 147:	learn: 0.1704999	total: 5.88s	remaining: 5.96s
# 148:	learn: 0.1700104	total: 5.92s	remaining: 5.92s
# 149:	learn: 0.1692958	total: 5.96s	remaining: 5.88s
# 150:	learn: 0.1683026	total: 6s	remaining: 5.84s
# 151:	learn: 0.1682579	total: 6.04s	remaining: 5.8s
# 152:	learn: 0.1681851	total: 6.08s	remaining: 5.76s
# 153:	learn: 0.1681465	total: 6.13s	remaining: 5.73s
# 154:	learn: 0.1680843	total: 6.16s	remaining: 5.69s
# 155:	learn: 0.1679292	total: 6.2s	remaining: 5.65s
# 156:	learn: 0.1678830	total: 6.24s	remaining: 5.6s
# 157:	learn: 0.1678622	total: 6.28s	remaining: 5.57s
# 158:	learn: 0.1678091	total: 6.32s	remaining: 5.52s
# 159:	learn: 0.1677579	total: 6.36s	remaining: 5.49s
# 160:	learn: 0.1677195	total: 6.4s	remaining: 5.45s
# 161:	learn: 0.1667315	total: 6.44s	remaining: 5.41s
# 162:	learn: 0.1666887	total: 6.48s	remaining: 5.37s
# 163:	learn: 0.1666160	total: 6.52s	remaining: 5.33s
# 164:	learn: 0.1665840	total: 6.56s	remaining: 5.29s
# 165:	learn: 0.1656316	total: 6.6s	remaining: 5.25s
# 166:	learn: 0.1656112	total: 6.64s	remaining: 5.21s
# 167:	learn: 0.1655773	total: 6.68s	remaining: 5.17s
# 168:	learn: 0.1655111	total: 6.71s	remaining: 5.13s
# 169:	learn: 0.1649038	total: 6.75s	remaining: 5.08s
# 170:	learn: 0.1646384	total: 6.8s	remaining: 5.05s
# 171:	learn: 0.1641031	total: 6.83s	remaining: 5s
# 172:	learn: 0.1640798	total: 6.87s	remaining: 4.96s
# 173:	learn: 0.1640479	total: 6.91s	remaining: 4.92s
# 174:	learn: 0.1640050	total: 6.95s	remaining: 4.88s
# 175:	learn: 0.1639888	total: 6.99s	remaining: 4.84s
# 176:	learn: 0.1638417	total: 7.03s	remaining: 4.8s
# 177:	learn: 0.1632237	total: 7.07s	remaining: 4.76s
# 178:	learn: 0.1632183	total: 7.11s	remaining: 4.72s
# 179:	learn: 0.1632084	total: 7.15s	remaining: 4.68s
# 180:	learn: 0.1623418	total: 7.18s	remaining: 4.64s
# 181:	learn: 0.1622860	total: 7.22s	remaining: 4.6s
# 182:	learn: 0.1622647	total: 7.26s	remaining: 4.56s
# 183:	learn: 0.1620575	total: 7.3s	remaining: 4.52s
# 184:	learn: 0.1620488	total: 7.34s	remaining: 4.48s
# 185:	learn: 0.1620099	total: 7.38s	remaining: 4.44s
# 186:	learn: 0.1620079	total: 7.42s	remaining: 4.4s
# 187:	learn: 0.1619761	total: 7.46s	remaining: 4.37s
# 188:	learn: 0.1614297	total: 7.5s	remaining: 4.32s
# 189:	learn: 0.1614274	total: 7.54s	remaining: 4.29s
# 190:	learn: 0.1612831	total: 7.58s	remaining: 4.25s
# 191:	learn: 0.1607379	total: 7.62s	remaining: 4.2s
# 192:	learn: 0.1607088	total: 7.65s	remaining: 4.16s
# 193:	learn: 0.1607070	total: 7.68s	remaining: 4.12s
# 194:	learn: 0.1600314	total: 7.72s	remaining: 4.08s
# 195:	learn: 0.1600307	total: 7.76s	remaining: 4.04s
# 196:	learn: 0.1598335	total: 7.8s	remaining: 4s
# 197:	learn: 0.1598283	total: 7.84s	remaining: 3.96s
# 198:	learn: 0.1598213	total: 7.88s	remaining: 3.92s
# 199:	learn: 0.1598194	total: 7.92s	remaining: 3.88s
# 200:	learn: 0.1597974	total: 7.96s	remaining: 3.84s
# 201:	learn: 0.1597871	total: 8s	remaining: 3.8s
# 202:	learn: 0.1593647	total: 8.04s	remaining: 3.76s
# 203:	learn: 0.1593594	total: 8.08s	remaining: 3.72s
# 204:	learn: 0.1593542	total: 8.12s	remaining: 3.68s
# 205:	learn: 0.1587313	total: 8.16s	remaining: 3.64s
# 206:	learn: 0.1587260	total: 8.2s	remaining: 3.6s
# 207:	learn: 0.1587241	total: 8.24s	remaining: 3.56s
# 208:	learn: 0.1587222	total: 8.28s	remaining: 3.52s
# 209:	learn: 0.1582953	total: 8.31s	remaining: 3.48s
# 210:	learn: 0.1580965	total: 8.35s	remaining: 3.44s
# 211:	learn: 0.1578601	total: 8.39s	remaining: 3.4s
# 212:	learn: 0.1578532	total: 8.43s	remaining: 3.36s
# 213:	learn: 0.1578434	total: 8.47s	remaining: 3.33s
# 214:	learn: 0.1578385	total: 8.51s	remaining: 3.29s
# 215:	learn: 0.1578329	total: 8.55s	remaining: 3.25s
# 216:	learn: 0.1577109	total: 8.6s	remaining: 3.21s
# 217:	learn: 0.1577042	total: 8.64s	remaining: 3.17s
# 218:	learn: 0.1572912	total: 8.68s	remaining: 3.13s
# 219:	learn: 0.1572894	total: 8.71s	remaining: 3.09s
# 220:	learn: 0.1572855	total: 8.75s	remaining: 3.05s
# 221:	learn: 0.1572819	total: 8.79s	remaining: 3.01s
# 222:	learn: 0.1572767	total: 8.82s	remaining: 2.97s
# 223:	learn: 0.1572751	total: 8.85s	remaining: 2.92s
# 224:	learn: 0.1572721	total: 8.89s	remaining: 2.88s
# 225:	learn: 0.1572662	total: 8.93s	remaining: 2.85s
# 226:	learn: 0.1572618	total: 8.97s	remaining: 2.81s
# 227:	learn: 0.1572601	total: 9.01s	remaining: 2.77s
# 228:	learn: 0.1572550	total: 9.05s	remaining: 2.73s
# 229:	learn: 0.1572533	total: 9.09s	remaining: 2.69s
# 230:	learn: 0.1572518	total: 9.13s	remaining: 2.65s
# 231:	learn: 0.1572454	total: 9.16s	remaining: 2.61s
# 232:	learn: 0.1572389	total: 9.2s	remaining: 2.57s
# 233:	learn: 0.1572342	total: 9.24s	remaining: 2.53s
# 234:	learn: 0.1572291	total: 9.28s	remaining: 2.49s
# 235:	learn: 0.1572255	total: 9.32s	remaining: 2.45s
# 236:	learn: 0.1572238	total: 9.36s	remaining: 2.41s
# 237:	learn: 0.1572221	total: 9.39s	remaining: 2.37s
# 238:	learn: 0.1572157	total: 9.43s	remaining: 2.33s
# 239:	learn: 0.1572094	total: 9.47s	remaining: 2.29s
# 240:	learn: 0.1566052	total: 9.5s	remaining: 2.25s
# 241:	learn: 0.1566020	total: 9.54s	remaining: 2.21s
# 242:	learn: 0.1565755	total: 9.59s	remaining: 2.17s
# 243:	learn: 0.1565715	total: 9.62s	remaining: 2.13s
# 244:	learn: 0.1565687	total: 9.66s	remaining: 2.09s
# 245:	learn: 0.1565484	total: 9.71s	remaining: 2.05s
# 246:	learn: 0.1565430	total: 9.75s	remaining: 2.01s
# 247:	learn: 0.1565350	total: 9.78s	remaining: 1.97s
# 248:	learn: 0.1565187	total: 9.82s	remaining: 1.93s
# 249:	learn: 0.1565169	total: 9.86s	remaining: 1.89s
# 250:	learn: 0.1564980	total: 9.9s	remaining: 1.85s
# 251:	learn: 0.1564918	total: 9.94s	remaining: 1.81s
# 252:	learn: 0.1564906	total: 9.97s	remaining: 1.77s
# 253:	learn: 0.1564856	total: 10s	remaining: 1.73s
# 254:	learn: 0.1564803	total: 10s	remaining: 1.69s
# 255:	learn: 0.1564770	total: 10.1s	remaining: 1.65s
# 256:	learn: 0.1564505	total: 10.1s	remaining: 1.61s
# 257:	learn: 0.1560847	total: 10.2s	remaining: 1.58s
# 258:	learn: 0.1560787	total: 10.2s	remaining: 1.54s
# 259:	learn: 0.1560695	total: 10.2s	remaining: 1.5s
# 260:	learn: 0.1560584	total: 10.3s	remaining: 1.46s
# 261:	learn: 0.1560568	total: 10.3s	remaining: 1.42s
# 262:	learn: 0.1555706	total: 10.4s	remaining: 1.38s
# 263:	learn: 0.1555687	total: 10.4s	remaining: 1.34s
# 264:	learn: 0.1555668	total: 10.4s	remaining: 1.3s
# 265:	learn: 0.1555628	total: 10.5s	remaining: 1.26s
# 266:	learn: 0.1555277	total: 10.5s	remaining: 1.22s
# 267:	learn: 0.1555229	total: 10.6s	remaining: 1.18s
# 268:	learn: 0.1555213	total: 10.6s	remaining: 1.14s
# 269:	learn: 0.1553336	total: 10.6s	remaining: 1.1s
# 270:	learn: 0.1548026	total: 10.7s	remaining: 1.06s
# 271:	learn: 0.1547306	total: 10.7s	remaining: 1.02s
# 272:	learn: 0.1546971	total: 10.8s	remaining: 986ms
# 273:	learn: 0.1546633	total: 10.8s	remaining: 947ms
# 274:	learn: 0.1545372	total: 10.8s	remaining: 907ms
# 275:	learn: 0.1545136	total: 10.9s	remaining: 868ms
# 276:	learn: 0.1543190	total: 10.9s	remaining: 829ms
# 277:	learn: 0.1536023	total: 11s	remaining: 789ms
# 278:	learn: 0.1531467	total: 11s	remaining: 750ms
# 279:	learn: 0.1523944	total: 11.1s	remaining: 710ms
# 280:	learn: 0.1518874	total: 11.1s	remaining: 671ms
# 281:	learn: 0.1518389	total: 11.1s	remaining: 632ms
# 282:	learn: 0.1517825	total: 11.2s	remaining: 592ms
# 283:	learn: 0.1517492	total: 11.2s	remaining: 553ms
# 284:	learn: 0.1517047	total: 11.3s	remaining: 513ms
# 285:	learn: 0.1514642	total: 11.3s	remaining: 474ms
# 286:	learn: 0.1514382	total: 11.3s	remaining: 434ms
# 287:	learn: 0.1514079	total: 11.4s	remaining: 395ms
# 288:	learn: 0.1513691	total: 11.4s	remaining: 356ms
# 289:	learn: 0.1513371	total: 11.5s	remaining: 316ms
# 290:	learn: 0.1505251	total: 11.5s	remaining: 276ms
# 291:	learn: 0.1504884	total: 11.5s	remaining: 237ms
# 292:	learn: 0.1498862	total: 11.6s	remaining: 197ms
# 293:	learn: 0.1494357	total: 11.6s	remaining: 158ms
# 294:	learn: 0.1493170	total: 11.7s	remaining: 118ms
# 295:	learn: 0.1487726	total: 11.7s	remaining: 79ms
# 296:	learn: 0.1487527	total: 11.7s	remaining: 39.5ms
# 297:	learn: 0.1480949	total: 11.8s	remaining: 0us
# 0:	learn: 0.5371962	total: 48ms	remaining: 3.79s
# 1:	learn: 0.4539448	total: 78.6ms	remaining: 3.07s
# 2:	learn: 0.3938078	total: 109ms	remaining: 2.8s
# 3:	learn: 0.3544713	total: 139ms	remaining: 2.65s
# 4:	learn: 0.3294751	total: 169ms	remaining: 2.53s
# 5:	learn: 0.3127777	total: 199ms	remaining: 2.46s
# 6:	learn: 0.2975694	total: 229ms	remaining: 2.38s
# 7:	learn: 0.2866501	total: 259ms	remaining: 2.33s
# 8:	learn: 0.2759679	total: 289ms	remaining: 2.28s
# 9:	learn: 0.2698562	total: 319ms	remaining: 2.23s
# 10:	learn: 0.2632342	total: 349ms	remaining: 2.19s
# 11:	learn: 0.2563083	total: 379ms	remaining: 2.15s
# 12:	learn: 0.2530953	total: 410ms	remaining: 2.12s
# 13:	learn: 0.2488323	total: 440ms	remaining: 2.07s
# 14:	learn: 0.2449207	total: 470ms	remaining: 2.04s
# 15:	learn: 0.2406549	total: 500ms	remaining: 2s
# 16:	learn: 0.2371990	total: 529ms	remaining: 1.96s
# 17:	learn: 0.2340293	total: 559ms	remaining: 1.93s
# 18:	learn: 0.2333619	total: 595ms	remaining: 1.91s
# 19:	learn: 0.2313258	total: 624ms	remaining: 1.87s
# 20:	learn: 0.2304298	total: 654ms	remaining: 1.84s
# 21:	learn: 0.2284524	total: 683ms	remaining: 1.8s
# 22:	learn: 0.2264640	total: 713ms	remaining: 1.77s
# 23:	learn: 0.2240392	total: 750ms	remaining: 1.75s
# 24:	learn: 0.2236821	total: 781ms	remaining: 1.72s
# 25:	learn: 0.2233801	total: 812ms	remaining: 1.69s
# 26:	learn: 0.2231563	total: 842ms	remaining: 1.65s
# 27:	learn: 0.2211555	total: 872ms	remaining: 1.62s
# 28:	learn: 0.2209132	total: 903ms	remaining: 1.59s
# 29:	learn: 0.2184069	total: 932ms	remaining: 1.55s
# 30:	learn: 0.2170662	total: 963ms	remaining: 1.52s
# 31:	learn: 0.2168967	total: 992ms	remaining: 1.49s
# 32:	learn: 0.2154423	total: 1.03s	remaining: 1.47s
# 33:	learn: 0.2142372	total: 1.06s	remaining: 1.44s
# 34:	learn: 0.2140745	total: 1.09s	remaining: 1.4s
# 35:	learn: 0.2120119	total: 1.12s	remaining: 1.37s
# 36:	learn: 0.2118355	total: 1.15s	remaining: 1.34s
# 37:	learn: 0.2103125	total: 1.18s	remaining: 1.3s
# 38:	learn: 0.2098155	total: 1.21s	remaining: 1.27s
# 39:	learn: 0.2087143	total: 1.24s	remaining: 1.24s
# 40:	learn: 0.2082371	total: 1.28s	remaining: 1.22s
# 41:	learn: 0.2078397	total: 1.31s	remaining: 1.19s
# 42:	learn: 0.2058961	total: 1.34s	remaining: 1.15s
# 43:	learn: 0.2054864	total: 1.37s	remaining: 1.12s
# 44:	learn: 0.2053447	total: 1.4s	remaining: 1.09s
# 45:	learn: 0.2052018	total: 1.43s	remaining: 1.06s
# 46:	learn: 0.2035770	total: 1.46s	remaining: 1.02s
# 47:	learn: 0.2033448	total: 1.49s	remaining: 994ms
# 48:	learn: 0.2032945	total: 1.53s	remaining: 967ms
# 49:	learn: 0.2032608	total: 1.56s	remaining: 935ms
# 50:	learn: 0.2032108	total: 1.59s	remaining: 904ms
# 51:	learn: 0.2031656	total: 1.62s	remaining: 872ms
# 52:	learn: 0.2024404	total: 1.65s	remaining: 841ms
# 53:	learn: 0.2024246	total: 1.68s	remaining: 810ms
# 54:	learn: 0.2023473	total: 1.71s	remaining: 778ms
# 55:	learn: 0.2023396	total: 1.74s	remaining: 747ms
# 56:	learn: 0.2023316	total: 1.77s	remaining: 715ms
# 57:	learn: 0.2023092	total: 1.8s	remaining: 684ms
# 58:	learn: 0.2022750	total: 1.83s	remaining: 653ms
# 59:	learn: 0.2001122	total: 1.86s	remaining: 621ms
# 60:	learn: 0.1999958	total: 1.89s	remaining: 590ms
# 61:	learn: 0.1998942	total: 1.92s	remaining: 559ms
# 62:	learn: 0.1997061	total: 1.95s	remaining: 527ms
# 63:	learn: 0.1978939	total: 1.98s	remaining: 496ms
# 64:	learn: 0.1966741	total: 2.02s	remaining: 465ms
# 65:	learn: 0.1966524	total: 2.04s	remaining: 434ms
# 66:	learn: 0.1966187	total: 2.07s	remaining: 403ms
# 67:	learn: 0.1965975	total: 2.1s	remaining: 371ms
# 68:	learn: 0.1965896	total: 2.13s	remaining: 340ms
# 69:	learn: 0.1965707	total: 2.16s	remaining: 309ms
# 70:	learn: 0.1965494	total: 2.2s	remaining: 279ms
# 71:	learn: 0.1965123	total: 2.23s	remaining: 248ms
# 72:	learn: 0.1950987	total: 2.26s	remaining: 217ms
# 73:	learn: 0.1950912	total: 2.29s	remaining: 186ms
# 74:	learn: 0.1948257	total: 2.32s	remaining: 155ms
# 75:	learn: 0.1947505	total: 2.35s	remaining: 124ms
# 76:	learn: 0.1942737	total: 2.38s	remaining: 92.8ms
# 77:	learn: 0.1942537	total: 2.41s	remaining: 61.8ms
# 78:	learn: 0.1942168	total: 2.44s	remaining: 30.9ms
# 79:	learn: 0.1939998	total: 2.47s	remaining: 0us
# 0:	learn: 0.4073520	total: 34.5ms	remaining: 7.7s
# 1:	learn: 0.3301443	total: 55.4ms	remaining: 6.15s
# 2:	learn: 0.3026086	total: 75ms	remaining: 5.53s
# 3:	learn: 0.2844579	total: 94.4ms	remaining: 5.19s
# 4:	learn: 0.2716285	total: 114ms	remaining: 5s
# 5:	learn: 0.2611816	total: 134ms	remaining: 4.86s
# 6:	learn: 0.2563414	total: 153ms	remaining: 4.76s
# 7:	learn: 0.2541733	total: 173ms	remaining: 4.68s
# 8:	learn: 0.2481657	total: 193ms	remaining: 4.62s
# 9:	learn: 0.2450578	total: 213ms	remaining: 4.55s
# 10:	learn: 0.2398041	total: 232ms	remaining: 4.5s
# 11:	learn: 0.2362149	total: 252ms	remaining: 4.45s
# 12:	learn: 0.2317646	total: 272ms	remaining: 4.41s
# 13:	learn: 0.2282963	total: 292ms	remaining: 4.37s
# 14:	learn: 0.2269059	total: 313ms	remaining: 4.36s
# 15:	learn: 0.2252655	total: 333ms	remaining: 4.33s
# 16:	learn: 0.2200556	total: 353ms	remaining: 4.3s
# 17:	learn: 0.2158890	total: 372ms	remaining: 4.26s
# 18:	learn: 0.2155501	total: 392ms	remaining: 4.23s
# 19:	learn: 0.2154349	total: 412ms	remaining: 4.2s
# 20:	learn: 0.2153088	total: 437ms	remaining: 4.23s
# 21:	learn: 0.2151410	total: 458ms	remaining: 4.2s
# 22:	learn: 0.2145464	total: 478ms	remaining: 4.18s
# 23:	learn: 0.2115825	total: 497ms	remaining: 4.14s
# 24:	learn: 0.2090704	total: 517ms	remaining: 4.12s
# 25:	learn: 0.2085362	total: 537ms	remaining: 4.09s
# 26:	learn: 0.2076426	total: 557ms	remaining: 4.06s
# 27:	learn: 0.2074100	total: 577ms	remaining: 4.04s
# 28:	learn: 0.2058265	total: 598ms	remaining: 4.02s
# 29:	learn: 0.2055256	total: 618ms	remaining: 4s
# 30:	learn: 0.2051561	total: 639ms	remaining: 3.98s
# 31:	learn: 0.2046739	total: 659ms	remaining: 3.95s
# 32:	learn: 0.2046181	total: 680ms	remaining: 3.93s
# 33:	learn: 0.2045476	total: 700ms	remaining: 3.91s
# 34:	learn: 0.2044867	total: 721ms	remaining: 3.89s
# 35:	learn: 0.2024331	total: 741ms	remaining: 3.87s
# 36:	learn: 0.2023777	total: 761ms	remaining: 3.85s
# 37:	learn: 0.2022755	total: 784ms	remaining: 3.83s
# 38:	learn: 0.2021851	total: 804ms	remaining: 3.81s
# 39:	learn: 0.2021363	total: 823ms	remaining: 3.79s
# 40:	learn: 0.2020855	total: 843ms	remaining: 3.76s
# 41:	learn: 0.1989550	total: 864ms	remaining: 3.74s
# 42:	learn: 0.1988715	total: 884ms	remaining: 3.72s
# 43:	learn: 0.1955855	total: 903ms	remaining: 3.69s
# 44:	learn: 0.1949549	total: 925ms	remaining: 3.68s
# 45:	learn: 0.1936155	total: 944ms	remaining: 3.65s
# 46:	learn: 0.1932751	total: 971ms	remaining: 3.65s
# 47:	learn: 0.1925221	total: 990ms	remaining: 3.63s
# 48:	learn: 0.1917968	total: 1.01s	remaining: 3.61s
# 49:	learn: 0.1917163	total: 1.03s	remaining: 3.58s
# 50:	learn: 0.1916659	total: 1.05s	remaining: 3.56s
# 51:	learn: 0.1897336	total: 1.07s	remaining: 3.54s
# 52:	learn: 0.1892311	total: 1.09s	remaining: 3.52s
# 53:	learn: 0.1880959	total: 1.11s	remaining: 3.49s
# 54:	learn: 0.1879349	total: 1.13s	remaining: 3.48s
# 55:	learn: 0.1877206	total: 1.15s	remaining: 3.45s
# 56:	learn: 0.1857724	total: 1.17s	remaining: 3.43s
# 57:	learn: 0.1855054	total: 1.19s	remaining: 3.41s
# 58:	learn: 0.1843796	total: 1.21s	remaining: 3.39s
# 59:	learn: 0.1843618	total: 1.23s	remaining: 3.37s
# 60:	learn: 0.1842198	total: 1.25s	remaining: 3.35s
# 61:	learn: 0.1841751	total: 1.27s	remaining: 3.33s
# 62:	learn: 0.1841321	total: 1.29s	remaining: 3.3s
# 63:	learn: 0.1840622	total: 1.31s	remaining: 3.28s
# 64:	learn: 0.1822837	total: 1.33s	remaining: 3.26s
# 65:	learn: 0.1822238	total: 1.35s	remaining: 3.24s
# 66:	learn: 0.1801268	total: 1.37s	remaining: 3.22s
# 67:	learn: 0.1801043	total: 1.39s	remaining: 3.19s
# 68:	learn: 0.1800147	total: 1.41s	remaining: 3.17s
# 69:	learn: 0.1795192	total: 1.43s	remaining: 3.15s
# 70:	learn: 0.1762995	total: 1.45s	remaining: 3.13s
# 71:	learn: 0.1758641	total: 1.47s	remaining: 3.11s
# 72:	learn: 0.1752671	total: 1.5s	remaining: 3.1s
# 73:	learn: 0.1733472	total: 1.52s	remaining: 3.08s
# 74:	learn: 0.1726340	total: 1.54s	remaining: 3.05s
# 75:	learn: 0.1724509	total: 1.56s	remaining: 3.03s
# 76:	learn: 0.1715084	total: 1.58s	remaining: 3.01s
# 77:	learn: 0.1714999	total: 1.6s	remaining: 2.99s
# 78:	learn: 0.1714908	total: 1.62s	remaining: 2.97s
# 79:	learn: 0.1714732	total: 1.64s	remaining: 2.95s
# 80:	learn: 0.1693538	total: 1.66s	remaining: 2.93s
# 81:	learn: 0.1664795	total: 1.68s	remaining: 2.91s
# 82:	learn: 0.1653338	total: 1.7s	remaining: 2.88s
# 83:	learn: 0.1635077	total: 1.72s	remaining: 2.86s
# 84:	learn: 0.1632559	total: 1.74s	remaining: 2.84s
# 85:	learn: 0.1620980	total: 1.76s	remaining: 2.82s
# 86:	learn: 0.1620486	total: 1.78s	remaining: 2.8s
# 87:	learn: 0.1619452	total: 1.8s	remaining: 2.79s
# 88:	learn: 0.1618658	total: 1.82s	remaining: 2.77s
# 89:	learn: 0.1617817	total: 1.84s	remaining: 2.75s
# 90:	learn: 0.1617213	total: 1.86s	remaining: 2.72s
# 91:	learn: 0.1615856	total: 1.88s	remaining: 2.7s
# 92:	learn: 0.1615677	total: 1.91s	remaining: 2.68s
# 93:	learn: 0.1614447	total: 1.93s	remaining: 2.66s
# 94:	learn: 0.1613727	total: 1.95s	remaining: 2.64s
# 95:	learn: 0.1613552	total: 1.97s	remaining: 2.62s
# 96:	learn: 0.1613270	total: 1.99s	remaining: 2.6s
# 97:	learn: 0.1603132	total: 2s	remaining: 2.58s
# 98:	learn: 0.1601376	total: 2.03s	remaining: 2.56s
# 99:	learn: 0.1600688	total: 2.05s	remaining: 2.54s
# 100:	learn: 0.1599643	total: 2.06s	remaining: 2.52s
# 101:	learn: 0.1599475	total: 2.09s	remaining: 2.5s
# 102:	learn: 0.1598326	total: 2.11s	remaining: 2.47s
# 103:	learn: 0.1597906	total: 2.13s	remaining: 2.45s
# 104:	learn: 0.1597634	total: 2.15s	remaining: 2.43s
# 105:	learn: 0.1587130	total: 2.17s	remaining: 2.41s
# 106:	learn: 0.1587042	total: 2.19s	remaining: 2.39s
# 107:	learn: 0.1586869	total: 2.21s	remaining: 2.37s
# 108:	learn: 0.1586678	total: 2.23s	remaining: 2.35s
# 109:	learn: 0.1586591	total: 2.25s	remaining: 2.33s
# 110:	learn: 0.1586515	total: 2.27s	remaining: 2.31s
# 111:	learn: 0.1586436	total: 2.29s	remaining: 2.29s
# 112:	learn: 0.1586213	total: 2.31s	remaining: 2.26s
# 113:	learn: 0.1577970	total: 2.33s	remaining: 2.24s
# 114:	learn: 0.1576908	total: 2.35s	remaining: 2.22s
# 115:	learn: 0.1576723	total: 2.37s	remaining: 2.2s
# 116:	learn: 0.1576552	total: 2.39s	remaining: 2.18s
# 117:	learn: 0.1576368	total: 2.41s	remaining: 2.17s
# 118:	learn: 0.1576197	total: 2.43s	remaining: 2.15s
# 119:	learn: 0.1575793	total: 2.45s	remaining: 2.12s
# 120:	learn: 0.1575525	total: 2.47s	remaining: 2.1s
# 121:	learn: 0.1575358	total: 2.49s	remaining: 2.08s
# 122:	learn: 0.1574972	total: 2.51s	remaining: 2.06s
# 123:	learn: 0.1574805	total: 2.54s	remaining: 2.04s
# 124:	learn: 0.1574635	total: 2.56s	remaining: 2.02s
# 125:	learn: 0.1574161	total: 2.58s	remaining: 2s
# 126:	learn: 0.1573983	total: 2.59s	remaining: 1.98s
# 127:	learn: 0.1573826	total: 2.61s	remaining: 1.96s
# 128:	learn: 0.1570058	total: 2.63s	remaining: 1.94s
# 129:	learn: 0.1569972	total: 2.65s	remaining: 1.92s
# 130:	learn: 0.1569809	total: 2.67s	remaining: 1.9s
# 131:	learn: 0.1569737	total: 2.69s	remaining: 1.88s
# 132:	learn: 0.1569661	total: 2.71s	remaining: 1.86s
# 133:	learn: 0.1569499	total: 2.73s	remaining: 1.84s
# 134:	learn: 0.1569084	total: 2.75s	remaining: 1.82s
# 135:	learn: 0.1566017	total: 2.77s	remaining: 1.79s
# 136:	learn: 0.1565725	total: 2.79s	remaining: 1.77s
# 137:	learn: 0.1565553	total: 2.81s	remaining: 1.75s
# 138:	learn: 0.1565146	total: 2.84s	remaining: 1.73s
# 139:	learn: 0.1564987	total: 2.86s	remaining: 1.72s
# 140:	learn: 0.1564836	total: 2.88s	remaining: 1.69s
# 141:	learn: 0.1564687	total: 2.9s	remaining: 1.67s
# 142:	learn: 0.1543249	total: 2.92s	remaining: 1.65s
# 143:	learn: 0.1527769	total: 2.94s	remaining: 1.63s
# 144:	learn: 0.1522305	total: 2.96s	remaining: 1.61s
# 145:	learn: 0.1505223	total: 2.98s	remaining: 1.59s
# 146:	learn: 0.1499742	total: 3s	remaining: 1.57s
# 147:	learn: 0.1496316	total: 3.02s	remaining: 1.55s
# 148:	learn: 0.1496227	total: 3.04s	remaining: 1.53s
# 149:	learn: 0.1496078	total: 3.06s	remaining: 1.51s
# 150:	learn: 0.1495910	total: 3.08s	remaining: 1.49s
# 151:	learn: 0.1495831	total: 3.1s	remaining: 1.47s
# 152:	learn: 0.1495663	total: 3.12s	remaining: 1.45s
# 153:	learn: 0.1495573	total: 3.14s	remaining: 1.43s
# 154:	learn: 0.1495501	total: 3.16s	remaining: 1.41s
# 155:	learn: 0.1495336	total: 3.18s	remaining: 1.39s
# 156:	learn: 0.1495259	total: 3.2s	remaining: 1.37s
# 157:	learn: 0.1492550	total: 3.22s	remaining: 1.34s
# 158:	learn: 0.1478207	total: 3.24s	remaining: 1.32s
# 159:	learn: 0.1473987	total: 3.26s	remaining: 1.3s
# 160:	learn: 0.1455653	total: 3.28s	remaining: 1.28s
# 161:	learn: 0.1449396	total: 3.3s	remaining: 1.26s
# 162:	learn: 0.1441228	total: 3.32s	remaining: 1.24s
# 163:	learn: 0.1415697	total: 3.34s	remaining: 1.22s
# 164:	learn: 0.1398248	total: 3.36s	remaining: 1.2s
# 165:	learn: 0.1396057	total: 3.38s	remaining: 1.18s
# 166:	learn: 0.1391349	total: 3.4s	remaining: 1.16s
# 167:	learn: 0.1385907	total: 3.42s	remaining: 1.14s
# 168:	learn: 0.1385759	total: 3.44s	remaining: 1.12s
# 169:	learn: 0.1385525	total: 3.46s	remaining: 1.1s
# 170:	learn: 0.1367109	total: 3.48s	remaining: 1.08s
# 171:	learn: 0.1362276	total: 3.5s	remaining: 1.06s
# 172:	learn: 0.1360378	total: 3.52s	remaining: 1.04s
# 173:	learn: 0.1357704	total: 3.55s	remaining: 1.02s
# 174:	learn: 0.1354961	total: 3.57s	remaining: 999ms
# 175:	learn: 0.1352745	total: 3.59s	remaining: 979ms
# 176:	learn: 0.1350356	total: 3.61s	remaining: 958ms
# 177:	learn: 0.1344801	total: 3.63s	remaining: 938ms
# 178:	learn: 0.1335135	total: 3.65s	remaining: 918ms
# 179:	learn: 0.1329750	total: 3.67s	remaining: 897ms
# 180:	learn: 0.1323215	total: 3.69s	remaining: 876ms
# 181:	learn: 0.1322209	total: 3.71s	remaining: 856ms
# 182:	learn: 0.1319460	total: 3.73s	remaining: 835ms
# 183:	learn: 0.1317493	total: 3.75s	remaining: 815ms
# 184:	learn: 0.1299198	total: 3.77s	remaining: 794ms
# 185:	learn: 0.1281634	total: 3.79s	remaining: 774ms
# 186:	learn: 0.1281500	total: 3.81s	remaining: 753ms
# 187:	learn: 0.1280980	total: 3.83s	remaining: 733ms
# 188:	learn: 0.1280862	total: 3.85s	remaining: 712ms
# 189:	learn: 0.1267494	total: 3.87s	remaining: 693ms
# 190:	learn: 0.1264308	total: 3.89s	remaining: 673ms
# 191:	learn: 0.1251719	total: 3.91s	remaining: 652ms
# 192:	learn: 0.1249964	total: 3.93s	remaining: 632ms
# 193:	learn: 0.1245166	total: 3.95s	remaining: 611ms
# 194:	learn: 0.1238199	total: 3.97s	remaining: 591ms
# 195:	learn: 0.1228672	total: 3.99s	remaining: 571ms
# 196:	learn: 0.1217550	total: 4.01s	remaining: 550ms
# 197:	learn: 0.1216920	total: 4.03s	remaining: 530ms
# 198:	learn: 0.1214764	total: 4.05s	remaining: 509ms
# 199:	learn: 0.1203297	total: 4.07s	remaining: 489ms
# 200:	learn: 0.1202306	total: 4.09s	remaining: 469ms
# 201:	learn: 0.1201347	total: 4.12s	remaining: 448ms
# 202:	learn: 0.1183756	total: 4.13s	remaining: 428ms
# 203:	learn: 0.1181730	total: 4.15s	remaining: 407ms
# 204:	learn: 0.1181514	total: 4.17s	remaining: 387ms
# 205:	learn: 0.1181446	total: 4.19s	remaining: 367ms
# 206:	learn: 0.1181370	total: 4.21s	remaining: 346ms
# ...
# 61:	learn: 0.1880307	total: 9.41s	remaining: 30.4s
# 62:	learn: 0.1878657	total: 9.56s	remaining: 30.2s
# 63:	learn: 0.1876858	total: 9.69s	remaining: 30s
# 64:	learn: 0.1856148	total: 9.87s	remaining: 29.9s
# 65:	learn: 0.1850049	total: 10s	remaining: 29.7s
# 66:	learn: 0.1843117	total: 10.1s	remaining: 29.5s
# 67:	learn: 0.1823383	total: 10.3s	remaining: 29.3s
# 68:	learn: 0.1818259	total: 10.4s	remaining: 29.1s
# 69:	learn: 0.1816725	total: 10.6s	remaining: 29s
# 70:	learn: 0.1809916	total: 10.8s	remaining: 28.9s
# 71:	learn: 0.1802599	total: 11s	remaining: 28.9s
# 72:	learn: 0.1790883	total: 11.1s	remaining: 28.8s
# 73:	learn: 0.1789653	total: 11.3s	remaining: 28.7s
# 74:	learn: 0.1782560	total: 11.5s	remaining: 28.7s
# 75:	learn: 0.1780761	total: 11.7s	remaining: 28.6s
# 76:	learn: 0.1762845	total: 11.9s	remaining: 28.5s
# 77:	learn: 0.1756355	total: 12s	remaining: 28.2s
# 78:	learn: 0.1753455	total: 12.1s	remaining: 28.1s
# 79:	learn: 0.1750079	total: 12.3s	remaining: 27.9s
# 80:	learn: 0.1739064	total: 12.5s	remaining: 27.9s
# 81:	learn: 0.1724779	total: 12.7s	remaining: 27.8s
# 82:	learn: 0.1724309	total: 12.8s	remaining: 27.6s
# 83:	learn: 0.1723094	total: 13s	remaining: 27.5s
# 84:	learn: 0.1722789	total: 13s	remaining: 27.1s
# 85:	learn: 0.1721051	total: 13.1s	remaining: 26.9s
# 86:	learn: 0.1719961	total: 13.3s	remaining: 26.7s
# 87:	learn: 0.1719444	total: 13.4s	remaining: 26.4s
# 88:	learn: 0.1719160	total: 13.5s	remaining: 26.2s
# 89:	learn: 0.1718827	total: 13.6s	remaining: 26s
# 90:	learn: 0.1718548	total: 13.7s	remaining: 25.8s
# 91:	learn: 0.1718238	total: 13.8s	remaining: 25.5s
# 92:	learn: 0.1717897	total: 13.9s	remaining: 25.3s
# 93:	learn: 0.1717313	total: 14s	remaining: 25s
# 94:	learn: 0.1716585	total: 14.1s	remaining: 24.8s
# 95:	learn: 0.1715127	total: 14.2s	remaining: 24.6s
# 96:	learn: 0.1714920	total: 14.4s	remaining: 24.4s
# 97:	learn: 0.1713827	total: 14.5s	remaining: 24.3s
# 98:	learn: 0.1713484	total: 14.7s	remaining: 24.2s
# 99:	learn: 0.1712237	total: 14.8s	remaining: 24s
# 100:	learn: 0.1711810	total: 15s	remaining: 23.9s
# 101:	learn: 0.1698175	total: 15.1s	remaining: 23.7s
# 102:	learn: 0.1697089	total: 15.2s	remaining: 23.4s
# 103:	learn: 0.1688381	total: 15.3s	remaining: 23.3s
# 104:	learn: 0.1687037	total: 15.4s	remaining: 23.1s
# 105:	learn: 0.1685817	total: 15.6s	remaining: 22.9s
# 106:	learn: 0.1684638	total: 15.7s	remaining: 22.7s
# 107:	learn: 0.1679567	total: 15.7s	remaining: 22.5s
# 108:	learn: 0.1667844	total: 15.9s	remaining: 22.3s
# 109:	learn: 0.1666514	total: 16.1s	remaining: 22.2s
# 110:	learn: 0.1662976	total: 16.2s	remaining: 22.1s
# 111:	learn: 0.1649640	total: 16.4s	remaining: 21.9s
# 112:	learn: 0.1647030	total: 16.5s	remaining: 21.8s
# 113:	learn: 0.1642046	total: 16.7s	remaining: 21.7s
# 114:	learn: 0.1639674	total: 16.8s	remaining: 21.5s
# 115:	learn: 0.1632598	total: 16.9s	remaining: 21.3s
# 116:	learn: 0.1622190	total: 17s	remaining: 21.1s
# 117:	learn: 0.1621900	total: 17.3s	remaining: 21.1s
# 118:	learn: 0.1621329	total: 17.5s	remaining: 21s
# 119:	learn: 0.1609100	total: 17.6s	remaining: 20.8s
# 120:	learn: 0.1608929	total: 17.7s	remaining: 20.6s
# 121:	learn: 0.1608773	total: 17.8s	remaining: 20.5s
# 122:	learn: 0.1608385	total: 18s	remaining: 20.3s
# 123:	learn: 0.1608215	total: 18.1s	remaining: 20.2s
# 124:	learn: 0.1608047	total: 18.3s	remaining: 20s
# 125:	learn: 0.1607837	total: 18.4s	remaining: 19.8s
# 126:	learn: 0.1607702	total: 18.5s	remaining: 19.7s
# 127:	learn: 0.1607504	total: 18.7s	remaining: 19.6s
# 128:	learn: 0.1607292	total: 18.8s	remaining: 19.4s
# 129:	learn: 0.1607137	total: 18.9s	remaining: 19.2s
# 130:	learn: 0.1606935	total: 19.1s	remaining: 19.1s
# 131:	learn: 0.1606747	total: 19.2s	remaining: 18.9s
# 132:	learn: 0.1606689	total: 19.4s	remaining: 18.8s
# 133:	learn: 0.1606620	total: 19.6s	remaining: 18.7s
# 134:	learn: 0.1606491	total: 19.7s	remaining: 18.5s
# 135:	learn: 0.1606424	total: 19.8s	remaining: 18.4s
# 136:	learn: 0.1606245	total: 19.9s	remaining: 18.2s
# 137:	learn: 0.1606129	total: 20.1s	remaining: 18.1s
# 138:	learn: 0.1606014	total: 20.3s	remaining: 17.9s
# 139:	learn: 0.1605162	total: 20.4s	remaining: 17.8s
# 140:	learn: 0.1605052	total: 20.4s	remaining: 17.5s
# 141:	learn: 0.1604986	total: 20.6s	remaining: 17.4s
# 142:	learn: 0.1604844	total: 20.8s	remaining: 17.3s
# 143:	learn: 0.1604641	total: 20.9s	remaining: 17.1s
# 144:	learn: 0.1604147	total: 21s	remaining: 17s
# 145:	learn: 0.1603946	total: 21.1s	remaining: 16.8s
# 146:	learn: 0.1603836	total: 21.2s	remaining: 16.6s
# 147:	learn: 0.1603778	total: 21.3s	remaining: 16.4s
# 148:	learn: 0.1603273	total: 21.5s	remaining: 16.3s
# 149:	learn: 0.1603208	total: 21.6s	remaining: 16.1s
# 150:	learn: 0.1599065	total: 21.8s	remaining: 16s
# 151:	learn: 0.1598482	total: 21.9s	remaining: 15.8s
# 152:	learn: 0.1598425	total: 22s	remaining: 15.7s
# 153:	learn: 0.1598360	total: 22.2s	remaining: 15.5s
# 154:	learn: 0.1598291	total: 22.3s	remaining: 15.4s
# 155:	learn: 0.1589431	total: 22.4s	remaining: 15.2s
# 156:	learn: 0.1588814	total: 22.7s	remaining: 15.2s
# 157:	learn: 0.1588646	total: 22.8s	remaining: 15s
# 158:	learn: 0.1588022	total: 22.9s	remaining: 14.8s
# 159:	learn: 0.1587943	total: 23s	remaining: 14.7s
# 160:	learn: 0.1587876	total: 23.2s	remaining: 14.6s
# 161:	learn: 0.1587319	total: 23.3s	remaining: 14.4s
# 162:	learn: 0.1587256	total: 23.5s	remaining: 14.2s
# 163:	learn: 0.1586599	total: 23.6s	remaining: 14.1s
# 164:	learn: 0.1586502	total: 23.7s	remaining: 13.9s
# 165:	learn: 0.1586389	total: 23.9s	remaining: 13.8s
# 166:	learn: 0.1586329	total: 24s	remaining: 13.7s
# 167:	learn: 0.1586268	total: 24.1s	remaining: 13.5s
# 168:	learn: 0.1586209	total: 24.2s	remaining: 13.3s
# 169:	learn: 0.1585075	total: 24.3s	remaining: 13.2s
# 170:	learn: 0.1584512	total: 24.4s	remaining: 13s
# 171:	learn: 0.1581375	total: 24.5s	remaining: 12.8s
# 172:	learn: 0.1580824	total: 24.5s	remaining: 12.6s
# 173:	learn: 0.1574856	total: 24.6s	remaining: 12.5s
# 174:	learn: 0.1574258	total: 24.7s	remaining: 12.3s
# 175:	learn: 0.1563535	total: 24.8s	remaining: 12.1s
# 176:	learn: 0.1562348	total: 24.9s	remaining: 12s
# 177:	learn: 0.1561557	total: 25s	remaining: 11.8s
# 178:	learn: 0.1560403	total: 25.1s	remaining: 11.6s
# 179:	learn: 0.1559836	total: 25.2s	remaining: 11.5s
# 180:	learn: 0.1559381	total: 25.4s	remaining: 11.4s
# 181:	learn: 0.1559322	total: 25.6s	remaining: 11.2s
# 182:	learn: 0.1558822	total: 25.7s	remaining: 11.1s
# 183:	learn: 0.1558034	total: 25.9s	remaining: 11s
# 184:	learn: 0.1549395	total: 26s	remaining: 10.8s
# 185:	learn: 0.1549332	total: 26.2s	remaining: 10.7s
# 186:	learn: 0.1549274	total: 26.3s	remaining: 10.6s
# 187:	learn: 0.1549216	total: 26.4s	remaining: 10.4s
# 188:	learn: 0.1549159	total: 26.5s	remaining: 10.2s
# 189:	learn: 0.1545730	total: 26.7s	remaining: 10.1s
# 190:	learn: 0.1543689	total: 26.8s	remaining: 9.97s
# 191:	learn: 0.1538039	total: 26.9s	remaining: 9.81s
# 192:	learn: 0.1537983	total: 27s	remaining: 9.65s
# 193:	learn: 0.1537929	total: 27.1s	remaining: 9.51s
# 194:	learn: 0.1537870	total: 27.2s	remaining: 9.36s
# 195:	learn: 0.1537815	total: 27.3s	remaining: 9.21s
# 196:	learn: 0.1537761	total: 27.5s	remaining: 9.07s
# 197:	learn: 0.1537707	total: 27.6s	remaining: 8.93s
# 198:	learn: 0.1537654	total: 27.8s	remaining: 8.79s
# 199:	learn: 0.1537600	total: 27.9s	remaining: 8.63s
# 200:	learn: 0.1527638	total: 28s	remaining: 8.49s
# 201:	learn: 0.1527500	total: 28.1s	remaining: 8.35s
# 202:	learn: 0.1527339	total: 28.2s	remaining: 8.2s
# 203:	learn: 0.1517934	total: 28.4s	remaining: 8.08s
# 204:	learn: 0.1517901	total: 28.5s	remaining: 7.94s
# 205:	learn: 0.1517840	total: 28.7s	remaining: 7.8s
# 206:	learn: 0.1515688	total: 28.8s	remaining: 7.64s
# 207:	learn: 0.1503687	total: 29s	remaining: 7.52s
# 208:	learn: 0.1500309	total: 29.1s	remaining: 7.38s
# 209:	learn: 0.1500279	total: 29.2s	remaining: 7.23s
# 210:	learn: 0.1500251	total: 29.4s	remaining: 7.09s
# 211:	learn: 0.1500193	total: 29.5s	remaining: 6.96s
# 212:	learn: 0.1500159	total: 29.6s	remaining: 6.81s
# 213:	learn: 0.1500121	total: 29.7s	remaining: 6.67s
# 214:	learn: 0.1487361	total: 29.9s	remaining: 6.53s
# 215:	learn: 0.1486907	total: 30.1s	remaining: 6.41s
# 216:	learn: 0.1486855	total: 30.2s	remaining: 6.26s
# 217:	learn: 0.1485809	total: 30.3s	remaining: 6.12s
# 218:	learn: 0.1485751	total: 30.4s	remaining: 5.98s
# 219:	learn: 0.1485220	total: 30.6s	remaining: 5.84s
# 220:	learn: 0.1482860	total: 30.8s	remaining: 5.71s
# 221:	learn: 0.1482806	total: 30.9s	remaining: 5.56s
# 222:	learn: 0.1482647	total: 31s	remaining: 5.42s
# 223:	learn: 0.1482592	total: 31.1s	remaining: 5.27s
# 224:	learn: 0.1482559	total: 31.2s	remaining: 5.14s
# 225:	learn: 0.1482501	total: 31.3s	remaining: 4.99s
# 226:	learn: 0.1482445	total: 31.4s	remaining: 4.85s
# 227:	learn: 0.1482393	total: 31.6s	remaining: 4.71s
# 228:	learn: 0.1479101	total: 31.8s	remaining: 4.58s
# 229:	learn: 0.1479043	total: 32s	remaining: 4.45s
# 230:	learn: 0.1478993	total: 32.2s	remaining: 4.32s
# 231:	learn: 0.1478967	total: 32.3s	remaining: 4.18s
# 232:	learn: 0.1478812	total: 32.4s	remaining: 4.04s
# 233:	learn: 0.1478642	total: 32.5s	remaining: 3.89s
# 234:	learn: 0.1467763	total: 32.7s	remaining: 3.76s
# 235:	learn: 0.1467705	total: 32.9s	remaining: 3.62s
# 236:	learn: 0.1467678	total: 33s	remaining: 3.48s
# 237:	learn: 0.1467525	total: 33.1s	remaining: 3.34s
# 238:	learn: 0.1467470	total: 33.2s	remaining: 3.2s
# 239:	learn: 0.1467440	total: 33.4s	remaining: 3.06s
# 240:	learn: 0.1466934	total: 33.5s	remaining: 2.92s
# 241:	learn: 0.1466904	total: 33.6s	remaining: 2.78s
# 242:	learn: 0.1466855	total: 33.7s	remaining: 2.64s
# 243:	learn: 0.1466801	total: 33.9s	remaining: 2.5s
# 244:	learn: 0.1466368	total: 34s	remaining: 2.36s
# 245:	learn: 0.1466193	total: 34.1s	remaining: 2.22s
# 246:	learn: 0.1466164	total: 34.3s	remaining: 2.08s
# 247:	learn: 0.1462740	total: 34.4s	remaining: 1.94s
# 248:	learn: 0.1462708	total: 34.5s	remaining: 1.8s
# 249:	learn: 0.1461958	total: 34.6s	remaining: 1.66s
# 250:	learn: 0.1461906	total: 34.7s	remaining: 1.52s
# 251:	learn: 0.1461876	total: 34.9s	remaining: 1.38s
# 252:	learn: 0.1451946	total: 35s	remaining: 1.24s
# 253:	learn: 0.1451914	total: 35.1s	remaining: 1.1s
# 254:	learn: 0.1451883	total: 35.2s	remaining: 965ms
# 255:	learn: 0.1444681	total: 35.3s	remaining: 826ms
# 256:	learn: 0.1444652	total: 35.4s	remaining: 688ms
# 257:	learn: 0.1444622	total: 35.5s	remaining: 550ms
# 258:	learn: 0.1444591	total: 35.6s	remaining: 412ms
# 259:	learn: 0.1434493	total: 35.8s	remaining: 275ms
# 260:	learn: 0.1433651	total: 35.9s	remaining: 137ms
# 261:	learn: 0.1433095	total: 35.9s	remaining: 0us
# the best hyper-parameters for 1-AR-Alva-6108-slim-Normalize-group.csv activity are:   {'depth': 9, 'l2_leaf_reg': 26, 'learning_rate': 0.355040818510905, 'n_estimators': 95, 'random_strength': 0.33155031661904366}
# 0:	learn: 0.4237330	total: 391ms	remaining: 40.7s
# 1:	learn: 0.3219335	total: 720ms	remaining: 37.1s
# 2:	learn: 0.2814503	total: 1.02s	remaining: 34.9s
# 3:	learn: 0.2564286	total: 1.29s	remaining: 32.7s
# 4:	learn: 0.2381645	total: 1.57s	remaining: 31.5s
# 5:	learn: 0.2232544	total: 1.93s	remaining: 31.8s
# 6:	learn: 0.2116846	total: 2.28s	remaining: 31.9s
# 7:	learn: 0.2034976	total: 2.65s	remaining: 32.2s
# 8:	learn: 0.1945254	total: 2.97s	remaining: 31.6s
# 9:	learn: 0.1881712	total: 3.31s	remaining: 31.4s
# 10:	learn: 0.1821141	total: 3.57s	remaining: 30.5s
# 11:	learn: 0.1764249	total: 3.87s	remaining: 30s
# 12:	learn: 0.1684118	total: 4.11s	remaining: 29.1s
# 13:	learn: 0.1623575	total: 4.45s	remaining: 28.9s
# 14:	learn: 0.1595790	total: 4.75s	remaining: 28.5s
# 15:	learn: 0.1543528	total: 5.08s	remaining: 28.3s
# 16:	learn: 0.1503129	total: 5.38s	remaining: 27.9s
# 17:	learn: 0.1457856	total: 5.66s	remaining: 27.4s
# 18:	learn: 0.1420884	total: 5.98s	remaining: 27.1s
# 19:	learn: 0.1393838	total: 6.25s	remaining: 26.6s
# 20:	learn: 0.1386632	total: 6.49s	remaining: 26s
# 21:	learn: 0.1364358	total: 6.79s	remaining: 25.6s
# 22:	learn: 0.1357378	total: 7.06s	remaining: 25.2s
# 23:	learn: 0.1325327	total: 7.33s	remaining: 24.8s
# 24:	learn: 0.1324035	total: 7.61s	remaining: 24.3s
# 25:	learn: 0.1322110	total: 7.93s	remaining: 24.1s
# 26:	learn: 0.1321013	total: 8.21s	remaining: 23.7s
# 27:	learn: 0.1320068	total: 8.48s	remaining: 23.3s
# 28:	learn: 0.1319047	total: 8.86s	remaining: 23.2s
# 29:	learn: 0.1318115	total: 9.09s	remaining: 22.7s
# 30:	learn: 0.1317180	total: 9.36s	remaining: 22.3s
# 31:	learn: 0.1316301	total: 9.63s	remaining: 22s
# 32:	learn: 0.1314272	total: 9.91s	remaining: 21.6s
# 33:	learn: 0.1277979	total: 10.2s	remaining: 21.3s
# 34:	learn: 0.1267826	total: 10.6s	remaining: 21.2s
# 35:	learn: 0.1267022	total: 11s	remaining: 21s
# 36:	learn: 0.1242485	total: 11.2s	remaining: 20.6s
# 37:	learn: 0.1201443	total: 11.4s	remaining: 20.2s
# 38:	learn: 0.1172794	total: 11.7s	remaining: 19.8s
# 39:	learn: 0.1150463	total: 12s	remaining: 19.4s
# 40:	learn: 0.1149592	total: 12.3s	remaining: 19.1s
# 41:	learn: 0.1148925	total: 12.5s	remaining: 18.8s
# 42:	learn: 0.1148329	total: 12.8s	remaining: 18.4s
# 43:	learn: 0.1147728	total: 13.1s	remaining: 18.2s
# 44:	learn: 0.1146984	total: 13.4s	remaining: 17.9s
# 45:	learn: 0.1144808	total: 13.7s	remaining: 17.6s
# 46:	learn: 0.1108969	total: 14s	remaining: 17.3s
# 47:	learn: 0.1108397	total: 14.3s	remaining: 17s
# 48:	learn: 0.1099027	total: 14.5s	remaining: 16.6s
# 49:	learn: 0.1066742	total: 14.8s	remaining: 16.3s
# 50:	learn: 0.1045886	total: 15.1s	remaining: 16s
# 51:	learn: 0.1045277	total: 15.4s	remaining: 15.7s
# 52:	learn: 0.1015754	total: 15.7s	remaining: 15.4s
# 53:	learn: 0.0984351	total: 16.1s	remaining: 15.2s
# 54:	learn: 0.0956334	total: 16.3s	remaining: 14.8s
# 55:	learn: 0.0949243	total: 16.6s	remaining: 14.5s
# 56:	learn: 0.0933567	total: 16.9s	remaining: 14.2s
# 57:	learn: 0.0907156	total: 17.1s	remaining: 13.9s
# 58:	learn: 0.0904344	total: 17.4s	remaining: 13.6s
# 59:	learn: 0.0902628	total: 17.6s	remaining: 13.2s
# 60:	learn: 0.0901978	total: 17.9s	remaining: 12.9s
# 61:	learn: 0.0892186	total: 18.3s	remaining: 12.7s
# 62:	learn: 0.0891754	total: 18.6s	remaining: 12.4s
# 63:	learn: 0.0891325	total: 18.9s	remaining: 12.1s
# 64:	learn: 0.0890938	total: 19.1s	remaining: 11.8s
# 65:	learn: 0.0889411	total: 19.4s	remaining: 11.5s
# 66:	learn: 0.0870728	total: 19.7s	remaining: 11.2s
# 67:	learn: 0.0853244	total: 19.9s	remaining: 10.9s
# 68:	learn: 0.0844373	total: 20.3s	remaining: 10.6s
# 69:	learn: 0.0843947	total: 20.6s	remaining: 10.3s
# 70:	learn: 0.0840941	total: 21s	remaining: 10s
# 71:	learn: 0.0840482	total: 21.2s	remaining: 9.73s
# 72:	learn: 0.0822628	total: 21.6s	remaining: 9.45s
# 73:	learn: 0.0822205	total: 21.9s	remaining: 9.15s
# 74:	learn: 0.0821915	total: 22.1s	remaining: 8.86s
# 75:	learn: 0.0821478	total: 22.4s	remaining: 8.55s
# 76:	learn: 0.0820086	total: 22.6s	remaining: 8.23s
# 77:	learn: 0.0819683	total: 23s	remaining: 7.95s
# 78:	learn: 0.0819407	total: 23.2s	remaining: 7.65s
# 79:	learn: 0.0804129	total: 23.6s	remaining: 7.37s
# 80:	learn: 0.0784584	total: 23.9s	remaining: 7.09s
# 81:	learn: 0.0771169	total: 24.2s	remaining: 6.79s
# 82:	learn: 0.0768594	total: 24.5s	remaining: 6.49s
# 83:	learn: 0.0766699	total: 24.8s	remaining: 6.19s
# 84:	learn: 0.0766441	total: 25.1s	remaining: 5.91s
# 85:	learn: 0.0758527	total: 25.4s	remaining: 5.61s
# 86:	learn: 0.0742165	total: 25.7s	remaining: 5.32s
# 87:	learn: 0.0734918	total: 26s	remaining: 5.02s
# 88:	learn: 0.0734654	total: 26.4s	remaining: 4.74s
# 89:	learn: 0.0733782	total: 26.6s	remaining: 4.43s
# 90:	learn: 0.0719683	total: 26.9s	remaining: 4.14s
# 91:	learn: 0.0712287	total: 27.3s	remaining: 3.85s
# 92:	learn: 0.0695585	total: 27.6s	remaining: 3.56s
# 93:	learn: 0.0695227	total: 27.9s	remaining: 3.26s
# 94:	learn: 0.0693820	total: 28.2s	remaining: 2.96s
# 95:	learn: 0.0691737	total: 28.4s	remaining: 2.67s
# 96:	learn: 0.0672414	total: 28.7s	remaining: 2.37s
# 97:	learn: 0.0660211	total: 29s	remaining: 2.07s
# 98:	learn: 0.0646258	total: 29.3s	remaining: 1.77s
# 99:	learn: 0.0632737	total: 29.6s	remaining: 1.48s
# 100:	learn: 0.0631619	total: 29.8s	remaining: 1.18s
# 101:	learn: 0.0621237	total: 30.2s	remaining: 888ms
# 102:	learn: 0.0610430	total: 30.5s	remaining: 592ms
# 103:	learn: 0.0596489	total: 30.7s	remaining: 295ms
# 104:	learn: 0.0586485	total: 31s	remaining: 0us
# train 0.9998112762443974 0.9992883240321424
# valid 0.9537720706260031 0.8706659279746813
# test 0.9298011887681902 0.8429514152705901

# %%
# 10 repetitions based on thr best hypers
dataset.drop(columns=['group'], inplace=True)

# %%
pd_res = []
def best_model_runing(split):
    seed = split
    if task_type == 'cla':
        while True:
            training_data, data_te = train_test_split(sub_dataset, test_size=0.1, random_state=seed)
            # the training set was further splited into the training set and validation set
            data_tr, data_va = train_test_split(training_data, test_size=0.1, random_state=seed)
            if (all_one_zeros(data_tr[subtask]) or all_one_zeros(data_va[subtask]) or all_one_zeros(data_te[subtask])):
                print(
                    '\ninvalid random seed {} due to one class presented in the {} splitted sets...'.format(seed,
                                                                                                            subtask))
                print('Changing to another random seed...\n')
                seed = np.random.randint(10, 999999)
            else:
                print('random seed used in repetition {} is {}'.format(split, seed))
                break
    else:
        training_data, data_te = train_test_split(sub_dataset, test_size=0.1, random_state=seed)
        # the training set was further splited into the training set and validation set
        data_tr, data_va = train_test_split(training_data, test_size=0.1, random_state=seed)

    # prepare data for training
    # training set
    data_tr_y = data_tr[subtask].values.reshape(-1, 1)
    data_tr_x = np.array(data_tr.iloc[:, 1:].values)

    # validation set
    data_va_y = data_va[subtask].values.reshape(-1, 1)
    data_va_x = np.array(data_va.iloc[:, 1:].values)

    # test set
    data_te_y = data_te[subtask].values.reshape(-1, 1)
    data_te_x = np.array(data_te.iloc[:, 1:].values)

    if feature_selection:
        # univariate feature selection
        trans1 = SelectPercentile(f_classif, percentile=80)
        trans1.fit(data_tr_x, data_tr_y)
        data_tr_x = trans1.transform(data_tr_x)
        data_va_x = trans1.transform(data_va_x)
        data_te_x = trans1.transform(data_te_x)

        # select from model
        clf = XGBClassifier(random_state=1)
        clf = clf.fit(data_tr_x, data_tr_y)
        trans2 = SelectFromModel(clf, prefit=True)

        data_tr_x = trans2.transform(data_tr_x)
        data_va_x = trans2.transform(data_va_x)
        data_te_x = trans2.transform(data_te_x)     
        
    num_fea = data_tr_x.shape[1]
    pos_weight = (len(sub_dataset) - sum(sub_dataset[subtask])) / sum(sub_dataset[subtask])
    model = CatBoostClassifier(
                          n_estimators=best_hyper[best_hyper.subtask == subtask].iloc[0,]['n_estimators'],
#                           learning_rate=best_hyper[best_hyper.subtask == subtask].iloc[0,]['learning_rate'],
                          learning_rate=best_hyper[best_hyper.subtask == subtask].iloc[0,]['learning_rate'],
                          depth=best_hyper[best_hyper.subtask == subtask].iloc[0,]['depth'],
                          random_strength=best_hyper[best_hyper.subtask == subtask].iloc[0,]['random_strength'],
                          l2_leaf_reg=best_hyper[best_hyper.subtask == subtask].iloc[0,]['l2_leaf_reg'],
                          random_state=1) \
        if task_type == 'cla' else CatBoostRegressor(
                          n_estimators=best_hyper[best_hyper.subtask == subtask].iloc[0,]['n_estimators'],
#                           learning_rate=best_hyper[best_hyper.subtask == subtask].iloc[0,]['learning_rate'],
                          learning_rate=best_hyper[best_hyper.subtask == subtask].iloc[0,]['learning_rate'],
                          depth=best_hyper[best_hyper.subtask == subtask].iloc[0,]['depth'],
                          random_strength=best_hyper[best_hyper.subtask == subtask].iloc[0,]['random_strength'],
                          l2_leaf_reg=best_hyper[best_hyper.subtask == subtask].iloc[0,]['l2_leaf_reg'],
        random_state=1, seed=1)

    model.fit(data_tr_x, data_tr_y,
          eval_set=[(data_va_x, data_va_y)],
          early_stopping_rounds=patience, verbose=False)
    num_of_compounds = sub_dataset.shape[0]
    import pickle
    pickle.dump(model, open("./model/cat_"+str(split)+".pkl", "wb"))
    if task_type == 'cla':
        # training set
        tr_pred = model.predict_proba(data_tr_x)
        tr_results = [split, dataset_label, subtask, 'tr', num_fea, num_of_compounds,
                      data_tr_y[data_tr_y == 1].shape[0],
                      data_tr_y[data_tr_y == 0].shape[0],
                      data_tr_y[data_tr_y == 0].shape[0] / data_tr_y[data_tr_y == 1].shape[0]]
        tr_results.extend(statistical(data_tr_y, np.argmax(tr_pred, axis=1), tr_pred[:, 1]))

        # validation set
        va_pred = model.predict_proba(data_va_x)
        va_results = [split, dataset_label, subtask, 'va', num_fea, num_of_compounds,
                      data_va_y[data_va_y == 1].shape[0],
                      data_va_y[data_va_y == 0].shape[0],
                      data_va_y[data_va_y == 0].shape[0] / data_va_y[data_va_y == 1].shape[0]]
        va_results.extend(statistical(data_va_y, np.argmax(va_pred, axis=1), va_pred[:, 1]))

        # test set
        te_pred = model.predict_proba(data_te_x)
        te_results = [split, dataset_label, subtask, 'te', num_fea, num_of_compounds,
                      data_te_y[data_te_y == 1].shape[0],
                      data_te_y[data_te_y == 0].shape[0],
                      data_te_y[data_te_y == 0].shape[0] / data_te_y[data_te_y == 1].shape[0]]
        te_results.extend(statistical(data_te_y, np.argmax(te_pred, axis=1), te_pred[:, 1]))
    else:
        # training set
        tr_pred = model.predict(data_tr_x)
        tr_results = [split, dataset_label, subtask, 'tr', num_fea, num_of_compounds,
                      np.sqrt(mean_squared_error(data_tr_y, tr_pred)), r2_score(data_tr_y, tr_pred),
                      mean_absolute_error(data_tr_y, tr_pred)]

        # validation set
        va_pred = model.predict(data_va_x)
        va_results = [split, dataset_label, subtask, 'va', num_fea, num_of_compounds,
                      np.sqrt(mean_squared_error(data_va_y, va_pred)), r2_score(data_va_y, va_pred),
                      mean_absolute_error(data_va_y, va_pred)]

        # test set
        te_pred = model.predict(data_te_x)
        te_results = [split, dataset_label, subtask, 'te', num_fea, num_of_compounds,
                      np.sqrt(mean_squared_error(data_te_y, te_pred)), r2_score(data_te_y, te_pred),
                      mean_absolute_error(data_te_y, te_pred)]
    return tr_results, va_results, te_results


for subtask in tasks:
    cols = [subtask]
    cols.extend(dataset.columns[(len(tasks) + 1):])
    sub_dataset = dataset[cols]

    # detect the NA in the subtask (y cloumn)
    rm_index = sub_dataset[subtask][sub_dataset[subtask].isnull()].index
    sub_dataset.drop(index=rm_index, inplace=True)

    # remove the features with na
    sub_dataset = sub_dataset.dropna(axis=1)
    # *******************
    # demension reduction
    # *******************
    # Removing features with low variance
    # threshold = 0.05
    data_fea_var = sub_dataset.iloc[:, 1:].var()
    del_fea1 = list(data_fea_var[data_fea_var <= 0.05].index)
    sub_dataset.drop(columns=del_fea1, inplace=True)

    # pair correlations
    # threshold = 0.95
    data_fea_corr = sub_dataset.iloc[:, 1:].corr()
    del_fea2_col = []
    del_fea2_ind = []
    length = data_fea_corr.shape[1]
    for i in range(length):
        for j in range(i + 1, length):
            if abs(data_fea_corr.iloc[i, j]) >= 0.95:
                del_fea2_col.append(data_fea_corr.columns[i])
                del_fea2_ind.append(data_fea_corr.index[j])
    sub_dataset.drop(columns=del_fea2_ind, inplace=True)

    # standardize the features
    cols_ = list(sub_dataset.columns)[1:]
    if not ecfp :
        sub_dataset[cols_] = sub_dataset[cols_].apply(standardize, axis=0)

    # for split in range(1, splits+1):
    pool = multiprocessing.Pool(num_pools)
    res = pool.starmap(best_model_runing, zip(range(1, repetitions + 1)))
    pool.close()
    pool.join()
    for item in res:
        for i in range(3):
            pd_res.append(item[i])
if task_type == 'cla':
    stat_res = pd.DataFrame(pd_res, columns=['split', 'dataset', 'subtask', 'set',
                                             'num_of_retained_feature',
                                             'num_of_compounds', 'postives',
                                             'negtives', 'negtives/postives',
                                             'tn', 'fp', 'fn', 'tp', 'se', 'sp',
                                             'auc_prc', 'acc', 'auc_roc','recall','precision','f1','kappa','mcc'])
else:
    stat_res = pd.DataFrame(pd_res, columns=['split', 'dataset', 'subtask', 'set',
                                             'num_of_retained_feature',
                                             'num_of_compounds', 'rmse', 'r2', 'mae'])
stat_res.to_csv('./model/' + dataset_label + '_CAT_statistical_results_split.csv', index=0)
# single tasks
if len(tasks) == 1:
    args = {'data_label': dataset_label, 'metric': 'auc_roc' if task_type == 'cla' else 'rmse', 'model': 'CAT'}
    print('{}_{}: the mean {} for the training set is {:.3f} with std {:.3f}'.format(args['data_label'], args['model'],
                                                                                     args['metric'], np.mean(
            stat_res[stat_res['set'] == 'tr'][args['metric']]), np.std(
            stat_res[stat_res['set'] == 'tr'][args['metric']])))
    print(
        '{}_{}: the mean {} for the validation set is {:.3f} with std {:.3f}'.format(args['data_label'], args['model'],
                                                                                     args['metric'], np.mean(
                stat_res[stat_res['set'] == 'va'][args['metric']]), np.std(
                stat_res[stat_res['set'] == 'va'][args['metric']])))
    print('{}_{}: the mean {} for the test set is {:.3f} with std {:.3f}'.format(args['data_label'], args['model'],
                                                                                 args['metric'], np.mean(
            stat_res[stat_res['set'] == 'te'][args['metric']]), np.std(
            stat_res[stat_res['set'] == 'te'][args['metric']])))
# multi-tasks
else:
    args = {'data_label': dataset_label, 'metric': 'auc_roc' if dataset_label != 'muv' else 'auc_prc', 'model': 'CAT'}
    tr_acc = np.zeros(repetitions)
    va_acc = np.zeros(repetitions)
    te_acc = np.zeros(repetitions)
    for subtask in tasks:
        tr = stat_res[stat_res['set'] == 'tr']
        tr_acc = tr_acc + tr[tr['subtask'] == subtask][args['metric']].values

        va = stat_res[stat_res['set'] == 'va']
        va_acc = va_acc + va[va['subtask'] == subtask][args['metric']].values

        te = stat_res[stat_res['set'] == 'te']
        te_acc = te_acc + te[te['subtask'] == subtask][args['metric']].values
    tr_acc = tr_acc / len(tasks)
    va_acc = va_acc / len(tasks)
    te_acc = te_acc / len(tasks)
    print('{}_{}: the mean {} for the training set is {:.3f} with std {:.3f}'.format(args['data_label'], args['model'],
                                                                                     args['metric'], np.mean(tr_acc),
                                                                                     np.std(tr_acc)))
    print(
        '{}_{}: the mean {} for the validation set is {:.3f} with std {:.3f}'.format(args['data_label'], args['model'],
                                                                                     args['metric'], np.mean(va_acc),
                                                                                     np.std(va_acc)))
    print('{}_{}: the mean {} for the test set is {:.3f} with std {:.3f}'.format(args['data_label'], args['model'],
                                                                                 args['metric'], np.mean(te_acc),
                                                                                 np.std(te_acc)))
end = time.time()  # get the end time
# Out:
# random seed used in repetition 2 is 2
# random seed used in repetition 9 is 9
# random seed used in repetition 3 is 3
# random seed used in repetition 4 is 4
# random seed used in repetition 8 is 8
# random seed used in repetition 1 is 1
# random seed used in repetition 7 is 7
# random seed used in repetition 6 is 6
# random seed used in repetition 5 is 5
# random seed used in repetition 10 is 10
# 0:	learn: 0.4211970	total: 897ms	remaining: 1m 33s
# 0:	learn: 0.4296748	total: 1.44s	remaining: 2m 29s
# 0:	learn: 0.4267790	total: 1.31s	remaining: 2m 16s
# 0:	learn: 0.4200213	total: 1.24s	remaining: 2m 9s
# 0:	learn: 0.4232128	total: 1.45s	remaining: 2m 31s
# 0:	learn: 0.4229790	total: 1.28s	remaining: 2m 12s
# 0:	learn: 0.4276278	total: 1.59s	remaining: 2m 45s
# 1:	learn: 0.3314900	total: 2.38s	remaining: 2m 2s
# 0:	learn: 0.4262286	total: 1.6s	remaining: 2m 45s
# 0:	learn: 0.4104390	total: 1.37s	remaining: 2m 22s
# 0:	learn: 0.4195025	total: 1.32s	remaining: 2m 17s
# 1:	learn: 0.3209358	total: 2.56s	remaining: 2m 11s
# 1:	learn: 0.3191303	total: 2.45s	remaining: 2m 6s
# 1:	learn: 0.3295622	total: 2.54s	remaining: 2m 10s
# 1:	learn: 0.3332015	total: 2.47s	remaining: 2m 7s
# 2:	learn: 0.2849265	total: 3.58s	remaining: 2m 1s
# 1:	learn: 0.3271316	total: 2.57s	remaining: 2m 12s
# 1:	learn: 0.3232615	total: 3.22s	remaining: 2m 45s
# 2:	learn: 0.2753043	total: 3.42s	remaining: 1m 56s
# 1:	learn: 0.3283826	total: 3.74s	remaining: 3m 12s
# 1:	learn: 0.3215548	total: 2.89s	remaining: 2m 28s
# 2:	learn: 0.2840347	total: 3.95s	remaining: 2m 14s
# 1:	learn: 0.3209085	total: 3.34s	remaining: 2m 51s
# 2:	learn: 0.2808492	total: 3.86s	remaining: 2m 11s
# 3:	learn: 0.2576650	total: 4.8s	remaining: 2m 1s
# 2:	learn: 0.2803583	total: 4.01s	remaining: 2m 16s
# 2:	learn: 0.2867092	total: 3.82s	remaining: 2m 9s
# 3:	learn: 0.2515660	total: 4.43s	remaining: 1m 51s
# 2:	learn: 0.2824864	total: 5.13s	remaining: 2m 54s
# 2:	learn: 0.2819081	total: 4.95s	remaining: 2m 48s
# 3:	learn: 0.2606191	total: 4.94s	remaining: 2m 4s
# 2:	learn: 0.2859197	total: 4.39s	remaining: 2m 29s
# 3:	learn: 0.2517286	total: 5.2s	remaining: 2m 11s
# 3:	learn: 0.2571632	total: 5.27s	remaining: 2m 12s
# 4:	learn: 0.2396248	total: 6.23s	remaining: 2m 4s
# 2:	learn: 0.2801912	total: 4.49s	remaining: 2m 32s
# 3:	learn: 0.2591539	total: 5.31s	remaining: 2m 14s
# 4:	learn: 0.2333289	total: 5.93s	remaining: 1m 58s
# 3:	learn: 0.2526490	total: 5.9s	remaining: 2m 28s
# 3:	learn: 0.2556140	total: 6.39s	remaining: 2m 41s
# 4:	learn: 0.2422627	total: 6.06s	remaining: 2m 1s
# 4:	learn: 0.2334052	total: 6.29s	remaining: 2m 5s
# 3:	learn: 0.2561403	total: 5.44s	remaining: 2m 17s
# 4:	learn: 0.2397606	total: 6.47s	remaining: 2m 9s
# 4:	learn: 0.2365873	total: 7.14s	remaining: 2m 22s
# 4:	learn: 0.2390904	total: 6.98s	remaining: 2m 19s
# 5:	learn: 0.2271094	total: 7.9s	remaining: 2m 10s
# 4:	learn: 0.2345028	total: 7.61s	remaining: 2m 32s
# 5:	learn: 0.2186749	total: 7.51s	remaining: 2m 3s
# 5:	learn: 0.2207430	total: 7.31s	remaining: 2m
# 5:	learn: 0.2297475	total: 7.49s	remaining: 2m 3s
# 3:	learn: 0.2528447	total: 6.92s	remaining: 2m 54s
# 5:	learn: 0.2246644	total: 7.52s	remaining: 2m 4s
# 4:	learn: 0.2364687	total: 6.9s	remaining: 2m 18s
# 6:	learn: 0.2156709	total: 8.99s	remaining: 2m 5s
# 5:	learn: 0.2252400	total: 8.1s	remaining: 2m 13s
# 6:	learn: 0.2089306	total: 8.64s	remaining: 2m
# 5:	learn: 0.2211479	total: 8.91s	remaining: 2m 27s
# 4:	learn: 0.2327606	total: 8.25s	remaining: 2m 45s
# 6:	learn: 0.2179787	total: 8.85s	remaining: 2m 3s
# 6:	learn: 0.2083977	total: 8.88s	remaining: 2m 4s
# 6:	learn: 0.2125893	total: 8.69s	remaining: 2m 1s
# 5:	learn: 0.2206745	total: 9.06s	remaining: 2m 29s
# 5:	learn: 0.2232192	total: 8.07s	remaining: 2m 13s
# 7:	learn: 0.2090467	total: 10s	remaining: 2m 1s
# 6:	learn: 0.2116601	total: 9.86s	remaining: 2m 18s
# 7:	learn: 0.2097055	total: 9.82s	remaining: 1m 59s
# 7:	learn: 0.1977752	total: 10.1s	remaining: 2m 3s
# 7:	learn: 0.2044419	total: 9.82s	remaining: 1m 59s
# 7:	learn: 0.1992297	total: 10.1s	remaining: 2m 2s
# 6:	learn: 0.2106100	total: 10.1s	remaining: 2m 20s
# 6:	learn: 0.2088355	total: 10.5s	remaining: 2m 26s
# 5:	learn: 0.2193178	total: 9.88s	remaining: 2m 43s
# 6:	learn: 0.2122431	total: 9.46s	remaining: 2m 12s
# 8:	learn: 0.1996838	total: 11.2s	remaining: 1m 59s
# 8:	learn: 0.2034320	total: 11s	remaining: 1m 57s
# 8:	learn: 0.1894096	total: 11.3s	remaining: 2m
# 8:	learn: 0.1920275	total: 11.1s	remaining: 1m 58s
# 7:	learn: 0.2008357	total: 11.6s	remaining: 2m 20s
# 8:	learn: 0.1944721	total: 11s	remaining: 1m 57s
# 7:	learn: 0.2005439	total: 11.4s	remaining: 2m 18s
# 7:	learn: 0.2027963	total: 10.6s	remaining: 2m 8s
# 6:	learn: 0.2076529	total: 11.2s	remaining: 2m 36s
# 9:	learn: 0.1956643	total: 12s	remaining: 1m 54s
# 9:	learn: 0.1915070	total: 12.7s	remaining: 2m
# 8:	learn: 0.1914341	total: 12.8s	remaining: 2m 16s
# 9:	learn: 0.1836459	total: 12.4s	remaining: 1m 57s
# 9:	learn: 0.1868596	total: 12.2s	remaining: 1m 55s
# 7:	learn: 0.2000594	total: 12.6s	remaining: 2m 32s
# 9:	learn: 0.1819038	total: 12.7s	remaining: 2m 1s
# 8:	learn: 0.1946545	total: 12.7s	remaining: 2m 15s
# 7:	learn: 0.1979435	total: 12.7s	remaining: 2m 33s
# 8:	learn: 0.1932562	total: 12.2s	remaining: 2m 10s
# 10:	learn: 0.1889169	total: 13.2s	remaining: 1m 52s
# 10:	learn: 0.1840461	total: 14.1s	remaining: 2m
# 10:	learn: 0.1743841	total: 13.9s	remaining: 1m 58s
# 10:	learn: 0.1810542	total: 13.4s	remaining: 1m 54s
# 8:	learn: 0.1925464	total: 13.9s	remaining: 2m 28s
# 9:	learn: 0.1861677	total: 14.3s	remaining: 2m 15s
# 10:	learn: 0.1775166	total: 13.8s	remaining: 1m 58s
# 9:	learn: 0.1872865	total: 13.9s	remaining: 2m 11s
# 8:	learn: 0.1892868	total: 13.6s	remaining: 2m 25s
# 11:	learn: 0.1800817	total: 14.4s	remaining: 1m 51s
# 9:	learn: 0.1856769	total: 13.5s	remaining: 2m 7s
# 11:	learn: 0.1772499	total: 15.2s	remaining: 1m 57s
# 11:	learn: 0.1718442	total: 15s	remaining: 1m 55s
# 11:	learn: 0.1754114	total: 14.8s	remaining: 1m 54s
# 10:	learn: 0.1792639	total: 15s	remaining: 2m 8s
# 11:	learn: 0.1688404	total: 15.2s	remaining: 1m 58s
# 9:	learn: 0.1856342	total: 15.4s	remaining: 2m 25s
# 10:	learn: 0.1803396	total: 15.7s	remaining: 2m 14s
# 12:	learn: 0.1724295	total: 16.1s	remaining: 1m 54s
# 9:	learn: 0.1812206	total: 15.1s	remaining: 2m 23s
# 12:	learn: 0.1749114	total: 15.6s	remaining: 1m 50s
# 10:	learn: 0.1832263	total: 14.9s	remaining: 2m 7s
# 12:	learn: 0.1661816	total: 16.2s	remaining: 1m 54s
# 12:	learn: 0.1701018	total: 15.9s	remaining: 1m 52s
# 11:	learn: 0.1726199	total: 16.2s	remaining: 2m 5s
# 10:	learn: 0.1785252	total: 16.5s	remaining: 2m 20s
# 12:	learn: 0.1667657	total: 16.5s	remaining: 1m 56s
# 13:	learn: 0.1678613	total: 17.7s	remaining: 1m 55s
# 10:	learn: 0.1752250	total: 16.6s	remaining: 2m 22s
# 13:	learn: 0.1627756	total: 17.3s	remaining: 1m 52s
# 13:	learn: 0.1691590	total: 17s	remaining: 1m 50s
# 11:	learn: 0.1746508	total: 17.6s	remaining: 2m 16s
# 12:	learn: 0.1693441	total: 17.3s	remaining: 2m 2s
# 13:	learn: 0.1634446	total: 17.3s	remaining: 1m 52s
# 13:	learn: 0.1623836	total: 17.7s	remaining: 1m 55s
# 11:	learn: 0.1718937	total: 17.9s	remaining: 2m 18s
# 11:	learn: 0.1766678	total: 17s	remaining: 2m 11s
# 14:	learn: 0.1574980	total: 18.4s	remaining: 1m 50s
# 11:	learn: 0.1693336	total: 17.9s	remaining: 2m 18s
# 14:	learn: 0.1630027	total: 19s	remaining: 1m 53s
# 14:	learn: 0.1656911	total: 18.4s	remaining: 1m 50s
# 14:	learn: 0.1621165	total: 18.3s	remaining: 1m 49s
# 12:	learn: 0.1691855	total: 19s	remaining: 2m 14s
# 13:	learn: 0.1626342	total: 18.6s	remaining: 2m
# 15:	learn: 0.1505337	total: 19.2s	remaining: 1m 46s
# 14:	learn: 0.1549159	total: 18.9s	remaining: 1m 53s
# 12:	learn: 0.1699138	total: 18.1s	remaining: 2m 8s
# 12:	learn: 0.1605597	total: 19s	remaining: 2m 14s
# 12:	learn: 0.1686551	total: 19.3s	remaining: 2m 16s
# 15:	learn: 0.1610696	total: 20.1s	remaining: 1m 51s
# 13:	learn: 0.1648301	total: 20.1s	remaining: 2m 10s
# 14:	learn: 0.1594309	total: 19.7s	remaining: 1m 58s
# 15:	learn: 0.1617836	total: 20s	remaining: 1m 51s
# 13:	learn: 0.1675690	total: 19.4s	remaining: 2m 5s
# 15:	learn: 0.1485189	total: 20.2s	remaining: 1m 52s
# 15:	learn: 0.1585637	total: 20.1s	remaining: 1m 51s
# 13:	learn: 0.1624752	total: 20.4s	remaining: 2m 12s
# 13:	learn: 0.1568994	total: 20.1s	remaining: 2m 10s
# 16:	learn: 0.1456175	total: 20.9s	remaining: 1m 48s
# 16:	learn: 0.1543273	total: 21.5s	remaining: 1m 51s
# 14:	learn: 0.1618901	total: 21.5s	remaining: 2m 9s
# 14:	learn: 0.1628836	total: 20.4s	remaining: 2m 2s
# 16:	learn: 0.1545559	total: 21.3s	remaining: 1m 50s
# 16:	learn: 0.1582035	total: 21.6s	remaining: 1m 51s
# 16:	learn: 0.1446445	total: 21.6s	remaining: 1m 51s
# 14:	learn: 0.1513450	total: 21.3s	remaining: 2m 7s
# 17:	learn: 0.1444548	total: 22s	remaining: 1m 46s
# 15:	learn: 0.1535097	total: 21.7s	remaining: 2m
# 14:	learn: 0.1581944	total: 21.7s	remaining: 2m 10s
# 17:	learn: 0.1500127	total: 22.6s	remaining: 1m 49s
# 15:	learn: 0.1581268	total: 22.7s	remaining: 2m 6s
# 15:	learn: 0.1600544	total: 21.5s	remaining: 1m 59s
# 17:	learn: 0.1575650	total: 22.4s	remaining: 1m 48s
# 17:	learn: 0.1494789	total: 22.5s	remaining: 1m 48s
# 17:	learn: 0.1427091	total: 22.8s	remaining: 1m 50s
# 15:	learn: 0.1458481	total: 22.6s	remaining: 2m 5s
# 15:	learn: 0.1552929	total: 22.9s	remaining: 2m 7s
# 16:	learn: 0.1475268	total: 23s	remaining: 1m 59s
# 18:	learn: 0.1394506	total: 23.5s	remaining: 1m 46s
# 16:	learn: 0.1528556	total: 23.7s	remaining: 2m 2s
# 18:	learn: 0.1468894	total: 24.1s	remaining: 1m 48s
# 16:	learn: 0.1566649	total: 22.9s	remaining: 1m 58s
# 18:	learn: 0.1449351	total: 23.7s	remaining: 1m 47s
# 18:	learn: 0.1383804	total: 24s	remaining: 1m 48s
# 16:	learn: 0.1503193	total: 24s	remaining: 2m 4s
# 18:	learn: 0.1539823	total: 24.1s	remaining: 1m 48s
# 17:	learn: 0.1430862	total: 24.3s	remaining: 1m 57s
# 19:	learn: 0.1435078	total: 25s	remaining: 1m 46s
# 17:	learn: 0.1510377	total: 25s	remaining: 2m
# 16:	learn: 0.1430592	total: 24.1s	remaining: 2m 5s
# 19:	learn: 0.1360159	total: 24.9s	remaining: 1m 45s
# 17:	learn: 0.1527553	total: 24.1s	remaining: 1m 56s
# 19:	learn: 0.1371205	total: 25.2s	remaining: 1m 47s
# 19:	learn: 0.1430272	total: 24.9s	remaining: 1m 46s
# 19:	learn: 0.1536020	total: 25.2s	remaining: 1m 47s
# 17:	learn: 0.1459532	total: 25.3s	remaining: 2m 2s
# 20:	learn: 0.1405969	total: 26.1s	remaining: 1m 44s
# 18:	learn: 0.1408976	total: 25.5s	remaining: 1m 55s
# 18:	learn: 0.1491685	total: 26.2s	remaining: 1m 58s
# 17:	learn: 0.1378043	total: 25.4s	remaining: 2m 2s
# 20:	learn: 0.1323348	total: 26.4s	remaining: 1m 45s
# 18:	learn: 0.1469960	total: 25.3s	remaining: 1m 54s
# 20:	learn: 0.1320814	total: 26.3s	remaining: 1m 45s
# 20:	learn: 0.1532773	total: 26.3s	remaining: 1m 45s
# 20:	learn: 0.1383147	total: 26.4s	remaining: 1m 45s
# 18:	learn: 0.1431095	total: 26.6s	remaining: 2m
# 21:	learn: 0.1287639	total: 27.3s	remaining: 1m 42s
# 18:	learn: 0.1353629	total: 26.6s	remaining: 2m
# 21:	learn: 0.1398609	total: 27.6s	remaining: 1m 44s
# 19:	learn: 0.1373760	total: 27s	remaining: 1m 54s
# 19:	learn: 0.1445761	total: 28.1s	remaining: 1m 59s
# 21:	learn: 0.1284546	total: 27.6s	remaining: 1m 44s
# 19:	learn: 0.1439911	total: 26.8s	remaining: 1m 53s
# 21:	learn: 0.1531622	total: 27.8s	remaining: 1m 44s
# 21:	learn: 0.1347056	total: 27.7s	remaining: 1m 44s
# 20:	learn: 0.1326459	total: 27.9s	remaining: 1m 51s
# 22:	learn: 0.1372483	total: 28.7s	remaining: 1m 42s
# 22:	learn: 0.1255406	total: 28.5s	remaining: 1m 41s
# 19:	learn: 0.1347172	total: 27.8s	remaining: 1m 58s
# 19:	learn: 0.1404698	total: 28.2s	remaining: 1m 59s
# 20:	learn: 0.1441182	total: 29.3s	remaining: 1m 57s
# 22:	learn: 0.1260654	total: 28.9s	remaining: 1m 42s
# 20:	learn: 0.1382688	total: 27.8s	remaining: 1m 51s
# 22:	learn: 0.1529999	total: 28.9s	remaining: 1m 43s
# 21:	learn: 0.1283019	total: 29.3s	remaining: 1m 50s
# 22:	learn: 0.1309460	total: 29.1s	remaining: 1m 43s
# 20:	learn: 0.1344836	total: 29s	remaining: 1m 56s
# 23:	learn: 0.1347923	total: 30s	remaining: 1m 41s
# 20:	learn: 0.1346955	total: 29.5s	remaining: 1m 58s
# 23:	learn: 0.1230966	total: 30.1s	remaining: 1m 41s
# 23:	learn: 0.1235725	total: 29.8s	remaining: 1m 40s
# 21:	learn: 0.1340982	total: 29.1s	remaining: 1m 49s
# 21:	learn: 0.1381943	total: 30.7s	remaining: 1m 55s
# 23:	learn: 0.1507237	total: 30.1s	remaining: 1m 41s
# 23:	learn: 0.1278761	total: 30.3s	remaining: 1m 42s
# 24:	learn: 0.1207234	total: 31s	remaining: 1m 39s
# 21:	learn: 0.1304428	total: 30.6s	remaining: 1m 55s
# 22:	learn: 0.1229680	total: 30.7s	remaining: 1m 49s
# 24:	learn: 0.1213703	total: 30.8s	remaining: 1m 38s
# 21:	learn: 0.1300447	total: 30.5s	remaining: 1m 55s
# 24:	learn: 0.1333703	total: 31.5s	remaining: 1m 40s
# 22:	learn: 0.1354837	total: 32s	remaining: 1m 53s
# 24:	learn: 0.1503513	total: 31.5s	remaining: 1m 40s
# 22:	learn: 0.1293615	total: 30.7s	remaining: 1m 49s
# 24:	learn: 0.1253546	total: 31.4s	remaining: 1m 40s
# 22:	learn: 0.1291478	total: 31.6s	remaining: 1m 52s
# 23:	learn: 0.1207193	total: 31.7s	remaining: 1m 47s
# 22:	learn: 0.1249096	total: 31.5s	remaining: 1m 52s
# 25:	learn: 0.1173225	total: 32.6s	remaining: 1m 39s
# 25:	learn: 0.1327103	total: 32.8s	remaining: 1m 39s
# 23:	learn: 0.1279269	total: 32.4s	remaining: 1m 49s
# 25:	learn: 0.1188662	total: 32.5s	remaining: 1m 38s
# 23:	learn: 0.1323672	total: 33.2s	remaining: 1m 52s
# 25:	learn: 0.1502211	total: 32.7s	remaining: 1m 39s
# 25:	learn: 0.1212143	total: 32.6s	remaining: 1m 39s
# 23:	learn: 0.1279243	total: 32.2s	remaining: 1m 48s
# 26:	learn: 0.1171686	total: 33.6s	remaining: 1m 37s
# 24:	learn: 0.1183076	total: 33.2s	remaining: 1m 46s
# 23:	learn: 0.1225289	total: 32.9s	remaining: 1m 50s
# 26:	learn: 0.1288982	total: 34.2s	remaining: 1m 38s
# 26:	learn: 0.1173696	total: 33.8s	remaining: 1m 37s
# 24:	learn: 0.1249498	total: 33.8s	remaining: 1m 48s
# 24:	learn: 0.1303234	total: 34.4s	remaining: 1m 50s
# 26:	learn: 0.1500091	total: 33.9s	remaining: 1m 37s
# 26:	learn: 0.1185780	total: 33.9s	remaining: 1m 37s
# 24:	learn: 0.1181121	total: 33.9s	remaining: 1m 48s
# 27:	learn: 0.1169870	total: 34.8s	remaining: 1m 35s
# 24:	learn: 0.1243690	total: 33.4s	remaining: 1m 46s
# 25:	learn: 0.1159430	total: 34.8s	remaining: 1m 45s
# 27:	learn: 0.1231121	total: 35.4s	remaining: 1m 37s
# 25:	learn: 0.1218423	total: 35s	remaining: 1m 46s
# 27:	learn: 0.1134284	total: 35.1s	remaining: 1m 36s
# 27:	learn: 0.1149621	total: 35s	remaining: 1m 36s
# 25:	learn: 0.1253896	total: 35.9s	remaining: 1m 49s
# 25:	learn: 0.1234159	total: 34.5s	remaining: 1m 44s
# 28:	learn: 0.1168450	total: 35.9s	remaining: 1m 34s
# 25:	learn: 0.1158400	total: 35.1s	remaining: 1m 46s
# 27:	learn: 0.1495452	total: 35.4s	remaining: 1m 37s
# 28:	learn: 0.1210044	total: 36.3s	remaining: 1m 35s
# 26:	learn: 0.1135274	total: 36.3s	remaining: 1m 44s
# 28:	learn: 0.1113137	total: 36.4s	remaining: 1m 35s
# 28:	learn: 0.1118009	total: 36.2s	remaining: 1m 34s
# 26:	learn: 0.1213765	total: 36.4s	remaining: 1m 45s
# 26:	learn: 0.1250311	total: 37s	remaining: 1m 46s
# 26:	learn: 0.1218309	total: 35.7s	remaining: 1m 43s
# 29:	learn: 0.1167160	total: 37.2s	remaining: 1m 32s
# 26:	learn: 0.1125642	total: 36.5s	remaining: 1m 45s
# 29:	learn: 0.1196450	total: 37.5s	remaining: 1m 33s
# 28:	learn: 0.1447391	total: 37.1s	remaining: 1m 37s
# 27:	learn: 0.1249406	total: 38s	remaining: 1m 44s
# 29:	learn: 0.1109516	total: 37.4s	remaining: 1m 33s
# 27:	learn: 0.1103514	total: 37.7s	remaining: 1m 43s
# 27:	learn: 0.1191833	total: 36.9s	remaining: 1m 41s
# 30:	learn: 0.1166321	total: 38.4s	remaining: 1m 31s
# 29:	learn: 0.1098452	total: 38s	remaining: 1m 35s
# 29:	learn: 0.1446419	total: 38.3s	remaining: 1m 35s
# 27:	learn: 0.1182035	total: 38.3s	remaining: 1m 45s
# 30:	learn: 0.1180463	total: 39s	remaining: 1m 33s
# 28:	learn: 0.1219482	total: 39s	remaining: 1m 42s
# 27:	learn: 0.1124381	total: 38.1s	remaining: 1m 44s
# 28:	learn: 0.1171038	total: 38.2s	remaining: 1m 39s
# 30:	learn: 0.1091918	total: 38.8s	remaining: 1m 32s
# 28:	learn: 0.1070432	total: 39s	remaining: 1m 42s
# 30:	learn: 0.1075955	total: 39.1s	remaining: 1m 33s
# 30:	learn: 0.1440895	total: 39.3s	remaining: 1m 33s
# 31:	learn: 0.1165374	total: 40s	remaining: 1m 31s
# 28:	learn: 0.1151609	total: 39.9s	remaining: 1m 44s
# 29:	learn: 0.1216772	total: 40.5s	remaining: 1m 41s
# 28:	learn: 0.1123311	total: 39.5s	remaining: 1m 43s
# 31:	learn: 0.1170264	total: 40.5s	remaining: 1m 32s
# 31:	learn: 0.1056291	total: 40s	remaining: 1m 31s
# 31:	learn: 0.1380044	total: 40.3s	remaining: 1m 31s
# 31:	learn: 0.1090137	total: 40.1s	remaining: 1m 31s
# 29:	learn: 0.1166243	total: 39.6s	remaining: 1m 39s
# 29:	learn: 0.1043642	total: 40.4s	remaining: 1m 41s
# 29:	learn: 0.1122569	total: 40.4s	remaining: 1m 41s
# 30:	learn: 0.1215621	total: 41.6s	remaining: 1m 39s
# 29:	learn: 0.1146393	total: 41s	remaining: 1m 42s
# 32:	learn: 0.1164309	total: 41.6s	remaining: 1m 30s
# 32:	learn: 0.1055378	total: 41.3s	remaining: 1m 30s
# 32:	learn: 0.1374020	total: 41.3s	remaining: 1m 30s
# 32:	learn: 0.1166347	total: 41.9s	remaining: 1m 31s
# 32:	learn: 0.1088073	total: 41.5s	remaining: 1m 30s
# 30:	learn: 0.1004891	total: 41.6s	remaining: 1m 39s
# 30:	learn: 0.1165196	total: 41s	remaining: 1m 37s
# 30:	learn: 0.1121547	total: 41.6s	remaining: 1m 39s
# 31:	learn: 0.1214568	total: 42.8s	remaining: 1m 37s
# 33:	learn: 0.1054616	total: 42.2s	remaining: 1m 28s
# 33:	learn: 0.1163687	total: 42.8s	remaining: 1m 29s
# 33:	learn: 0.1320937	total: 42.5s	remaining: 1m 28s
# 30:	learn: 0.1136350	total: 42.4s	remaining: 1m 41s
# 33:	learn: 0.1165571	total: 43.3s	remaining: 1m 30s
# 33:	learn: 0.1087270	total: 42.7s	remaining: 1m 29s
# 31:	learn: 0.1164009	total: 42s	remaining: 1m 35s
# 31:	learn: 0.1120043	total: 42.6s	remaining: 1m 37s
# 32:	learn: 0.1213728	total: 43.9s	remaining: 1m 35s
# 34:	learn: 0.1162999	total: 43.8s	remaining: 1m 27s
# 34:	learn: 0.1053862	total: 43.4s	remaining: 1m 26s
# 31:	learn: 0.0983045	total: 43.4s	remaining: 1m 38s
# 31:	learn: 0.1114603	total: 43.7s	remaining: 1m 39s
# 34:	learn: 0.1164835	total: 44.4s	remaining: 1m 28s
# 34:	learn: 0.1320025	total: 44.1s	remaining: 1m 28s
# 32:	learn: 0.1119382	total: 43.7s	remaining: 1m 35s
# 34:	learn: 0.1086443	total: 43.9s	remaining: 1m 27s
# 32:	learn: 0.1162916	total: 43.2s	remaining: 1m 34s
# 33:	learn: 0.1212910	total: 45.1s	remaining: 1m 34s
# 35:	learn: 0.1161559	total: 45s	remaining: 1m 26s
# 35:	learn: 0.1053145	total: 44.5s	remaining: 1m 25s
# 32:	learn: 0.0953819	total: 44.6s	remaining: 1m 37s
# 32:	learn: 0.1110774	total: 45.1s	remaining: 1m 38s
# 35:	learn: 0.1164083	total: 45.6s	remaining: 1m 27s
# 33:	learn: 0.1161935	total: 44.2s	remaining: 1m 32s
# 33:	learn: 0.1118414	total: 44.9s	remaining: 1m 33s
# 35:	learn: 0.1319106	total: 45.5s	remaining: 1m 27s
# 34:	learn: 0.1212194	total: 46.2s	remaining: 1m 32s
# 36:	learn: 0.1052432	total: 45.7s	remaining: 1m 24s
# 35:	learn: 0.1085696	total: 45.6s	remaining: 1m 27s
# 33:	learn: 0.0934280	total: 45.9s	remaining: 1m 35s
# 33:	learn: 0.1110013	total: 46.2s	remaining: 1m 36s
# 36:	learn: 0.1138017	total: 46.7s	remaining: 1m 25s
# 34:	learn: 0.1117737	total: 45.9s	remaining: 1m 31s
# 36:	learn: 0.1163040	total: 46.9s	remaining: 1m 26s
# 34:	learn: 0.1161040	total: 45.6s	remaining: 1m 31s
# 35:	learn: 0.1211510	total: 47.3s	remaining: 1m 30s
# 37:	learn: 0.1051568	total: 46.8s	remaining: 1m 22s
# 36:	learn: 0.1318272	total: 47.3s	remaining: 1m 26s
# 35:	learn: 0.1117017	total: 47s	remaining: 1m 30s
# 36:	learn: 0.1084970	total: 47.1s	remaining: 1m 26s
# 37:	learn: 0.1161908	total: 48.1s	remaining: 1m 24s
# 37:	learn: 0.1131829	total: 48s	remaining: 1m 24s
# 34:	learn: 0.1109242	total: 47.6s	remaining: 1m 35s
# 35:	learn: 0.1160168	total: 46.6s	remaining: 1m 29s
# 34:	learn: 0.0915380	total: 47.6s	remaining: 1m 35s
# 36:	learn: 0.1210803	total: 48.4s	remaining: 1m 28s
# 38:	learn: 0.1050923	total: 48s	remaining: 1m 21s
# 37:	learn: 0.1316887	total: 48.5s	remaining: 1m 25s
# 38:	learn: 0.1093839	total: 49s	remaining: 1m 22s
# 35:	learn: 0.0888439	total: 48.5s	remaining: 1m 32s
# 37:	learn: 0.1084274	total: 48.4s	remaining: 1m 25s
# 38:	learn: 0.1161163	total: 49.3s	remaining: 1m 23s
# 36:	learn: 0.1116357	total: 48.5s	remaining: 1m 29s
# 36:	learn: 0.1159357	total: 48s	remaining: 1m 28s
# 35:	learn: 0.1108504	total: 49.1s	remaining: 1m 34s
# 37:	learn: 0.1210184	total: 49.6s	remaining: 1m 27s
# 39:	learn: 0.1050122	total: 49s	remaining: 1m 19s
# 39:	learn: 0.1059279	total: 50.1s	remaining: 1m 21s
# 36:	learn: 0.0874937	total: 49.6s	remaining: 1m 31s
# 38:	learn: 0.1316023	total: 49.7s	remaining: 1m 24s
# 38:	learn: 0.1083601	total: 49.5s	remaining: 1m 23s
# 39:	learn: 0.1160435	total: 50.5s	remaining: 1m 22s
# 38:	learn: 0.1209494	total: 50.7s	remaining: 1m 25s
# 37:	learn: 0.1158590	total: 49.2s	remaining: 1m 26s
# 36:	learn: 0.1107814	total: 50.3s	remaining: 1m 32s
# 40:	learn: 0.1049515	total: 50.3s	remaining: 1m 18s
# 37:	learn: 0.1115714	total: 50.1s	remaining: 1m 28s
# 40:	learn: 0.1058086	total: 51.3s	remaining: 1m 20s
# 37:	learn: 0.0860692	total: 50.8s	remaining: 1m 29s
# 39:	learn: 0.1082745	total: 50.5s	remaining: 1m 22s
# 39:	learn: 0.1315235	total: 50.9s	remaining: 1m 22s
# 40:	learn: 0.1159716	total: 51.5s	remaining: 1m 20s
# 39:	learn: 0.1208882	total: 51.9s	remaining: 1m 24s
# 38:	learn: 0.1156883	total: 50.6s	remaining: 1m 25s
# 37:	learn: 0.1107132	total: 51.6s	remaining: 1m 30s
# 41:	learn: 0.1048369	total: 51.7s	remaining: 1m 17s
# 38:	learn: 0.1113023	total: 51.5s	remaining: 1m 27s
# 41:	learn: 0.1057505	total: 52.4s	remaining: 1m 18s
# 38:	learn: 0.0857241	total: 51.8s	remaining: 1m 27s
# 40:	learn: 0.1082085	total: 51.6s	remaining: 1m 20s
# 41:	learn: 0.1159059	total: 52.7s	remaining: 1m 19s
# 40:	learn: 0.1208281	total: 53.1s	remaining: 1m 22s
# 40:	learn: 0.1312592	total: 52.7s	remaining: 1m 22s
# 39:	learn: 0.1155486	total: 51.7s	remaining: 1m 24s
# 38:	learn: 0.1106473	total: 52.8s	remaining: 1m 29s
# 39:	learn: 0.1081811	total: 52.6s	remaining: 1m 25s
# 42:	learn: 0.1044778	total: 52.8s	remaining: 1m 16s
# 39:	learn: 0.0856406	total: 53.3s	remaining: 1m 26s
# 42:	learn: 0.1056919	total: 53.9s	remaining: 1m 17s
# 41:	learn: 0.1081271	total: 53.1s	remaining: 1m 19s
# 42:	learn: 0.1158423	total: 54.1s	remaining: 1m 17s
# 41:	learn: 0.1287830	total: 53.7s	remaining: 1m 20s
# 41:	learn: 0.1207657	total: 54.3s	remaining: 1m 21s
# 40:	learn: 0.1153075	total: 53s	remaining: 1m 22s
# 43:	learn: 0.1021332	total: 54s	remaining: 1m 14s
# 40:	learn: 0.1081250	total: 54.1s	remaining: 1m 24s
# 39:	learn: 0.1105826	total: 54.4s	remaining: 1m 28s
# 40:	learn: 0.0855506	total: 54.5s	remaining: 1m 25s
# 43:	learn: 0.1056429	total: 55.2s	remaining: 1m 16s
# 42:	learn: 0.1080666	total: 54.3s	remaining: 1m 18s
# 43:	learn: 0.1136027	total: 55.3s	remaining: 1m 16s
# 42:	learn: 0.1276485	total: 55.1s	remaining: 1m 19s
# 42:	learn: 0.1186909	total: 55.7s	remaining: 1m 20s
# 41:	learn: 0.1141328	total: 54.5s	remaining: 1m 21s
# 41:	learn: 0.1080171	total: 55.3s	remaining: 1m 22s
# 44:	learn: 0.1020804	total: 55.5s	remaining: 1m 14s
# 40:	learn: 0.1105202	total: 55.7s	remaining: 1m 26s
# 41:	learn: 0.0854803	total: 55.7s	remaining: 1m 23s
# 44:	learn: 0.1040229	total: 56.3s	remaining: 1m 15s
# 43:	learn: 0.1079839	total: 55.6s	remaining: 1m 17s
# 43:	learn: 0.1275656	total: 56s	remaining: 1m 17s
# 44:	learn: 0.1131526	total: 56.7s	remaining: 1m 15s
# 43:	learn: 0.1186312	total: 56.9s	remaining: 1m 18s
# 42:	learn: 0.1117094	total: 55.6s	remaining: 1m 20s
# 41:	learn: 0.1104578	total: 56.6s	remaining: 1m 24s
# 42:	learn: 0.1079482	total: 56.5s	remaining: 1m 21s
# 45:	learn: 0.1020291	total: 56.7s	remaining: 1m 12s
# 42:	learn: 0.0854334	total: 57s	remaining: 1m 22s
# 44:	learn: 0.1079071	total: 56.8s	remaining: 1m 15s
# 44:	learn: 0.1274726	total: 57.2s	remaining: 1m 16s
# 45:	learn: 0.1039793	total: 57.9s	remaining: 1m 14s
# 44:	learn: 0.1185782	total: 58s	remaining: 1m 17s
# 42:	learn: 0.1103956	total: 57.7s	remaining: 1m 23s
# 45:	learn: 0.1130928	total: 58.2s	remaining: 1m 14s
# 43:	learn: 0.1078993	total: 57.6s	remaining: 1m 19s
# 43:	learn: 0.1083579	total: 57s	remaining: 1m 19s
# 45:	learn: 0.1078198	total: 57.6s	remaining: 1m 13s
# 46:	learn: 0.1019824	total: 57.9s	remaining: 1m 11s
# 45:	learn: 0.1273999	total: 58.3s	remaining: 1m 14s
# 46:	learn: 0.1039399	total: 59.2s	remaining: 1m 13s
# 46:	learn: 0.1130401	total: 59.3s	remaining: 1m 13s
# 45:	learn: 0.1184785	total: 59.3s	remaining: 1m 16s
# 43:	learn: 0.1100103	total: 58.9s	remaining: 1m 21s
# 44:	learn: 0.1047583	total: 58.2s	remaining: 1m 17s
# 46:	learn: 0.1077192	total: 58.8s	remaining: 1m 12s
# 43:	learn: 0.0853753	total: 59.1s	remaining: 1m 21s
# 44:	learn: 0.1076935	total: 58.9s	remaining: 1m 18s
# 47:	learn: 0.1019358	total: 59.2s	remaining: 1m 10s
# 46:	learn: 0.1273297	total: 59.3s	remaining: 1m 13s
# 47:	learn: 0.1038534	total: 1m	remaining: 1m 11s
# 47:	learn: 0.1129877	total: 1m	remaining: 1m 11s
# 45:	learn: 0.1046327	total: 59.3s	remaining: 1m 16s
# 47:	learn: 0.1076181	total: 59.9s	remaining: 1m 11s
# 44:	learn: 0.1064194	total: 1m	remaining: 1m 20s
# 46:	learn: 0.1181502	total: 1m	remaining: 1m 15s
# 45:	learn: 0.1076330	total: 1m	remaining: 1m 17s
# 44:	learn: 0.0853310	total: 1m	remaining: 1m 20s
# 48:	learn: 0.1035467	total: 1m 1s	remaining: 1m 9s
# 47:	learn: 0.1220250	total: 1m	remaining: 1m 12s
# 48:	learn: 0.1018849	total: 1m	remaining: 1m 9s
# 48:	learn: 0.1129380	total: 1m 1s	remaining: 1m 10s
# 48:	learn: 0.1067076	total: 1m	remaining: 1m 9s
# 45:	learn: 0.1043373	total: 1m 1s	remaining: 1m 18s
# 46:	learn: 0.1045652	total: 1m	remaining: 1m 14s
# 47:	learn: 0.1179978	total: 1m 2s	remaining: 1m 13s
# 46:	learn: 0.1040273	total: 1m 1s	remaining: 1m 15s
# 48:	learn: 0.1188731	total: 1m 1s	remaining: 1m 10s
# 49:	learn: 0.1015840	total: 1m 2s	remaining: 1m 8s
# 45:	learn: 0.0852870	total: 1m 1s	remaining: 1m 19s
# 49:	learn: 0.1018425	total: 1m 1s	remaining: 1m 8s
# 49:	learn: 0.1128397	total: 1m 2s	remaining: 1m 8s
# 48:	learn: 0.1146570	total: 1m 3s	remaining: 1m 12s
# 49:	learn: 0.1066344	total: 1m 2s	remaining: 1m 8s
# 46:	learn: 0.1003533	total: 1m 2s	remaining: 1m 17s
# 47:	learn: 0.1044798	total: 1m 2s	remaining: 1m 13s
# 50:	learn: 0.1015362	total: 1m 3s	remaining: 1m 7s
# 46:	learn: 0.0852362	total: 1m 2s	remaining: 1m 17s
# 49:	learn: 0.1144291	total: 1m 3s	remaining: 1m 9s
# 50:	learn: 0.1018008	total: 1m 3s	remaining: 1m 6s
# 50:	learn: 0.1127919	total: 1m 3s	remaining: 1m 7s
# 47:	learn: 0.1039763	total: 1m 3s	remaining: 1m 15s
# 49:	learn: 0.1110989	total: 1m 4s	remaining: 1m 10s
# 47:	learn: 0.1002999	total: 1m 4s	remaining: 1m 16s
# 47:	learn: 0.0851976	total: 1m 3s	remaining: 1m 15s
# 51:	learn: 0.1001296	total: 1m 4s	remaining: 1m 5s
# 48:	learn: 0.1044246	total: 1m 3s	remaining: 1m 12s
# 50:	learn: 0.1042775	total: 1m 4s	remaining: 1m 7s
# 50:	learn: 0.1110388	total: 1m 4s	remaining: 1m 8s
# 51:	learn: 0.0991345	total: 1m 4s	remaining: 1m 5s
# 51:	learn: 0.1127477	total: 1m 5s	remaining: 1m 6s
# 48:	learn: 0.1012554	total: 1m 4s	remaining: 1m 13s
# 50:	learn: 0.1108036	total: 1m 5s	remaining: 1m 9s
# 48:	learn: 0.1002343	total: 1m 5s	remaining: 1m 14s
# 51:	learn: 0.1020277	total: 1m 5s	remaining: 1m 6s
# 51:	learn: 0.1079012	total: 1m 5s	remaining: 1m 6s
# 52:	learn: 0.0992201	total: 1m 6s	remaining: 1m 5s
# 52:	learn: 0.1091650	total: 1m 6s	remaining: 1m 4s
# 48:	learn: 0.0851556	total: 1m 5s	remaining: 1m 15s
# 52:	learn: 0.0990145	total: 1m 5s	remaining: 1m 4s
# 51:	learn: 0.1064546	total: 1m 6s	remaining: 1m 7s
# 49:	learn: 0.1043570	total: 1m 5s	remaining: 1m 11s
# 49:	learn: 0.0990316	total: 1m 5s	remaining: 1m 12s
# 49:	learn: 0.1001851	total: 1m 6s	remaining: 1m 13s
# 52:	learn: 0.1056903	total: 1m 6s	remaining: 1m 5s
# 53:	learn: 0.0962123	total: 1m 7s	remaining: 1m 3s
# 53:	learn: 0.1067786	total: 1m 7s	remaining: 1m 3s
# 53:	learn: 0.0989819	total: 1m 6s	remaining: 1m 3s
# 50:	learn: 0.0958173	total: 1m 6s	remaining: 1m 10s
# 52:	learn: 0.1040255	total: 1m 7s	remaining: 1m 6s
# 52:	learn: 0.0989973	total: 1m 7s	remaining: 1m 5s
# 49:	learn: 0.0851160	total: 1m 7s	remaining: 1m 13s
# 50:	learn: 0.1001219	total: 1m 7s	remaining: 1m 11s
# 50:	learn: 0.1013670	total: 1m 6s	remaining: 1m 10s
# 53:	learn: 0.1026787	total: 1m 7s	remaining: 1m 4s
# 51:	learn: 0.0930021	total: 1m 7s	remaining: 1m 9s
# 54:	learn: 0.1040073	total: 1m 8s	remaining: 1m 2s
# 54:	learn: 0.0989384	total: 1m 8s	remaining: 1m 1s
# 51:	learn: 0.1000727	total: 1m 8s	remaining: 1m 9s
# 51:	learn: 0.1012199	total: 1m 7s	remaining: 1m 8s
# 53:	learn: 0.1034933	total: 1m 9s	remaining: 1m 5s
# 53:	learn: 0.0958573	total: 1m 8s	remaining: 1m 4s
# 54:	learn: 0.0951697	total: 1m 9s	remaining: 1m 2s
# 50:	learn: 0.0850802	total: 1m 8s	remaining: 1m 12s
# 54:	learn: 0.0994485	total: 1m 8s	remaining: 1m 2s
# 52:	learn: 0.0997137	total: 1m 9s	remaining: 1m 7s
# 52:	learn: 0.0920483	total: 1m 8s	remaining: 1m 7s
# 55:	learn: 0.0989049	total: 1m 9s	remaining: 1m
# 55:	learn: 0.1007942	total: 1m 9s	remaining: 1m 1s
# 54:	learn: 0.0958092	total: 1m 9s	remaining: 1m 3s
# 52:	learn: 0.0976794	total: 1m 9s	remaining: 1m 7s
# 55:	learn: 0.0938048	total: 1m 10s	remaining: 1m 1s
# 53:	learn: 0.0996714	total: 1m 10s	remaining: 1m 6s
# 51:	learn: 0.0848344	total: 1m 10s	remaining: 1m 11s
# 56:	learn: 0.0988491	total: 1m 10s	remaining: 59.3s
# 54:	learn: 0.1025833	total: 1m 11s	remaining: 1m 4s
# 56:	learn: 0.0980055	total: 1m 11s	remaining: 59.9s
# 53:	learn: 0.0903074	total: 1m 10s	remaining: 1m 6s
# 53:	learn: 0.0974217	total: 1m 10s	remaining: 1m 6s
# 56:	learn: 0.0913394	total: 1m 11s	remaining: 1m
# 55:	learn: 0.0957453	total: 1m 10s	remaining: 1m 2s
# 55:	learn: 0.0962284	total: 1m 11s	remaining: 1m 2s
# 54:	learn: 0.0996313	total: 1m 11s	remaining: 1m 5s
# 52:	learn: 0.0846769	total: 1m 11s	remaining: 1m 9s
# 57:	learn: 0.0988211	total: 1m 11s	remaining: 58.1s
# 54:	learn: 0.0872439	total: 1m 11s	remaining: 1m 5s
# 55:	learn: 0.1024751	total: 1m 12s	remaining: 1m 3s
# 57:	learn: 0.0957464	total: 1m 12s	remaining: 58.6s
# 55:	learn: 0.0965595	total: 1m 12s	remaining: 1m 3s
# 54:	learn: 0.0949455	total: 1m 11s	remaining: 1m 4s
# 57:	learn: 0.0912785	total: 1m 12s	remaining: 59s
# 55:	learn: 0.0848589	total: 1m 12s	remaining: 1m 3s
# 56:	learn: 0.0943256	total: 1m 12s	remaining: 1m 1s
# 53:	learn: 0.0822391	total: 1m 12s	remaining: 1m 8s
# 56:	learn: 0.0957018	total: 1m 12s	remaining: 1m 1s
# 58:	learn: 0.0987343	total: 1m 12s	remaining: 56.8s
# 56:	learn: 0.0964941	total: 1m 13s	remaining: 1m 1s
# 58:	learn: 0.0953152	total: 1m 13s	remaining: 57.5s
# 56:	learn: 0.0996977	total: 1m 14s	remaining: 1m 2s
# 58:	learn: 0.0894883	total: 1m 13s	remaining: 57.6s
# 55:	learn: 0.0919247	total: 1m 12s	remaining: 1m 3s
# 57:	learn: 0.0920805	total: 1m 13s	remaining: 59.8s
# 54:	learn: 0.0821934	total: 1m 13s	remaining: 1m 6s
# 56:	learn: 0.0830384	total: 1m 13s	remaining: 1m 2s
# 57:	learn: 0.0954262	total: 1m 14s	remaining: 60s
# 59:	learn: 0.0956929	total: 1m 14s	remaining: 55.6s
# 59:	learn: 0.0869280	total: 1m 14s	remaining: 56s
# 59:	learn: 0.0929970	total: 1m 14s	remaining: 56.1s
# 57:	learn: 0.0964582	total: 1m 14s	remaining: 1m
# 58:	learn: 0.0918606	total: 1m 14s	remaining: 58.4s
# 57:	learn: 0.0968322	total: 1m 15s	remaining: 1m 1s
# 56:	learn: 0.0912243	total: 1m 14s	remaining: 1m 2s
# 55:	learn: 0.0821652	total: 1m 14s	remaining: 1m 5s
# 58:	learn: 0.0952629	total: 1m 15s	remaining: 58.5s
# 57:	learn: 0.0808853	total: 1m 14s	remaining: 1m
# 60:	learn: 0.0937662	total: 1m 15s	remaining: 54.4s
# 60:	learn: 0.0851063	total: 1m 16s	remaining: 55s
# 58:	learn: 0.0964260	total: 1m 15s	remaining: 59.2s
# 58:	learn: 0.0950310	total: 1m 16s	remaining: 59.7s
# 60:	learn: 0.0909471	total: 1m 16s	remaining: 55.2s
# 56:	learn: 0.0821370	total: 1m 15s	remaining: 1m 3s
# 59:	learn: 0.0916295	total: 1m 16s	remaining: 57.2s
# 58:	learn: 0.0792689	total: 1m 16s	remaining: 59.4s
# 57:	learn: 0.0909979	total: 1m 15s	remaining: 1m 1s
# 59:	learn: 0.0929049	total: 1m 16s	remaining: 57.4s
# 61:	learn: 0.0928757	total: 1m 16s	remaining: 53.2s
# 61:	learn: 0.0834617	total: 1m 17s	remaining: 53.6s
# 59:	learn: 0.0933221	total: 1m 17s	remaining: 58.1s
# 59:	learn: 0.0963704	total: 1m 17s	remaining: 57.9s
# 57:	learn: 0.0820984	total: 1m 16s	remaining: 1m 2s
# 60:	learn: 0.0892161	total: 1m 17s	remaining: 55.8s
# 61:	learn: 0.0882969	total: 1m 17s	remaining: 54s
# 59:	learn: 0.0776633	total: 1m 17s	remaining: 58.1s
# 60:	learn: 0.0928618	total: 1m 17s	remaining: 56.1s
# 62:	learn: 0.0819147	total: 1m 18s	remaining: 52.2s
# 58:	learn: 0.0909325	total: 1m 17s	remaining: 1m
# 62:	learn: 0.0901388	total: 1m 18s	remaining: 52s
# 58:	learn: 0.0820712	total: 1m 17s	remaining: 1m
# 61:	learn: 0.0889623	total: 1m 18s	remaining: 54.4s
# 60:	learn: 0.0931833	total: 1m 19s	remaining: 57s
# 60:	learn: 0.0963404	total: 1m 18s	remaining: 56.8s
# 62:	learn: 0.0868890	total: 1m 19s	remaining: 52.7s
# 59:	learn: 0.0908712	total: 1m 18s	remaining: 58.6s
# 61:	learn: 0.0925251	total: 1m 18s	remaining: 54.8s
# 63:	learn: 0.0807927	total: 1m 19s	remaining: 50.9s
# 60:	learn: 0.0764659	total: 1m 18s	remaining: 57s
# 61:	learn: 0.0962603	total: 1m 19s	remaining: 55.3s
# 63:	learn: 0.0881217	total: 1m 19s	remaining: 50.9s
# 63:	learn: 0.0852412	total: 1m 20s	remaining: 51.4s
# 59:	learn: 0.0820441	total: 1m 19s	remaining: 59.6s
# 62:	learn: 0.0882889	total: 1m 20s	remaining: 53.3s
# 61:	learn: 0.0903004	total: 1m 20s	remaining: 55.9s
# 64:	learn: 0.0790758	total: 1m 20s	remaining: 49.6s
# 61:	learn: 0.0760140	total: 1m 20s	remaining: 55.5s
# 60:	learn: 0.0908275	total: 1m 19s	remaining: 57.4s
# 64:	learn: 0.0880593	total: 1m 20s	remaining: 49.5s
# 62:	learn: 0.0924161	total: 1m 20s	remaining: 53.7s
# 64:	learn: 0.0827485	total: 1m 21s	remaining: 50s
# 62:	learn: 0.0953177	total: 1m 21s	remaining: 54.2s
# 62:	learn: 0.0901845	total: 1m 21s	remaining: 54.6s
# 62:	learn: 0.0754993	total: 1m 21s	remaining: 54.2s
# 63:	learn: 0.0881574	total: 1m 21s	remaining: 52.2s
# 65:	learn: 0.0774905	total: 1m 21s	remaining: 48.5s
# 63:	learn: 0.0908660	total: 1m 21s	remaining: 52.2s
# 60:	learn: 0.0820198	total: 1m 21s	remaining: 58.6s
# 61:	learn: 0.0907689	total: 1m 20s	remaining: 56.1s
# 65:	learn: 0.0815485	total: 1m 22s	remaining: 48.6s
# 65:	learn: 0.0880287	total: 1m 21s	remaining: 48.3s
# 64:	learn: 0.0880159	total: 1m 22s	remaining: 50.8s
# 63:	learn: 0.0931697	total: 1m 22s	remaining: 52.9s
# 63:	learn: 0.0900482	total: 1m 23s	remaining: 53.3s
# 63:	learn: 0.0754019	total: 1m 22s	remaining: 52.8s
# 62:	learn: 0.0907319	total: 1m 22s	remaining: 54.8s
# 64:	learn: 0.0908226	total: 1m 23s	remaining: 51.1s
# 61:	learn: 0.0819861	total: 1m 22s	remaining: 57.3s
# 66:	learn: 0.0789643	total: 1m 23s	remaining: 47.5s
# 66:	learn: 0.0880025	total: 1m 23s	remaining: 47.1s
# 66:	learn: 0.0760440	total: 1m 23s	remaining: 47.6s
# 65:	learn: 0.0879700	total: 1m 23s	remaining: 49.3s
# 64:	learn: 0.0907346	total: 1m 23s	remaining: 51.5s
# 64:	learn: 0.0883386	total: 1m 24s	remaining: 52s
# 64:	learn: 0.0753754	total: 1m 23s	remaining: 51.5s
# 63:	learn: 0.0884291	total: 1m 23s	remaining: 53.3s
# 62:	learn: 0.0799041	total: 1m 23s	remaining: 55.8s
# 67:	learn: 0.0768636	total: 1m 24s	remaining: 46.1s
# 67:	learn: 0.0879749	total: 1m 24s	remaining: 45.7s
# 66:	learn: 0.0879286	total: 1m 24s	remaining: 48s
# 65:	learn: 0.0753399	total: 1m 24s	remaining: 50s
# 67:	learn: 0.0759688	total: 1m 25s	remaining: 46.4s
# 65:	learn: 0.0884556	total: 1m 25s	remaining: 50.3s
# 65:	learn: 0.0907812	total: 1m 25s	remaining: 50.3s
# 64:	learn: 0.0883880	total: 1m 24s	remaining: 51.9s
# 68:	learn: 0.0879496	total: 1m 25s	remaining: 44.4s
# 65:	learn: 0.0861803	total: 1m 25s	remaining: 50.8s
# 63:	learn: 0.0795496	total: 1m 24s	remaining: 54.4s
# 68:	learn: 0.0753515	total: 1m 25s	remaining: 44.8s
# 67:	learn: 0.0878843	total: 1m 25s	remaining: 46.8s
# 66:	learn: 0.0753105	total: 1m 26s	remaining: 48.8s
# 66:	learn: 0.0861243	total: 1m 26s	remaining: 49s
# 66:	learn: 0.0907272	total: 1m 26s	remaining: 48.9s
# 68:	learn: 0.0739199	total: 1m 26s	remaining: 45.3s
# 65:	learn: 0.0882735	total: 1m 25s	remaining: 50.6s
# 69:	learn: 0.0877347	total: 1m 26s	remaining: 43.1s
# 69:	learn: 0.0749212	total: 1m 26s	remaining: 43.5s
# 66:	learn: 0.0838827	total: 1m 27s	remaining: 49.4s
# 64:	learn: 0.0794944	total: 1m 26s	remaining: 53.2s
# 67:	learn: 0.0851508	total: 1m 27s	remaining: 47.5s
# 68:	learn: 0.0877220	total: 1m 27s	remaining: 45.6s
# 70:	learn: 0.0859108	total: 1m 27s	remaining: 41.8s
# 67:	learn: 0.0752802	total: 1m 27s	remaining: 47.6s
# 69:	learn: 0.0720518	total: 1m 28s	remaining: 44s
# 66:	learn: 0.0856936	total: 1m 26s	remaining: 49.3s
# 70:	learn: 0.0737363	total: 1m 28s	remaining: 42.2s
# 67:	learn: 0.0906894	total: 1m 27s	remaining: 47.8s
# 67:	learn: 0.0825214	total: 1m 28s	remaining: 48.2s
# 65:	learn: 0.0776444	total: 1m 27s	remaining: 51.7s
# 68:	learn: 0.0836781	total: 1m 28s	remaining: 46.2s
# 69:	learn: 0.0876751	total: 1m 28s	remaining: 44.2s
# 68:	learn: 0.0752517	total: 1m 28s	remaining: 46s
# 67:	learn: 0.0855366	total: 1m 27s	remaining: 47.8s
# 71:	learn: 0.0858867	total: 1m 28s	remaining: 40.6s
# 70:	learn: 0.0703858	total: 1m 29s	remaining: 42.8s
# 66:	learn: 0.0774681	total: 1m 28s	remaining: 50.3s
# 68:	learn: 0.0906336	total: 1m 29s	remaining: 46.5s
# 68:	learn: 0.0823168	total: 1m 29s	remaining: 46.9s
# 71:	learn: 0.0731509	total: 1m 29s	remaining: 41.1s
# 70:	learn: 0.0875252	total: 1m 29s	remaining: 42.9s
# 69:	learn: 0.0824619	total: 1m 29s	remaining: 44.9s
# 68:	learn: 0.0838383	total: 1m 29s	remaining: 46.5s
# 72:	learn: 0.0845104	total: 1m 29s	remaining: 39.4s
# 69:	learn: 0.0752250	total: 1m 29s	remaining: 45s
# 71:	learn: 0.0685577	total: 1m 30s	remaining: 41.6s
# 67:	learn: 0.0773002	total: 1m 30s	remaining: 49s
# 69:	learn: 0.0821037	total: 1m 31s	remaining: 45.6s
# 69:	learn: 0.0888083	total: 1m 30s	remaining: 45.2s
# 71:	learn: 0.0872850	total: 1m 30s	remaining: 41.5s
# 72:	learn: 0.0730918	total: 1m 31s	remaining: 39.9s
# 70:	learn: 0.0812664	total: 1m 31s	remaining: 43.6s
# 70:	learn: 0.0751991	total: 1m 30s	remaining: 43.6s
# 69:	learn: 0.0816034	total: 1m 30s	remaining: 45.2s
# 70:	learn: 0.0801263	total: 1m 32s	remaining: 44.1s
# 73:	learn: 0.0841745	total: 1m 31s	remaining: 38.2s
# 68:	learn: 0.0772370	total: 1m 31s	remaining: 47.5s
# 72:	learn: 0.0679722	total: 1m 32s	remaining: 40.3s
# 72:	learn: 0.0871387	total: 1m 31s	remaining: 40.2s
# 70:	learn: 0.0881374	total: 1m 31s	remaining: 44s
# 73:	learn: 0.0730507	total: 1m 32s	remaining: 38.7s
# 71:	learn: 0.0733121	total: 1m 31s	remaining: 42.1s
# 71:	learn: 0.0794731	total: 1m 32s	remaining: 42.5s
# 70:	learn: 0.0806310	total: 1m 31s	remaining: 44s
# 69:	learn: 0.0771869	total: 1m 32s	remaining: 46.2s
# 74:	learn: 0.0841522	total: 1m 32s	remaining: 37s
# 71:	learn: 0.0793616	total: 1m 33s	remaining: 42.9s
# 73:	learn: 0.0667119	total: 1m 33s	remaining: 39.1s
# 71:	learn: 0.0881087	total: 1m 32s	remaining: 42.6s
# 73:	learn: 0.0868153	total: 1m 33s	remaining: 39s
# 74:	learn: 0.0730215	total: 1m 33s	remaining: 37.4s
# 72:	learn: 0.0731359	total: 1m 33s	remaining: 40.9s
# 72:	learn: 0.0787667	total: 1m 34s	remaining: 41.2s
# 75:	learn: 0.0837362	total: 1m 33s	remaining: 35.8s
# 74:	learn: 0.0866212	total: 1m 34s	remaining: 37.7s
# 74:	learn: 0.0662939	total: 1m 34s	remaining: 37.9s
# 72:	learn: 0.0880790	total: 1m 34s	remaining: 41.3s
# 70:	learn: 0.0771474	total: 1m 33s	remaining: 45s
# 71:	learn: 0.0786706	total: 1m 33s	remaining: 42.8s
# 75:	learn: 0.0729897	total: 1m 34s	remaining: 36.2s
# 72:	learn: 0.0792192	total: 1m 35s	remaining: 41.7s
# 73:	learn: 0.0731141	total: 1m 34s	remaining: 39.5s
# 73:	learn: 0.0774739	total: 1m 35s	remaining: 39.8s
# 76:	learn: 0.0816970	total: 1m 35s	remaining: 34.6s
# 72:	learn: 0.0785398	total: 1m 34s	remaining: 41.4s
# 73:	learn: 0.0880381	total: 1m 35s	remaining: 39.9s
# 71:	learn: 0.0770112	total: 1m 35s	remaining: 43.6s
# 75:	learn: 0.0847556	total: 1m 35s	remaining: 36.5s
# 74:	learn: 0.0730901	total: 1m 35s	remaining: 38.2s
# 73:	learn: 0.0791229	total: 1m 36s	remaining: 40.4s
# 75:	learn: 0.0640476	total: 1m 36s	remaining: 36.7s
# 76:	learn: 0.0729487	total: 1m 36s	remaining: 35s
# 74:	learn: 0.0761354	total: 1m 36s	remaining: 38.6s
# 72:	learn: 0.0756845	total: 1m 36s	remaining: 42.1s
# 73:	learn: 0.0772451	total: 1m 35s	remaining: 40.1s
# 74:	learn: 0.0878289	total: 1m 36s	remaining: 38.6s
# 76:	learn: 0.0845970	total: 1m 36s	remaining: 35.2s
# 75:	learn: 0.0730213	total: 1m 36s	remaining: 36.9s
# 76:	learn: 0.0630219	total: 1m 37s	remaining: 35.4s
# 77:	learn: 0.0799087	total: 1m 36s	remaining: 33.4s
# 77:	learn: 0.0729202	total: 1m 37s	remaining: 33.8s
# 74:	learn: 0.0790811	total: 1m 38s	remaining: 39.3s
# 74:	learn: 0.0749965	total: 1m 36s	remaining: 38.7s
# 75:	learn: 0.0748998	total: 1m 37s	remaining: 37.3s
# 73:	learn: 0.0733006	total: 1m 37s	remaining: 40.8s
# 75:	learn: 0.0867441	total: 1m 37s	remaining: 37.3s
# 77:	learn: 0.0829993	total: 1m 37s	remaining: 33.9s
# 77:	learn: 0.0622824	total: 1m 38s	remaining: 34.1s
# 78:	learn: 0.0782053	total: 1m 37s	remaining: 32.2s
# 76:	learn: 0.0729817	total: 1m 37s	remaining: 35.6s
# 78:	learn: 0.0728954	total: 1m 39s	remaining: 32.6s
# 76:	learn: 0.0746786	total: 1m 38s	remaining: 35.9s
# 75:	learn: 0.0734920	total: 1m 37s	remaining: 37.3s
# 74:	learn: 0.0719997	total: 1m 38s	remaining: 39.3s
# 75:	learn: 0.0789729	total: 1m 39s	remaining: 38s
# 76:	learn: 0.0856792	total: 1m 38s	remaining: 36s
# 77:	learn: 0.0722381	total: 1m 39s	remaining: 34.3s
# 78:	learn: 0.0622222	total: 1m 39s	remaining: 32.9s
# 78:	learn: 0.0829683	total: 1m 39s	remaining: 32.7s
# 79:	learn: 0.0763315	total: 1m 39s	remaining: 31s
# 77:	learn: 0.0728965	total: 1m 39s	remaining: 34.6s
# 76:	learn: 0.0728671	total: 1m 39s	remaining: 36s
# 79:	learn: 0.0728708	total: 1m 40s	remaining: 31.3s
# 75:	learn: 0.0706514	total: 1m 39s	remaining: 38s
# 76:	learn: 0.0788514	total: 1m 40s	remaining: 36.7s
# 77:	learn: 0.0826501	total: 1m 40s	remaining: 34.7s
# 79:	learn: 0.0608920	total: 1m 40s	remaining: 31.5s
# 78:	learn: 0.0719939	total: 1m 40s	remaining: 33s
# 80:	learn: 0.0761645	total: 1m 40s	remaining: 29.7s
# 79:	learn: 0.0829385	total: 1m 40s	remaining: 31.4s
# 77:	learn: 0.0725490	total: 1m 40s	remaining: 34.7s
# 77:	learn: 0.0787463	total: 1m 41s	remaining: 35.3s
# 78:	learn: 0.0728449	total: 1m 41s	remaining: 33.4s
# 76:	learn: 0.0687621	total: 1m 40s	remaining: 36.7s
# 80:	learn: 0.0714333	total: 1m 41s	remaining: 30.2s
# 79:	learn: 0.0703399	total: 1m 41s	remaining: 31.6s
# 80:	learn: 0.0608389	total: 1m 42s	remaining: 30.2s
# 78:	learn: 0.0809582	total: 1m 41s	remaining: 33.4s
# 80:	learn: 0.0818369	total: 1m 41s	remaining: 30.2s
# 81:	learn: 0.0761208	total: 1m 41s	remaining: 28.5s
# 77:	learn: 0.0678415	total: 1m 41s	remaining: 35.2s
# 78:	learn: 0.0785967	total: 1m 43s	remaining: 33.9s
# 78:	learn: 0.0725039	total: 1m 41s	remaining: 33.5s
# 81:	learn: 0.0607311	total: 1m 43s	remaining: 28.9s
# 81:	learn: 0.0713807	total: 1m 43s	remaining: 28.9s
# 79:	learn: 0.0727789	total: 1m 42s	remaining: 32.2s
# 79:	learn: 0.0789051	total: 1m 42s	remaining: 32.1s
# 80:	learn: 0.0702864	total: 1m 42s	remaining: 30.5s
# 82:	learn: 0.0760977	total: 1m 42s	remaining: 27.3s
# 81:	learn: 0.0817756	total: 1m 43s	remaining: 28.9s
# 78:	learn: 0.0677338	total: 1m 43s	remaining: 33.9s
# 79:	learn: 0.0704796	total: 1m 42s	remaining: 32.1s
# 82:	learn: 0.0592434	total: 1m 44s	remaining: 27.7s
# 79:	learn: 0.0785335	total: 1m 44s	remaining: 32.7s
# 82:	learn: 0.0713425	total: 1m 44s	remaining: 27.7s
# 80:	learn: 0.0786878	total: 1m 43s	remaining: 30.8s
# 82:	learn: 0.0816683	total: 1m 44s	remaining: 27.6s
# 81:	learn: 0.0686929	total: 1m 43s	remaining: 29.2s
# 83:	learn: 0.0760803	total: 1m 44s	remaining: 26.1s
# 80:	learn: 0.0726464	total: 1m 44s	remaining: 31s
# 79:	learn: 0.0663319	total: 1m 44s	remaining: 32.6s
# 83:	learn: 0.0711907	total: 1m 45s	remaining: 26.4s
# 80:	learn: 0.0769122	total: 1m 45s	remaining: 31.4s
# 81:	learn: 0.0770818	total: 1m 45s	remaining: 29.5s
# 80:	learn: 0.0703963	total: 1m 44s	remaining: 30.9s
# 82:	learn: 0.0685552	total: 1m 45s	remaining: 27.9s
# 83:	learn: 0.0589494	total: 1m 45s	remaining: 26.5s
# 84:	learn: 0.0759128	total: 1m 45s	remaining: 24.8s
# 81:	learn: 0.0726046	total: 1m 45s	remaining: 29.7s
# 83:	learn: 0.0797318	total: 1m 45s	remaining: 26.5s
# 80:	learn: 0.0661840	total: 1m 45s	remaining: 31.3s
# 83:	learn: 0.0684288	total: 1m 45s	remaining: 26.5s
# 81:	learn: 0.0678676	total: 1m 45s	remaining: 29.6s
# 82:	learn: 0.0770341	total: 1m 46s	remaining: 28.2s
# 82:	learn: 0.0725634	total: 1m 46s	remaining: 28.3s
# 84:	learn: 0.0589224	total: 1m 47s	remaining: 25.2s
# 84:	learn: 0.0696151	total: 1m 47s	remaining: 25.2s
# 81:	learn: 0.0750183	total: 1m 47s	remaining: 30.1s
# 84:	learn: 0.0785187	total: 1m 46s	remaining: 25.2s
# 85:	learn: 0.0748406	total: 1m 47s	remaining: 23.7s
# 81:	learn: 0.0653915	total: 1m 47s	remaining: 30s
# 85:	learn: 0.0588957	total: 1m 48s	remaining: 23.9s
# 82:	learn: 0.0665853	total: 1m 46s	remaining: 28.3s
# 82:	learn: 0.0731890	total: 1m 48s	remaining: 28.7s
# 83:	learn: 0.0725434	total: 1m 47s	remaining: 27s
# 83:	learn: 0.0766964	total: 1m 47s	remaining: 27s
# 85:	learn: 0.0682921	total: 1m 48s	remaining: 23.9s
# 84:	learn: 0.0668608	total: 1m 47s	remaining: 25.4s
# 85:	learn: 0.0782747	total: 1m 48s	remaining: 23.9s
# 83:	learn: 0.0648295	total: 1m 47s	remaining: 26.9s
# 82:	learn: 0.0653573	total: 1m 48s	remaining: 28.7s
# 84:	learn: 0.0766700	total: 1m 48s	remaining: 25.6s
# 86:	learn: 0.0577427	total: 1m 49s	remaining: 22.6s
# 86:	learn: 0.0729825	total: 1m 48s	remaining: 22.5s
# 84:	learn: 0.0723751	total: 1m 49s	remaining: 25.7s
# 83:	learn: 0.0711504	total: 1m 49s	remaining: 27.4s
# 86:	learn: 0.0680635	total: 1m 49s	remaining: 22.7s
# 86:	learn: 0.0782495	total: 1m 49s	remaining: 22.6s
# 84:	learn: 0.0633968	total: 1m 48s	remaining: 25.6s
# 85:	learn: 0.0666438	total: 1m 49s	remaining: 24.2s
# 83:	learn: 0.0651162	total: 1m 49s	remaining: 27.4s
# 87:	learn: 0.0576666	total: 1m 50s	remaining: 21.4s
# 85:	learn: 0.0766213	total: 1m 50s	remaining: 24.3s
# 84:	learn: 0.0710986	total: 1m 50s	remaining: 26.1s
# 87:	learn: 0.0722007	total: 1m 50s	remaining: 21.2s
# 85:	learn: 0.0722226	total: 1m 50s	remaining: 24.5s
# 85:	learn: 0.0622195	total: 1m 49s	remaining: 24.3s
# 87:	learn: 0.0782235	total: 1m 50s	remaining: 21.3s
# 87:	learn: 0.0680260	total: 1m 51s	remaining: 21.5s
# 85:	learn: 0.0693484	total: 1m 51s	remaining: 24.7s
# 84:	learn: 0.0650600	total: 1m 50s	remaining: 26.1s
# 86:	learn: 0.0750549	total: 1m 51s	remaining: 23s
# 88:	learn: 0.0710631	total: 1m 51s	remaining: 20s
# 86:	learn: 0.0666209	total: 1m 51s	remaining: 23s
# 88:	learn: 0.0576519	total: 1m 52s	remaining: 20.2s
# 86:	learn: 0.0699903	total: 1m 51s	remaining: 23.1s
# 86:	learn: 0.0611145	total: 1m 50s	remaining: 22.9s
# 88:	learn: 0.0782021	total: 1m 51s	remaining: 20s
# 88:	learn: 0.0663401	total: 1m 52s	remaining: 20.2s
# 86:	learn: 0.0692472	total: 1m 52s	remaining: 23.3s
# 85:	learn: 0.0646338	total: 1m 51s	remaining: 24.7s
# 87:	learn: 0.0730997	total: 1m 52s	remaining: 21.7s
# 89:	learn: 0.0708277	total: 1m 52s	remaining: 18.7s
# 87:	learn: 0.0665352	total: 1m 52s	remaining: 21.7s
# 89:	learn: 0.0576077	total: 1m 53s	remaining: 18.9s
# 87:	learn: 0.0679633	total: 1m 53s	remaining: 21.9s
# 89:	learn: 0.0663114	total: 1m 53s	remaining: 18.9s
# 89:	learn: 0.0779374	total: 1m 52s	remaining: 18.8s
# 87:	learn: 0.0609724	total: 1m 52s	remaining: 21.7s
# 87:	learn: 0.0680397	total: 1m 54s	remaining: 22s
# 88:	learn: 0.0714462	total: 1m 53s	remaining: 20.4s
# 86:	learn: 0.0636868	total: 1m 53s	remaining: 23.4s
# 90:	learn: 0.0694349	total: 1m 53s	remaining: 17.5s
# 90:	learn: 0.0575935	total: 1m 54s	remaining: 17.6s
# 90:	learn: 0.0757133	total: 1m 53s	remaining: 17.5s
# 88:	learn: 0.0650049	total: 1m 53s	remaining: 20.4s
# 90:	learn: 0.0645584	total: 1m 54s	remaining: 17.7s
# 88:	learn: 0.0597518	total: 1m 53s	remaining: 20.4s
# 88:	learn: 0.0680050	total: 1m 55s	remaining: 20.7s
# 88:	learn: 0.0663365	total: 1m 54s	remaining: 20.6s
# 91:	learn: 0.0679585	total: 1m 54s	remaining: 16.2s
# 87:	learn: 0.0629420	total: 1m 54s	remaining: 22.1s
# 89:	learn: 0.0695198	total: 1m 54s	remaining: 19.2s
# 89:	learn: 0.0642796	total: 1m 54s	remaining: 19.2s
# 91:	learn: 0.0738304	total: 1m 55s	remaining: 16.3s
# 91:	learn: 0.0575271	total: 1m 55s	remaining: 16.4s
# 89:	learn: 0.0679247	total: 1m 56s	remaining: 19.4s
# 89:	learn: 0.0651786	total: 1m 55s	remaining: 19.3s
# 89:	learn: 0.0583609	total: 1m 54s	remaining: 19.1s
# 91:	learn: 0.0633678	total: 1m 56s	remaining: 16.5s
# 92:	learn: 0.0669169	total: 1m 55s	remaining: 14.9s
# 90:	learn: 0.0642482	total: 1m 56s	remaining: 17.9s
# 90:	learn: 0.0679332	total: 1m 56s	remaining: 17.9s
# 88:	learn: 0.0628835	total: 1m 56s	remaining: 20.9s
# 90:	learn: 0.0677839	total: 1m 57s	remaining: 18s
# 92:	learn: 0.0564246	total: 1m 57s	remaining: 15.1s
# 90:	learn: 0.0571350	total: 1m 55s	remaining: 17.8s
# 92:	learn: 0.0723801	total: 1m 56s	remaining: 15.1s
# 90:	learn: 0.0642775	total: 1m 57s	remaining: 18s
# 92:	learn: 0.0632423	total: 1m 57s	remaining: 15.2s
# 93:	learn: 0.0658364	total: 1m 56s	remaining: 13.7s
# 89:	learn: 0.0627761	total: 1m 57s	remaining: 19.5s
# 91:	learn: 0.0671910	total: 1m 57s	remaining: 16.7s
# 93:	learn: 0.0563037	total: 1m 58s	remaining: 13.9s
# 91:	learn: 0.0677119	total: 1m 58s	remaining: 16.8s
# 93:	learn: 0.0706501	total: 1m 57s	remaining: 13.8s
# 91:	learn: 0.0562091	total: 1m 57s	remaining: 16.6s
# 91:	learn: 0.0641191	total: 1m 58s	remaining: 16.7s
# 93:	learn: 0.0632001	total: 1m 58s	remaining: 13.9s
# 94:	learn: 0.0645549	total: 1m 58s	remaining: 12.4s
# 90:	learn: 0.0615030	total: 1m 58s	remaining: 18.2s
# 92:	learn: 0.0666843	total: 1m 58s	remaining: 15.3s
# 91:	learn: 0.0640820	total: 1m 58s	remaining: 16.8s
# 94:	learn: 0.0560890	total: 1m 59s	remaining: 12.6s
# 94:	learn: 0.0699813	total: 1m 59s	remaining: 12.5s
# 92:	learn: 0.0640652	total: 1m 59s	remaining: 15.4s
# 92:	learn: 0.0676589	total: 2m	remaining: 15.5s
# 95:	learn: 0.0639489	total: 1m 59s	remaining: 11.2s
# 94:	learn: 0.0631791	total: 2m	remaining: 12.7s
# 91:	learn: 0.0599550	total: 1m 59s	remaining: 16.9s
# 92:	learn: 0.0546177	total: 1m 59s	remaining: 15.4s
# 93:	learn: 0.0666227	total: 1m 59s	remaining: 14s
# 92:	learn: 0.0640161	total: 1m 59s	remaining: 15.5s
# 93:	learn: 0.0640177	total: 2m	remaining: 14.1s
# 96:	learn: 0.0639047	total: 2m	remaining: 9.91s
# 95:	learn: 0.0699428	total: 2m	remaining: 11.3s
# 93:	learn: 0.0676194	total: 2m 1s	remaining: 14.2s
# 95:	learn: 0.0556131	total: 2m 1s	remaining: 11.4s
# 92:	learn: 0.0591677	total: 2m	remaining: 15.6s
# 94:	learn: 0.0656312	total: 2m 1s	remaining: 12.7s
# 95:	learn: 0.0619759	total: 2m 1s	remaining: 11.4s
# 93:	learn: 0.0639183	total: 2m 1s	remaining: 14.2s
# 93:	learn: 0.0535994	total: 2m	remaining: 14.1s
# 96:	learn: 0.0699203	total: 2m 1s	remaining: 10s
# 97:	learn: 0.0625130	total: 2m 1s	remaining: 8.67s
# 94:	learn: 0.0637901	total: 2m 1s	remaining: 12.8s
# 94:	learn: 0.0675797	total: 2m 2s	remaining: 12.9s
# 96:	learn: 0.0549646	total: 2m 2s	remaining: 10.1s
# 95:	learn: 0.0650632	total: 2m 2s	remaining: 11.5s
# 94:	learn: 0.0623691	total: 2m 2s	remaining: 12.9s
# 94:	learn: 0.0530031	total: 2m 1s	remaining: 12.8s
# 93:	learn: 0.0579729	total: 2m 2s	remaining: 14.3s
# 97:	learn: 0.0698980	total: 2m 2s	remaining: 8.73s
# 96:	learn: 0.0618242	total: 2m 3s	remaining: 10.2s
# 95:	learn: 0.0624501	total: 2m 2s	remaining: 11.5s
# 98:	learn: 0.0612172	total: 2m 2s	remaining: 7.44s
# 97:	learn: 0.0549328	total: 2m 3s	remaining: 8.84s
# 95:	learn: 0.0675414	total: 2m 3s	remaining: 11.6s
# 96:	learn: 0.0636151	total: 2m 3s	remaining: 10.2s
# 94:	learn: 0.0574442	total: 2m 3s	remaining: 13s
# 95:	learn: 0.0610012	total: 2m 3s	remaining: 11.6s
# 96:	learn: 0.0623419	total: 2m 3s	remaining: 10.2s
# 95:	learn: 0.0525681	total: 2m 3s	remaining: 11.5s
# 98:	learn: 0.0698662	total: 2m 3s	remaining: 7.5s
# 97:	learn: 0.0617973	total: 2m 4s	remaining: 8.9s
# 98:	learn: 0.0548871	total: 2m 4s	remaining: 7.56s
# 96:	learn: 0.0667830	total: 2m 4s	remaining: 10.3s
# 99:	learn: 0.0600578	total: 2m 4s	remaining: 6.22s
# 96:	learn: 0.0594708	total: 2m 4s	remaining: 10.3s
# 97:	learn: 0.0617997	total: 2m 4s	remaining: 8.9s
# 95:	learn: 0.0558633	total: 2m 4s	remaining: 11.6s
# 96:	learn: 0.0524681	total: 2m 4s	remaining: 10.2s
# 97:	learn: 0.0623114	total: 2m 5s	remaining: 8.95s
# 98:	learn: 0.0617716	total: 2m 5s	remaining: 7.63s
# 97:	learn: 0.0666688	total: 2m 5s	remaining: 8.99s
# 99:	learn: 0.0538023	total: 2m 6s	remaining: 6.31s
# 97:	learn: 0.0582107	total: 2m 5s	remaining: 8.97s
# 99:	learn: 0.0698294	total: 2m 5s	remaining: 6.27s
# 100:	learn: 0.0597991	total: 2m 5s	remaining: 4.97s
# 98:	learn: 0.0617805	total: 2m 5s	remaining: 7.63s
# 96:	learn: 0.0551284	total: 2m 5s	remaining: 10.4s
# 98:	learn: 0.0622726	total: 2m 6s	remaining: 7.65s
# 97:	learn: 0.0517502	total: 2m 5s	remaining: 8.96s
# 99:	learn: 0.0617535	total: 2m 7s	remaining: 6.35s
# 98:	learn: 0.0666017	total: 2m 7s	remaining: 7.71s
# 101:	learn: 0.0596431	total: 2m 6s	remaining: 3.73s
# 100:	learn: 0.0697652	total: 2m 6s	remaining: 5.01s
# 98:	learn: 0.0573325	total: 2m 6s	remaining: 7.69s
# 99:	learn: 0.0622356	total: 2m 7s	remaining: 6.37s
# 100:	learn: 0.0537908	total: 2m 7s	remaining: 5.07s
# 99:	learn: 0.0617578	total: 2m 7s	remaining: 6.36s
# 97:	learn: 0.0537937	total: 2m 6s	remaining: 9.06s
# 98:	learn: 0.0508539	total: 2m 6s	remaining: 7.68s
# 100:	learn: 0.0617393	total: 2m 8s	remaining: 5.09s
# 102:	learn: 0.0589455	total: 2m 7s	remaining: 2.48s
# 100:	learn: 0.0617399	total: 2m 8s	remaining: 5.07s
# 101:	learn: 0.0680694	total: 2m 7s	remaining: 3.76s
# 99:	learn: 0.0652771	total: 2m 8s	remaining: 6.44s
# 99:	learn: 0.0565051	total: 2m 8s	remaining: 6.41s
# 100:	learn: 0.0620636	total: 2m 8s	remaining: 5.09s
# 98:	learn: 0.0528317	total: 2m 8s	remaining: 7.76s
# 101:	learn: 0.0537607	total: 2m 9s	remaining: 3.8s
# 99:	learn: 0.0497528	total: 2m 7s	remaining: 6.4s
# 101:	learn: 0.0600410	total: 2m 9s	remaining: 3.81s
# 103:	learn: 0.0579884	total: 2m 8s	remaining: 1.24s
# 100:	learn: 0.0651825	total: 2m 9s	remaining: 5.14s
# 101:	learn: 0.0617181	total: 2m 9s	remaining: 3.8s
# 100:	learn: 0.0562322	total: 2m 9s	remaining: 5.12s
# 102:	learn: 0.0669448	total: 2m 9s	remaining: 2.51s
# 100:	learn: 0.0488311	total: 2m 8s	remaining: 5.11s
# 101:	learn: 0.0613664	total: 2m 9s	remaining: 3.82s
# 99:	learn: 0.0521297	total: 2m 9s	remaining: 6.47s
# 102:	learn: 0.0599350	total: 2m 10s	remaining: 2.54s
# 102:	learn: 0.0537493	total: 2m 10s	remaining: 2.54s
# 104:	learn: 0.0578627	total: 2m 9s	remaining: 0us
# 101:	learn: 0.0644858	total: 2m 11s	remaining: 3.86s
# 100:	learn: 0.0512856	total: 2m 10s	remaining: 5.17s
# 101:	learn: 0.0479075	total: 2m 10s	remaining: 3.83s
# 103:	learn: 0.0668430	total: 2m 10s	remaining: 1.25s
# 103:	learn: 0.0599071	total: 2m 11s	remaining: 1.26s
# 102:	learn: 0.0616865	total: 2m 10s	remaining: 2.54s
# 102:	learn: 0.0599777	total: 2m 11s	remaining: 2.55s
# 101:	learn: 0.0561387	total: 2m 11s	remaining: 3.85s
# 103:	learn: 0.0537216	total: 2m 11s	remaining: 1.27s
# 102:	learn: 0.0644136	total: 2m 12s	remaining: 2.56s
# 101:	learn: 0.0501167	total: 2m 11s	remaining: 3.86s
# 104:	learn: 0.0598928	total: 2m 12s	remaining: 0us
# 103:	learn: 0.0616672	total: 2m 12s	remaining: 1.27s
# 103:	learn: 0.0590321	total: 2m 12s	remaining: 1.27s
# 102:	learn: 0.0475698	total: 2m 11s	remaining: 2.55s
# 104:	learn: 0.0536461	total: 2m 13s	remaining: 0us
# 102:	learn: 0.0558799	total: 2m 12s	remaining: 2.57s
# 104:	learn: 0.0658206	total: 2m 12s	remaining: 0us
# 103:	learn: 0.0643724	total: 2m 13s	remaining: 1.28s
# 102:	learn: 0.0492093	total: 2m 12s	remaining: 2.57s
# 104:	learn: 0.0616509	total: 2m 12s	remaining: 0us
# 103:	learn: 0.0468271	total: 2m 12s	remaining: 1.27s
# 103:	learn: 0.0544601	total: 2m 13s	remaining: 1.28s
# 104:	learn: 0.0589973	total: 2m 13s	remaining: 0us
# 103:	learn: 0.0487649	total: 2m 13s	remaining: 1.28s
# 104:	learn: 0.0643375	total: 2m 13s	remaining: 0us
# 104:	learn: 0.0535248	total: 2m 13s	remaining: 0us
# 104:	learn: 0.0468069	total: 2m 13s	remaining: 0us
# 104:	learn: 0.0484664	total: 2m 13s	remaining: 0us
# 1-AR-Alva-6108-slim-Normalize-group.csv_CAT: the mean auc_roc for the training set is 1.000 with std 0.000
# 1-AR-Alva-6108-slim-Normalize-group.csv_CAT: the mean auc_roc for the validation set is 0.932 with std 0.011
# 1-AR-Alva-6108-slim-Normalize-group.csv_CAT: the mean auc_roc for the test set is 0.934 with std 0.009

# %%
# acc auc_roc recall precision f1 kappa mcc
acc_str = 'acc of training set is {:.3f}±{:.3f}, validation set is {:.3f}±{:.3f}, test set is {:.3f}±{:.3f}'.format(
                np.mean(stat_res[stat_res['set'] == 'tr']['acc']), 
                np.std(stat_res[stat_res['set'] == 'tr']['acc']),
                np.mean(stat_res[stat_res['set'] == 'va']['acc']), 
                np.std(stat_res[stat_res['set'] == 'va']['acc']),
                np.mean(stat_res[stat_res['set'] == 'te']['acc']), 
                np.std(stat_res[stat_res['set'] == 'te']['acc']),
)
auc_str = 'auc_roc of training set is {:.3f}±{:.3f}, validation set is {:.3f}±{:.3f}, test set is {:.3f}±{:.3f}'.format(
                np.mean(stat_res[stat_res['set'] == 'tr']['auc_roc']), 
                np.std(stat_res[stat_res['set'] == 'tr']['auc_roc']),
                np.mean(stat_res[stat_res['set'] == 'va']['auc_roc']), 
                np.std(stat_res[stat_res['set'] == 'va']['auc_roc']),
                np.mean(stat_res[stat_res['set'] == 'te']['auc_roc']), 
                np.std(stat_res[stat_res['set'] == 'te']['auc_roc']),
)
recall_str = 'recall of training set is {:.3f}±{:.3f}, validation set is {:.3f}±{:.3f}, test set is {:.3f}±{:.3f}'.format(
                np.mean(stat_res[stat_res['set'] == 'tr']['recall']), 
                np.std(stat_res[stat_res['set'] == 'tr']['recall']),
                np.mean(stat_res[stat_res['set'] == 'va']['recall']), 
                np.std(stat_res[stat_res['set'] == 'va']['recall']),
                np.mean(stat_res[stat_res['set'] == 'te']['recall']), 
                np.std(stat_res[stat_res['set'] == 'te']['recall']),
)
precision_str = 'precision of training set is {:.3f}±{:.3f}, validation set is {:.3f}±{:.3f}, test set is {:.3f}±{:.3f}'.format(
                np.mean(stat_res[stat_res['set'] == 'tr']['precision']), 
                np.std(stat_res[stat_res['set'] == 'tr']['precision']),
                np.mean(stat_res[stat_res['set'] == 'va']['precision']), 
                np.std(stat_res[stat_res['set'] == 'va']['precision']),
                np.mean(stat_res[stat_res['set'] == 'te']['precision']), 
                np.std(stat_res[stat_res['set'] == 'te']['precision']),
)
f1_str = 'f1 of training set is {:.3f}±{:.3f}, validation set is {:.3f}±{:.3f}, test set is {:.3f}±{:.3f}'.format(
                np.mean(stat_res[stat_res['set'] == 'tr']['f1']), 
                np.std(stat_res[stat_res['set'] == 'tr']['f1']),
                np.mean(stat_res[stat_res['set'] == 'va']['f1']), 
                np.std(stat_res[stat_res['set'] == 'va']['f1']),
                np.mean(stat_res[stat_res['set'] == 'te']['f1']), 
                np.std(stat_res[stat_res['set'] == 'te']['f1']),
)
kappa_str = 'kappa of training set is {:.3f}±{:.3f}, validation set is {:.3f}±{:.3f}, test set is {:.3f}±{:.3f}'.format(
                np.mean(stat_res[stat_res['set'] == 'tr']['kappa']), 
                np.std(stat_res[stat_res['set'] == 'tr']['kappa']),
                np.mean(stat_res[stat_res['set'] == 'va']['kappa']), 
                np.std(stat_res[stat_res['set'] == 'va']['kappa']),
                np.mean(stat_res[stat_res['set'] == 'te']['kappa']), 
                np.std(stat_res[stat_res['set'] == 'te']['kappa']),
)
mcc_str = 'mcc of training set is {:.3f}±{:.3f}, validation set is {:.3f}±{:.3f}, test set is {:.3f}±{:.3f}'.format(
                np.mean(stat_res[stat_res['set'] == 'tr']['mcc']), 
                np.std(stat_res[stat_res['set'] == 'tr']['mcc']),
                np.mean(stat_res[stat_res['set'] == 'va']['mcc']), 
                np.std(stat_res[stat_res['set'] == 'va']['mcc']),
                np.mean(stat_res[stat_res['set'] == 'te']['mcc']), 
                np.std(stat_res[stat_res['set'] == 'te']['mcc']),
)
print('the elapsed time is:', (end - start)/3600, 'H')
# Out:
# the elapsed time is: 0.39501462863551245 H

# %%
print(acc_str)
print(auc_str)
print(recall_str)
print(precision_str)
print(f1_str)
print(kappa_str)
print(mcc_str)
# Out:
# acc of training set is 0.995±0.002, validation set is 0.909±0.011, test set is 0.912±0.008
# auc_roc of training set is 1.000±0.000, validation set is 0.932±0.011, test set is 0.934±0.009
# recall of training set is 0.972±0.009, validation set is 0.629±0.037, test set is 0.638±0.023
# precision of training set is 1.000±0.001, validation set is 0.868±0.043, test set is 0.874±0.036
# f1 of training set is 0.985±0.005, validation set is 0.728±0.026, test set is 0.737±0.022
# kappa of training set is 0.982±0.006, validation set is 0.676±0.030, test set is 0.686±0.026
# mcc of training set is 0.982±0.006, validation set is 0.689±0.029, test set is 0.698±0.026

# %%
with open('output/output_cat.txt', 'w') as f:
    f.write(acc_str+'\n')
    f.write(auc_str+'\n')
    f.write(recall_str+'\n')
    f.write(precision_str+'\n')
    f.write(f1_str+'\n')
    f.write(kappa_str+'\n')
    f.write(mcc_str+'\n')
    f.write(str(cols_)+'\n')
cols_ = pd.DataFrame(cols_)
cols_.to_csv('output/output_cat_cols.csv',index=False)

# %%
import pandas as pd
import collections
dict1 = {"Model: CAT ":['acc','auc_roc','recall','precision','f1','kappa','mcc','auc_prc'],
         "Train":[np.mean(stat_res[stat_res['set'] == 'tr']['acc']),np.mean(stat_res[stat_res['set'] == 'tr']['auc_roc']),
                  np.mean(stat_res[stat_res['set'] == 'tr']['recall']),np.mean(stat_res[stat_res['set'] == 'tr']['precision']),
                  np.mean(stat_res[stat_res['set'] == 'tr']['f1']),np.mean(stat_res[stat_res['set'] == 'tr']['kappa']),
                  np.mean(stat_res[stat_res['set'] == 'tr']['mcc']),np.mean(stat_res[stat_res['set'] == 'tr']['auc_prc']),                                     
                 ],
         "Tr_STD":[np.std(stat_res[stat_res['set'] == 'tr']['acc']),np.std(stat_res[stat_res['set'] == 'tr']['auc_roc']),
                  np.std(stat_res[stat_res['set'] == 'tr']['recall']),np.std(stat_res[stat_res['set'] == 'tr']['precision']),
                  np.std(stat_res[stat_res['set'] == 'tr']['f1']),np.std(stat_res[stat_res['set'] == 'tr']['kappa']),
                  np.std(stat_res[stat_res['set'] == 'tr']['mcc']),np.std(stat_res[stat_res['set'] == 'tr']['auc_prc']),],
         "Validation":[np.mean(stat_res[stat_res['set'] == 'va']['acc']),np.mean(stat_res[stat_res['set'] == 'va']['auc_roc']),
                      np.mean(stat_res[stat_res['set'] == 'va']['recall']),np.mean(stat_res[stat_res['set'] == 'va']['precision']),
                      np.mean(stat_res[stat_res['set'] == 'va']['f1']),np.mean(stat_res[stat_res['set'] == 'va']['kappa']),
                      np.mean(stat_res[stat_res['set'] == 'va']['mcc']),np.mean(stat_res[stat_res['set'] == 'va']['auc_prc'])],
         "Va_STD":[np.std(stat_res[stat_res['set'] == 'va']['acc']),np.std(stat_res[stat_res['set'] == 'va']['auc_roc']),
                  np.std(stat_res[stat_res['set'] == 'va']['recall']),np.std(stat_res[stat_res['set'] == 'va']['precision']),
                  np.std(stat_res[stat_res['set'] == 'va']['f1']),np.std(stat_res[stat_res['set'] == 'va']['kappa']),
                  np.std(stat_res[stat_res['set'] == 'va']['mcc']),np.std(stat_res[stat_res['set'] == 'va']['auc_prc'])],
         "Test":[np.mean(stat_res[stat_res['set'] == 'te']['acc']),np.mean(stat_res[stat_res['set'] == 'te']['auc_roc']),
                np.mean(stat_res[stat_res['set'] == 'te']['recall']),np.mean(stat_res[stat_res['set'] == 'te']['precision']),
                np.mean(stat_res[stat_res['set'] == 'te']['f1']),np.mean(stat_res[stat_res['set'] == 'te']['kappa']),
                np.mean(stat_res[stat_res['set'] == 'te']['mcc']),np.mean(stat_res[stat_res['set'] == 'te']['auc_prc'])],
          "Te_STD":[np.std(stat_res[stat_res['set'] == 'te']['acc']),np.std(stat_res[stat_res['set'] == 'te']['auc_roc']),
                   np.std(stat_res[stat_res['set'] == 'te']['recall']),np.std(stat_res[stat_res['set'] == 'te']['precision']),
                   np.std(stat_res[stat_res['set'] == 'te']['f1']),np.std(stat_res[stat_res['set'] == 'te']['kappa']),
                   np.std(stat_res[stat_res['set'] == 'te']['mcc']),np.std(stat_res[stat_res['set'] == 'te']['auc_prc']),]}
dict1 = collections.OrderedDict(dict1)
df = pd.DataFrame(dict1,index = None)
df.to_csv('output/output_cat.csv',index = False)
df
# Out:
#   Model: CAT      Train    Tr_STD  Validation    Va_STD      Test    Te_STD
# 0         acc  0.994542  0.001746    0.909273  0.010923  0.911620  0.008118
# 1     auc_roc  0.999830  0.000127    0.932384  0.011347  0.934437  0.008692
# 2      recall  0.971634  0.008895    0.629329  0.037213  0.638139  0.023370
# 3   precision  0.999669  0.000506    0.868477  0.042965  0.874247  0.035595
# 4          f1  0.985432  0.004672    0.728480  0.026154  0.737329  0.022034
# 5       kappa  0.982075  0.005743    0.675745  0.030272  0.685749  0.025647
# 6         mcc  0.982240  0.005659    0.689275  0.028694  0.698355  0.026133
# 7     auc_prc  0.999396  0.000430    0.843364  0.021207  0.848043  0.014840

# %%
pd.set_option ( 'display.width', None)
pd.set_option ( 'display.max_columns', None) #显示全部列
hyper_parameters = best_hyper.iloc[0:1,8:-14].T
hyper_parameters.rename(columns={0:'Values'},inplace=True) 
hyper_parameters
# Out:
#                      Values
# n_estimators     105.000000
# learning_rate      0.355041
# depth             10.000000
# random_strength    0.331550
# l2_leaf_reg       27.000000
