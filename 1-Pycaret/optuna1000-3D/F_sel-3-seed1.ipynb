# %%
import numpy as np
import pandas as pd
df = pd.read_csv('descriptors-alva-66-fix.csv')
ncol = df.shape[1]-1
x = df.iloc[:,0:ncol]
y = df['active']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state = 1)

# %%
trainD = pd.concat([x_train, y_train], axis =1)
testD = pd.concat([x_test, y_test], axis =1)

# %%
F_sel = ['EE_B(s)', 'Mor16u', 'CATS2D_03_AL']
trainD = trainD[['EE_B(s)', 'Mor16u', 'CATS2D_03_AL','active']]
testD = testD[['EE_B(s)', 'Mor16u', 'CATS2D_03_AL','active']]

# %%
from pycaret.classification import *
cm = setup(data = trainD, target = 'active', train_size = 0.8, test_data = testD, silent=True,  numeric_features = F_sel,
             session_id=1, fold_strategy = 'stratifiedkfold', fold = 5, fold_shuffle = True, normalize = True)
# Out:
# <style type="text/css">
# #T_0e091_row0_col1, #T_0e091_row29_col1, #T_0e091_row44_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_0e091">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0e091_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_0e091_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0e091_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0e091_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_0e091_row0_col1" class="data row0 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_0e091_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0e091_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_0e091_row1_col1" class="data row1 col1" >active</td>
#     </tr>
#     <tr>
# ...

# %%
compare_models()
# Out:
# <style type="text/css">
# #T_73608 th {
#   text-align: left;
# }
# ...

# %%
mlp = create_model('mlp')
tunedmlp = tune_model(mlp, n_iter = 1000,  search_library = 'optuna', optimize = 'AUC')
predict_model(tunedmlp)
# Out:
# <style type="text/css">
# #T_db0e6_row5_col0, #T_db0e6_row5_col1, #T_db0e6_row5_col2, #T_db0e6_row5_col3, #T_db0e6_row5_col4, #T_db0e6_row5_col5, #T_db0e6_row5_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_db0e6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_db0e6_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_db0e6_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_db0e6_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_db0e6_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_db0e6_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_db0e6_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_db0e6_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
cat = create_model('catboost')
tunedcat = tune_model(cat, n_iter = 1000,  search_library = 'optuna', optimize = 'AUC')
predict_model(tunedcat)
# Out:
# <style type="text/css">
# #T_fe96f_row5_col0, #T_fe96f_row5_col1, #T_fe96f_row5_col2, #T_fe96f_row5_col3, #T_fe96f_row5_col4, #T_fe96f_row5_col5, #T_fe96f_row5_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_fe96f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fe96f_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_fe96f_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_fe96f_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_fe96f_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_fe96f_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_fe96f_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_fe96f_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
lgb = create_model('lightgbm')
tunedlgb = tune_model(lgb, n_iter = 1000,  search_library = 'optuna', optimize = 'AUC')
predict_model(tunedlgb)
# Out:
# <style type="text/css">
# #T_7bfd2_row5_col0, #T_7bfd2_row5_col1, #T_7bfd2_row5_col2, #T_7bfd2_row5_col3, #T_7bfd2_row5_col4, #T_7bfd2_row5_col5, #T_7bfd2_row5_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_7bfd2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7bfd2_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_7bfd2_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_7bfd2_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_7bfd2_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_7bfd2_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_7bfd2_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_7bfd2_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
svm = create_model('rbfsvm')
tunedsvm = tune_model(svm, n_iter = 1000,  search_library = 'optuna', optimize = 'AUC')
predict_model(tunedsvm)
# Out:
# <style type="text/css">
# #T_70570_row5_col0, #T_70570_row5_col1, #T_70570_row5_col2, #T_70570_row5_col3, #T_70570_row5_col4, #T_70570_row5_col5, #T_70570_row5_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_70570">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_70570_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_70570_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_70570_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_70570_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_70570_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_70570_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_70570_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
xgb = create_model('xgboost')
tunedxgb = tune_model(xgb, n_iter = 1000,  search_library = 'optuna', optimize = 'AUC')
predict_model(tunedxgb)
# Out:
# <style type="text/css">
# #T_b008c_row5_col0, #T_b008c_row5_col1, #T_b008c_row5_col2, #T_b008c_row5_col3, #T_b008c_row5_col4, #T_b008c_row5_col5, #T_b008c_row5_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_b008c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b008c_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_b008c_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_b008c_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_b008c_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_b008c_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_b008c_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_b008c_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
et = create_model('et')
tunedet = tune_model(et, n_iter = 1000,  search_library = 'optuna', optimize = 'AUC')
predict_model(tunedet)
# Out:
# <style type="text/css">
# #T_b3b60_row5_col0, #T_b3b60_row5_col1, #T_b3b60_row5_col2, #T_b3b60_row5_col3, #T_b3b60_row5_col4, #T_b3b60_row5_col5, #T_b3b60_row5_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_b3b60">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b3b60_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_b3b60_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_b3b60_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_b3b60_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_b3b60_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_b3b60_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_b3b60_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
rf = create_model('rf')
tunedrf = tune_model(rf, n_iter = 1000,  search_library = 'optuna', optimize = 'AUC')
predict_model(tunedrf)
# Out:
# <style type="text/css">
# #T_05d4a_row5_col0, #T_05d4a_row5_col1, #T_05d4a_row5_col2, #T_05d4a_row5_col3, #T_05d4a_row5_col4, #T_05d4a_row5_col5, #T_05d4a_row5_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_05d4a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_05d4a_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_05d4a_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_05d4a_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_05d4a_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_05d4a_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_05d4a_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_05d4a_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
gbc = create_model('gbc')
tunedgbc = tune_model(gbc, n_iter = 1000,  search_library = 'optuna', optimize = 'AUC')
predict_model(tunedgbc)
# Out:
# <style type="text/css">
# #T_6d42c_row5_col0, #T_6d42c_row5_col1, #T_6d42c_row5_col2, #T_6d42c_row5_col3, #T_6d42c_row5_col4, #T_6d42c_row5_col5, #T_6d42c_row5_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_6d42c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6d42c_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_6d42c_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_6d42c_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_6d42c_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_6d42c_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_6d42c_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_6d42c_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
gbc_tuned_model, gbc_tuner = tune_model(gbc, n_iter = 1,  search_library = 'optuna', optimize = 'AUC',return_tuner=True)
et_tuned_model, et_tuner = tune_model(et, n_iter = 1,  search_library = 'optuna', optimize = 'AUC',return_tuner=True)
lgb_tuned_model, lgb_tuner = tune_model(lgb, n_iter = 1,  search_library = 'optuna', optimize = 'AUC',return_tuner=True)
xgb_tuned_model, xgb_tuner = tune_model(xgb, n_iter = 1,  search_library = 'optuna', optimize = 'AUC',return_tuner=True)
svm_tuned_model, svm_tuner = tune_model(svm, n_iter = 1,  search_library = 'optuna', optimize = 'AUC',return_tuner=True)
mlp_tuned_model, mlp_tuner = tune_model(mlp, n_iter = 1,  search_library = 'optuna', optimize = 'AUC',return_tuner=True)
# Out:
# <style type="text/css">
# #T_649a6_row5_col0, #T_649a6_row5_col1, #T_649a6_row5_col2, #T_649a6_row5_col3, #T_649a6_row5_col4, #T_649a6_row5_col5, #T_649a6_row5_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_649a6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_649a6_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_649a6_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_649a6_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_649a6_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_649a6_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_649a6_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_649a6_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
gbc_tuner.get_params(True)['param_distributions']
# Out:
# {'actual_estimator__n_estimators': IntUniformDistribution(high=300, low=10, step=1),
#  'actual_estimator__learning_rate': LogUniformDistribution(high=0.5, low=1e-06),
#  'actual_estimator__subsample': UniformDistribution(high=1.0, low=0.2),
#  'actual_estimator__min_samples_split': IntUniformDistribution(high=10, low=2, step=1),
#  'actual_estimator__min_samples_leaf': IntUniformDistribution(high=5, low=1, step=1),
#  'actual_estimator__max_depth': IntUniformDistribution(high=11, low=1, step=1),
#  'actual_estimator__min_impurity_decrease': LogUniformDistribution(high=0.5, low=1e-09),
#  'actual_estimator__max_features': UniformDistribution(high=1.0, low=0.4)}

# %%
et_tuner.get_params(True)['param_distributions']
# Out:
# {'actual_estimator__n_estimators': IntUniformDistribution(high=300, low=10, step=1),
#  'actual_estimator__max_depth': IntUniformDistribution(high=11, low=1, step=1),
#  'actual_estimator__min_samples_split': IntUniformDistribution(high=10, low=2, step=1),
#  'actual_estimator__min_samples_leaf': IntUniformDistribution(high=5, low=1, step=1),
#  'actual_estimator__max_features': UniformDistribution(high=1.0, low=0.4),
#  'actual_estimator__min_impurity_decrease': LogUniformDistribution(high=0.5, low=1e-09),
#  'actual_estimator__criterion': CategoricalDistribution(choices=('gini', 'entropy')),
#  'actual_estimator__bootstrap': CategoricalDistribution(choices=(True, False)),
#  'actual_estimator__class_weight': CategoricalDistribution(choices=('balanced', 'balanced_subsample', {}))}

# %%
lgb_tuner.get_params(True)['param_distributions']
# Out:
# {'actual_estimator__num_leaves': IntUniformDistribution(high=256, low=2, step=1),
#  'actual_estimator__learning_rate': LogUniformDistribution(high=0.5, low=1e-06),
#  'actual_estimator__n_estimators': IntUniformDistribution(high=300, low=10, step=1),
#  'actual_estimator__min_split_gain': UniformDistribution(high=1.0, low=0.0),
#  'actual_estimator__reg_alpha': LogUniformDistribution(high=10.0, low=1e-10),
#  'actual_estimator__reg_lambda': LogUniformDistribution(high=10.0, low=1e-10),
#  'actual_estimator__feature_fraction': UniformDistribution(high=1.0, low=0.4),
#  'actual_estimator__bagging_fraction': UniformDistribution(high=1.0, low=0.4),
#  'actual_estimator__bagging_freq': IntUniformDistribution(high=7, low=0, step=1),
#  'actual_estimator__min_child_samples': IntUniformDistribution(high=100, low=1, step=1)}

# %%
xgb_tuner.get_params(True)['param_distributions']
# Out:
# {'actual_estimator__learning_rate': LogUniformDistribution(high=0.5, low=1e-06),
#  'actual_estimator__n_estimators': IntUniformDistribution(high=300, low=10, step=1),
#  'actual_estimator__subsample': UniformDistribution(high=1.0, low=0.2),
#  'actual_estimator__max_depth': IntUniformDistribution(high=11, low=1, step=1),
#  'actual_estimator__colsample_bytree': UniformDistribution(high=1.0, low=0.5),
#  'actual_estimator__min_child_weight': IntUniformDistribution(high=4, low=1, step=1),
#  'actual_estimator__reg_alpha': LogUniformDistribution(high=10.0, low=1e-10),
#  'actual_estimator__reg_lambda': LogUniformDistribution(high=10.0, low=1e-10),
#  'actual_estimator__scale_pos_weight': UniformDistribution(high=50.0, low=1.0)}

# %%
svm_tuner.get_params(True)['param_distributions']
# Out:
# {'actual_estimator__C': UniformDistribution(high=50.0, low=0.0),
#  'actual_estimator__class_weight': CategoricalDistribution(choices=('balanced', {}))}

# %%
mlp_tuner.get_params(True)['param_distributions']
# Out:
# {'actual_estimator__alpha': LogUniformDistribution(high=0.9999999999, low=1e-10),
#  'actual_estimator__hidden_layer_size_0': IntUniformDistribution(high=100, low=50, step=1),
#  'actual_estimator__hidden_layer_size_1': IntUniformDistribution(high=100, low=0, step=1),
#  'actual_estimator__hidden_layer_size_2': IntUniformDistribution(high=100, low=0, step=1),
#  'actual_estimator__learning_rate': CategoricalDistribution(choices=('constant', 'invscaling', 'adaptive')),
#  'actual_estimator__activation': CategoricalDistribution(choices=('tanh', 'identity', 'logistic', 'relu'))}

# %%
svm_tuner
# Out:
# OptunaSearchCV(cv=StratifiedKFold(n_splits=5, random_state=1, shuffle=True),
#                enable_pruning=False, error_score='raise',
#                estimator=Pipeline(memory=None,
#                                   steps=[('empty_step', 'passthrough'),
#                                          ('actual_estimator',
#                                           SVC(C=1.0, break_ties=False,
#                                               cache_size=200, class_weight=None,
#                                               coef0=0.0,
#                                               decision_function_shape='ovr',
#                                               degree=3, gamma='auto',
#                                               kernel='rbf', max_iter=-1,
#                                               p...
#                param_distributions={'actual_estimator__C': UniformDistribution(high=50.0, low=0.0),
# ...

# %%
mlp_tuner.get_params(True)
# Out:
# {'cv': StratifiedKFold(n_splits=5, random_state=1, shuffle=True),
#  'enable_pruning': False,
#  'error_score': 'raise',
#  'estimator__memory': None,
#  'estimator__steps': [('empty_step', 'passthrough'),
#   ('actual_estimator',
#    TunableMLPClassifier(activation='logistic', alpha=7.914564592305138e-07,
#                         batch_size='auto', beta_1=0.9, beta_2=0.999,
#                         early_stopping=False, epsilon=1e-08,
#                         hidden_layer_size_0=57, hidden_layer_size_1=65,
#                         hidden_layer_size_2=84, hidden_layer_sizes=[57, 65, 84],
#                         learning_rate='constant', learning_rate_init=0.001,
#                         max_fun=15000, max_iter=500, momentum=0.9,
#                         n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#                         random_state=1, shuffle=True, solver='adam', tol=0.0001,
# ...

# %%
gbc_tuned_model, gbc_tuner = tune_model(gbc, n_iter = 1,  search_library = 'scikit-optimize', optimize = 'AUC',return_tuner=True)
# Out:
# <style type="text/css">
# #T_9f10f_row5_col0, #T_9f10f_row5_col1, #T_9f10f_row5_col2, #T_9f10f_row5_col3, #T_9f10f_row5_col4, #T_9f10f_row5_col5, #T_9f10f_row5_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_9f10f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9f10f_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_9f10f_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_9f10f_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_9f10f_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_9f10f_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_9f10f_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_9f10f_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
gbc_tuner.get_params(True)
# Out:
# {'cv': StratifiedKFold(n_splits=5, random_state=1, shuffle=True),
#  'error_score': 'raise',
#  'estimator__memory': None,
#  'estimator__steps': [('empty_step', 'passthrough'),
#   ('actual_estimator',
#    GradientBoostingClassifier(ccp_alpha=0.0, criterion='friedman_mse', init=None,
#                               learning_rate=0.1, loss='deviance', max_depth=3,
#                               max_features=None, max_leaf_nodes=None,
#                               min_impurity_decrease=0.0, min_impurity_split=None,
#                               min_samples_leaf=1, min_samples_split=2,
#                               min_weight_fraction_leaf=0.0, n_estimators=100,
#                               n_iter_no_change=None, presort='deprecated',
#                               random_state=1, subsample=1.0, tol=0.0001,
#                               validation_fraction=0.1, verbose=0,
#                               warm_start=False))],
#  'estimator__verbose': False,
# ...

# %%
cat_tuned_model,cat_tuner = tune_model(cat, n_iter = 1,  search_library = 'optuna', optimize = 'AUC',return_tuner=True)
# Out:
# <style type="text/css">
# #T_8cd3a_row5_col0, #T_8cd3a_row5_col1, #T_8cd3a_row5_col2, #T_8cd3a_row5_col3, #T_8cd3a_row5_col4, #T_8cd3a_row5_col5, #T_8cd3a_row5_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_8cd3a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8cd3a_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_8cd3a_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_8cd3a_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_8cd3a_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_8cd3a_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_8cd3a_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_8cd3a_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
cat_tuner.get_params(True)['param_distributions']
# Out:
# {'actual_estimator__eta': LogUniformDistribution(high=0.5, low=1e-06),
#  'actual_estimator__depth': IntUniformDistribution(high=11, low=1, step=1),
#  'actual_estimator__n_estimators': IntUniformDistribution(high=300, low=10, step=1),
#  'actual_estimator__random_strength': UniformDistribution(high=0.8, low=0.0),
#  'actual_estimator__l2_leaf_reg': IntLogUniformDistribution(high=200, low=1, step=1)}
